# %% [markdown]
# # <center>Machine Learning with Spark MLlib</center>
# ## <center>Decision Trees and Random Forests</center>
# ### <center>July 20,2016</center>

# %% [markdown]
# <img src = "https://ibm.box.com/shared/static/wfbduwkbx22nx3i2psbp9g27s2p9s86v.png", width="500" align = 'center'>

# %% [markdown]
# ## <b>Welcome to the third lab in the course, Machine Learning with Spark MLlib.</b>
# ### <b>Spark has many libraries, namely under MLlib (Machine Learning Library)! Spark allows for quick and easy scalability of practical machine learning!</b>
#
# In this lab exercise, you will learn how to create Classification and Regression DecisionTree and RandomForest Models, as well as how to tune the parameters for each to create more optimal trees and ensembles of trees.

# %% [markdown]
# ### Some Notebook Commands
# #### In case you haven't dealt with a Jupyter Notebook before, here are some quick, useful commands that may be handy to get started.
# <ul>
#     <li>Run a cell: CTRL + ENTER</li>
#     <li>Create a cell above a cell: a</li>
#     <li>Create a cell below a cell: b</li>
#     <li>Change a cell to Markdown: m</li>
#
#     <li>Change a cell to code: y</li>
# </ul>
#
# <b> If you are interested in more keyboard shortcuts, go to Help -> Keyboard Shortcuts </b>

# %% [markdown]
# ### How this lab will operate:
# In this lab, you will be presented with a walk-through of a Regression DecisionTree model with how to tune some of the parameters. Then, you will create a Classification DecisionTree model yourself. You will also be presented with a walk-through of a Classification RandomForest model with how to tune some of the parameters, then you will create a Regression RandomForest model yourself.

# %% [markdown]
# ## DecisionTree (Regression)

# %% [markdown]
# Import the following libraries:
# <ul>
#     <li>DecisionTree, DecisionTreeModel from pyspark.mllib.tree</li>
#     <li>MLUtils from pyspark.mllib.util</li>
#     <li>time</li>
# </ul>

# %%
from pyspark.mllib.tree import DecisionTree, DecisionTreeModel
from pyspark.mllib.util import MLUtils
import time

# %% [markdown]
# Next, we will load in the <b>poker.txt</b> LibSVM file, which is a dataset based on poker hands. Use <b>MLUtils.loadLibSVMFile</b> and pass in the spark context (<b>sc</b>) and the path to the file <b>'resources/poker.txt'</b>. Store this into a variable called <b>regDT_data</b>

# %%
regDT_data = MLUtils.loadLibSVMFile(sc, '/resources/data/poker.txt')

# %% [markdown]
# Next, we need to split the data into a training dataset (called <b>regDT_train</b>) and testing dataset (called <b>regDT_test</b>). This will be done by running the <b>.randomSplit</b> function on <b>regDT_data</b>. The input into .randomSplit will be <b>[0.7, 0.3]</b>. <br> <br>
#
# This will give us a training dataset containing 70% of the data, and a testing dataset containing 30% of the data.

# %%
(regDT_train, regDT_test) = regDT_data.randomSplit([0.7, 0.3])

# %% [markdown]
# Next, we need to create the Regression Decision Tree called <b>regDT_model</b>. To instantiate the regressor, use <b>DecisionTree.trainRegressor</b>. We will pass in the following parameters:
# <ul>
#     <li>1st: The input data. In our case, we will use <b>regDT_train</b></li>
#     <li>2nd: The categorical features info. For our dataset, have <b>categoricalFeaturesInfo</b> equal <b>{}</b></li>
#     <li>3rd: The type of impurity. Since we're dealing with <b>Regression</b>, we will be have <b>impurity</b> set to <b>'variance'</b></li>
#     <li>4th: The maximum depth of the tree. For now, set <b>maxDepth</b> to <b>5</b>, which is the default value</li>
#     <li>5th: The maximum number of bins. For now, set <b>maxBins</b> to <b>32</b>, which is the default value</li>
#     <li>6th: The minimum instances required per node. For now, set <b>minInstancesPerNode</b> to <b>1</b>, which is the default value</li>
#     <li>7th: The minimum required information gain per node. For now, set <b>minInfoGain</b> to <b>0.0</b>, which is the default value</li>
# </ul> <br> <br>
#
# We will also be timing how long it takes to create the model, so run <b>start = time.time()</b> before creating the model and <b>print(time.time()-start)</b> after the model has been created. <br>
# <b>Note</b>: The timings differ on run and by computer, therefore some statements throughout the lab may not directly align with the results you get, which is okay! There are many factors that can affect the time output.

# %%
start = time.time()
regDT_model = DecisionTree.trainRegressor(regDT_train, categoricalFeaturesInfo={},
                                    impurity='variance', maxDepth=5, maxBins=32,
                                    minInstancesPerNode=1, minInfoGain=0.0)
print (time.time()-start)
# Out:
# 4.51244497299

# %% [markdown]
# Next, we want to get the models prediction on the test data, which we will call <b>regDT_pred</b>. We will run <b>.predict</b> on regDT_model, passing in the testing data, <b>regDT_test</b> that is mapped using <b>.map</b> which maps the features by passing in a lambda function (<b>lambda x: x.features</b>).

# %%
regDT_pred = regDT_model.predict(regDT_test.map(lambda x: x.features))

# %% [markdown]
# Now create a variable called <b>regDT_label_pred</b> which uses a <b>.map</b> on <b>regDT_test</b>. Pass <b>lambda l: l.label</b> into the mapping function. Outside of the mapping function, add a <b>.zip(regDT_pred)</b>. This will merge the label with the prediction</b>

# %%
regDT_label_pred = regDT_test.map(lambda l: l.label).zip(regDT_pred)

# %% [markdown]
# Now we will calculate the Mean Squared Error for this prediction, which we will call <b>regDT_MSE</b>. This will equate to <b>regDT_label_pred.map(lambda (v, p): (v - p)**2).sum() / float(regDT_test.count())</b>, which will take the difference of the actual value and the predicted response, square it, and sum that with the rest of the values. Afterwards, it is divided by the total number of values in the testing data.

# %%
regDT_MSE = regDT_label_pred.map(lambda (v, p): (v - p)**2).sum() / float(regDT_test.count())

# %% [markdown]
# Next, print out the MSE prediction value (<b>str(regDT_MSE)</b>), as well as the learned regression tree model (<b>regDT_model.toDebugString()</b>), so you have an idea of what the tree looks like.

# %%
print('Test Mean Squared Error = ' + str(regDT_MSE))
print('Learned Regression Tree Model: ' + regDT_model.toDebugString())
# Out:
# Test Mean Squared Error = 0.604814685923
# Learned Regression Tree Model: DecisionTreeModel regressor of depth 5 with 61 nodes
#   If (feature 7 <= 2.0)
#    If (feature 1 <= 2.0)
#     If (feature 5 <= 2.0)
#      If (feature 9 <= 2.0)
#       Predict: 3.0
#      Else (feature 9 > 2.0)
#       If (feature 3 <= 2.0)
#        Predict: 2.25
#       Else (feature 3 > 2.0)
#        Predict: 1.425
#     Else (feature 5 > 2.0)
#      If (feature 9 <= 2.0)
#       If (feature 3 <= 2.0)
#        Predict: 2.25
#       Else (feature 3 > 2.0)
#        Predict: 1.2941176470588236
#      Else (feature 9 > 2.0)
#       If (feature 3 <= 5.0)
#        Predict: 1.030612244897959
#       Else (feature 3 > 5.0)
#        Predict: 0.5538461538461539
#    Else (feature 1 > 2.0)
#     If (feature 5 <= 2.0)
#      If (feature 3 <= 2.0)
#       If (feature 9 <= 2.0)
#        Predict: 2.0
#       Else (feature 9 > 2.0)
#        Predict: 1.1951219512195121
#      Else (feature 3 > 2.0)
#       If (feature 9 <= 2.0)
#        Predict: 1.2222222222222223
#       Else (feature 9 > 2.0)
#        Predict: 0.6666666666666666
#     Else (feature 5 > 2.0)
#      If (feature 3 <= 2.0)
#       If (feature 9 <= 2.0)
#        Predict: 1.3870967741935485
#       Else (feature 9 > 2.0)
#        Predict: 0.6546762589928058
#      Else (feature 3 > 2.0)
#       If (feature 9 <= 2.0)
#        Predict: 0.61328125
#       Else (feature 9 > 2.0)
#        Predict: 0.41295546558704455
#   Else (feature 7 > 2.0)
#    If (feature 5 <= 2.0)
#     If (feature 3 <= 2.0)
#      If (feature 9 <= 2.0)
#       If (feature 1 <= 5.0)
#        Predict: 1.8666666666666667
#       Else (feature 1 > 5.0)
#        Predict: 1.3243243243243243
#      Else (feature 9 > 2.0)
#       If (feature 1 <= 2.0)
#        Predict: 1.4594594594594594
#       Else (feature 1 > 2.0)
#        Predict: 0.6722689075630253
#     Else (feature 3 > 2.0)
#      If (feature 9 <= 2.0)
#       If (feature 1 <= 2.0)
#        Predict: 1.3265306122448979
#       Else (feature 1 > 2.0)
#        Predict: 0.6345381526104418
#      Else (feature 9 > 2.0)
#       If (feature 1 <= 2.0)
#        Predict: 0.6343612334801763
#       Else (feature 1 > 2.0)
#        Predict: 0.4488355681016232
#    Else (feature 5 > 2.0)
#     If (feature 9 <= 2.0)
#      If (feature 1 <= 2.0)
#       If (feature 3 <= 2.0)
#        Predict: 1.5490196078431373
#       Else (feature 3 > 2.0)
#        Predict: 0.7374517374517374
#      Else (feature 1 > 2.0)
#       If (feature 3 <= 2.0)
#        Predict: 0.6197183098591549
#       Else (feature 3 > 2.0)
#        Predict: 0.44049247606019154
#     Else (feature 9 > 2.0)
#      If (feature 1 <= 2.0)
#       If (feature 3 <= 2.0)
#        Predict: 0.676923076923077
#       Else (feature 3 > 2.0)
#        Predict: 0.44680851063829785
#      Else (feature 1 > 2.0)
#       If (feature 3 <= 2.0)
#        Predict: 0.45174825174825173
#       Else (feature 3 > 2.0)
#        Predict: 0.736391268306162

# %% [markdown]
# Now that we've created the basic Regression Decision Tree, let's start tuning some parameters! To speed up the process and reduce the amount of code that appears in this notebook, I've made a function that encorporates all of the code above. This way, we can tune the parameters in a single line of code. <br> <br>
#
# Read over the code, and it should be apparent what each of the inputs should be. But just to reiterate:
# <ul>
#     <li>1st: maxDepthValue is the value for maxDepth (Type:Int, Range: 0 to 30)</li>
#     <li>2nd: maxBinsValue is the value for maxBins (Type: Int, Range: >= 2)</li>
#     <li>3rd: minInstancesValue is the value for minInstancesPerNode (Type: Int, Range: >=1)</li>
#     <li>4th: minInfoGainValue is the value for minInfoGain (Type: Float)</li>
#     <ul>
#         <li><b>NOTE</b>: The input for minInfoGain MUST contain a decimal (ex. -3.0, 0.1, etc.) or else you will get an error</li>
#     </ul>
# </ul>

# %%
def regDT_tuner(maxDepthValue, maxBinsValue, minInstancesValue, minInfoGainValue):
    start = time.time()
    regDT_model = DecisionTree.trainRegressor(regDT_train, categoricalFeaturesInfo={},
                                        impurity='variance', maxDepth=maxDepthValue, maxBins=maxBinsValue,
                                        minInstancesPerNode=minInstancesValue, minInfoGain=minInfoGainValue)
    print (time.time()-start)

    regDT_pred = regDT_model.predict(regDT_test.map(lambda x: x.features))
    regDT_label_pred = regDT_test.map(lambda l: l.label).zip(regDT_pred)
    regDT_MSE = regDT_label_pred.map(lambda (v, p): (v - p)**2).sum() / float(regDT_test.count())

    print('Test Mean Squared Error = ' + str(regDT_MSE))
    print('Learned Regression Tree Model: ' + regDT_model.toDebugString())

# %% [markdown]
# Start off by re-creating the original tree. That requires the inputs: <b>(5, 32, 1, 0.0)</b> into <b>regDT_tuner</b>

# %%
regDT_tuner(5, 32, 1, 0.0)
# Out:
# 1.61899995804
# Test Mean Squared Error = 0.604814685923
# Learned Regression Tree Model: DecisionTreeModel regressor of depth 5 with 61 nodes
#   If (feature 7 <= 2.0)
#    If (feature 1 <= 2.0)
#     If (feature 5 <= 2.0)
#      If (feature 9 <= 2.0)
#       Predict: 3.0
#      Else (feature 9 > 2.0)
#       If (feature 3 <= 2.0)
#        Predict: 2.25
#       Else (feature 3 > 2.0)
#        Predict: 1.425
#     Else (feature 5 > 2.0)
#      If (feature 9 <= 2.0)
#       If (feature 3 <= 2.0)
#        Predict: 2.25
#       Else (feature 3 > 2.0)
#        Predict: 1.2941176470588236
#      Else (feature 9 > 2.0)
#       If (feature 3 <= 5.0)
#        Predict: 1.030612244897959
#       Else (feature 3 > 5.0)
#        Predict: 0.5538461538461539
#    Else (feature 1 > 2.0)
#     If (feature 5 <= 2.0)
#      If (feature 3 <= 2.0)
#       If (feature 9 <= 2.0)
#        Predict: 2.0
#       Else (feature 9 > 2.0)
#        Predict: 1.1951219512195121
#      Else (feature 3 > 2.0)
#       If (feature 9 <= 2.0)
#        Predict: 1.2222222222222223
#       Else (feature 9 > 2.0)
#        Predict: 0.6666666666666666
#     Else (feature 5 > 2.0)
#      If (feature 3 <= 2.0)
#       If (feature 9 <= 2.0)
#        Predict: 1.3870967741935485
#       Else (feature 9 > 2.0)
#        Predict: 0.6546762589928058
#      Else (feature 3 > 2.0)
#       If (feature 9 <= 2.0)
#        Predict: 0.61328125
#       Else (feature 9 > 2.0)
#        Predict: 0.41295546558704455
#   Else (feature 7 > 2.0)
#    If (feature 5 <= 2.0)
#     If (feature 3 <= 2.0)
#      If (feature 9 <= 2.0)
#       If (feature 1 <= 5.0)
#        Predict: 1.8666666666666667
#       Else (feature 1 > 5.0)
#        Predict: 1.3243243243243243
#      Else (feature 9 > 2.0)
#       If (feature 1 <= 2.0)
#        Predict: 1.4594594594594594
#       Else (feature 1 > 2.0)
#        Predict: 0.6722689075630253
#     Else (feature 3 > 2.0)
#      If (feature 9 <= 2.0)
#       If (feature 1 <= 2.0)
#        Predict: 1.3265306122448979
#       Else (feature 1 > 2.0)
#        Predict: 0.6345381526104418
#      Else (feature 9 > 2.0)
#       If (feature 1 <= 2.0)
#        Predict: 0.6343612334801763
#       Else (feature 1 > 2.0)
#        Predict: 0.4488355681016232
#    Else (feature 5 > 2.0)
#     If (feature 9 <= 2.0)
#      If (feature 1 <= 2.0)
#       If (feature 3 <= 2.0)
#        Predict: 1.5490196078431373
#       Else (feature 3 > 2.0)
#        Predict: 0.7374517374517374
#      Else (feature 1 > 2.0)
#       If (feature 3 <= 2.0)
#        Predict: 0.6197183098591549
#       Else (feature 3 > 2.0)
#        Predict: 0.44049247606019154
#     Else (feature 9 > 2.0)
#      If (feature 1 <= 2.0)
#       If (feature 3 <= 2.0)
#        Predict: 0.676923076923077
#       Else (feature 3 > 2.0)
#        Predict: 0.44680851063829785
#      Else (feature 1 > 2.0)
#       If (feature 3 <= 2.0)
#        Predict: 0.45174825174825173
#       Else (feature 3 > 2.0)
#        Predict: 0.736391268306162

# %% [markdown]
# Remember that when we are tuning a specific parameter, that we will keep the other parameters at their original value

# %% [markdown]
# ### maxDepth Parameter
# Let's start by tuning the <b>maxDepth</b> parameter. Begin by setting it to a lower value, such as <b>1</b>

# %%
regDT_tuner(1, 32, 1, 0.0)
# Out:
# 1.07931900024
# Test Mean Squared Error = 0.650456393425
# Learned Regression Tree Model: DecisionTreeModel regressor of depth 1 with 3 nodes
#   If (feature 7 <= 2.0)
#    Predict: 0.5831238779174147
#   Else (feature 7 > 2.0)
#    Predict: 0.6239956421081302

# %% [markdown]
# By decreasing the maxDepth parameter, you can see that the run-time slightly decreased, presenting a smaller tree as well. You may also see a slight increase in the error, which is to be expected since the tree is too small to make accurate predictions.

# %% [markdown]
# Now try increasing to value of <b>maxDepth</b> to a large number, such as <b>30</b>, which is the maximum value.

# %%
regDT_tuner(30, 32, 1, 0.0)
# Out:
# 5.37232494354
# Test Mean Squared Error = 1.15386656055
# Learned Regression Tree Model: DecisionTreeModel regressor of depth 30 with 12745 nodes
#   If (feature 7 <= 2.0)
#    If (feature 1 <= 2.0)
#     If (feature 5 <= 2.0)
#      If (feature 9 <= 2.0)
#       Predict: 3.0
#      Else (feature 9 > 2.0)
#       If (feature 3 <= 2.0)
#        If (feature 4 <= 1.0)
#         Predict: 2.0
#        Else (feature 4 > 1.0)
#         Predict: 3.0
#       Else (feature 3 > 2.0)
#        If (feature 3 <= 7.0)
#         If (feature 0 <= 1.0)
#          If (feature 6 <= 2.0)
#           Predict: 1.0
#          Else (feature 6 > 2.0)
#           If (feature 2 <= 1.0)
#            Predict: 1.0
#           Else (feature 2 > 1.0)
#            Predict: 3.0
#         Else (feature 0 > 1.0)
#          Predict: 1.0
#        Else (feature 3 > 7.0)
#         If (feature 3 <= 10.0)
#          If (feature 8 <= 3.0)
#           If (feature 0 <= 2.0)
#            If (feature 5 <= 1.0)
#             If (feature 6 <= 1.0)
#              Predict: 2.0
#             Else (feature 6 > 1.0)
#              Predict: 3.0
#            Else (feature 5 > 1.0)
#             Predict: 1.0
#           Else (feature 0 > 2.0)
#            Predict: 3.0
#          Else (feature 8 > 3.0)
#           Predict: 1.0
#         Else (feature 3 > 10.0)
#          If (feature 4 <= 3.0)
#           Predict: 1.0
#          Else (feature 4 > 3.0)
#           If (feature 6 <= 2.0)
#            Predict: 3.0
#           Else (feature 6 > 2.0)
#            If (feature 0 <= 3.0)
#             Predict: 1.0
#            Else (feature 0 > 3.0)
#             Predict: 2.0
#     Else (feature 5 > 2.0)
#      If (feature 9 <= 2.0)
#       If (feature 3 <= 2.0)
#        If (feature 1 <= 1.0)
#         If (feature 2 <= 1.0)
#          Predict: 2.0
#         Else (feature 2 > 1.0)
#          Predict: 3.0
#        Else (feature 1 > 1.0)
#         Predict: 2.0
#       Else (feature 3 > 2.0)
#        If (feature 8 <= 1.0)
#         If (feature 4 <= 1.0)
#          Predict: 1.0
#         Else (feature 4 > 1.0)
#          If (feature 5 <= 9.0)
#           Predict: 3.0
#          Else (feature 5 > 9.0)
#           Predict: 1.0
#        Else (feature 8 > 1.0)
#         If (feature 5 <= 4.0)
#          If (feature 6 <= 2.0)
#           If (feature 3 <= 6.0)
#            Predict: 1.0
#           Else (feature 3 > 6.0)
#            Predict: 3.0
#          Else (feature 6 > 2.0)
#           Predict: 1.0
#         Else (feature 5 > 4.0)
#          Predict: 1.0
#      Else (feature 9 > 2.0)
#       If (feature 3 <= 5.0)
#        If (feature 9 <= 12.0)
#         If (feature 2 <= 3.0)
#          If (feature 3 <= 2.0)
#           If (feature 4 <= 3.0)
#            Predict: 1.0
#           Else (feature 4 > 3.0)
#            If (feature 5 <= 10.0)
#             Predict: 1.0
#            Else (feature 5 > 10.0)
#             Predict: 3.0
#          Else (feature 3 > 2.0)
#           If (feature 5 <= 9.0)
#            If (feature 9 <= 8.0)
#             If (feature 0 <= 3.0)
#              If (feature 9 <= 7.0)
#               Predict: 1.0
#              Else (feature 9 > 7.0)
#               If (feature 4 <= 2.0)
#                Predict: 1.0
#               Else (feature 4 > 2.0)
#                Predict: 2.0
#             Else (feature 0 > 3.0)
#              If (feature 2 <= 1.0)
#               Predict: 1.0
#              Else (feature 2 > 1.0)
#               Predict: 0.0
#            Else (feature 9 > 8.0)
#             If (feature 5 <= 4.0)
#              Predict: 1.0
#             Else (feature 5 > 4.0)
#              If (feature 0 <= 1.0)
#               If (feature 2 <= 2.0)
#                Predict: 1.0
#               Else (feature 2 > 2.0)
#                Predict: 0.0
#              Else (feature 0 > 1.0)
#               Predict: 0.0
#           Else (feature 5 > 9.0)
#            If (feature 5 <= 10.0)
#             If (feature 2 <= 1.0)
#              If (feature 0 <= 1.0)
#               Predict: 0.0
#              Else (feature 0 > 1.0)
#               Predict: 1.0
#             Else (feature 2 > 1.0)
#              Predict: 0.0
#            Else (feature 5 > 10.0)
#             If (feature 8 <= 1.0)
#              Predict: 0.0
#             Else (feature 8 > 1.0)
#              Predict: 1.0
#         Else (feature 2 > 3.0)
#          If (feature 9 <= 11.0)
#           If (feature 9 <= 4.0)
#            If (feature 6 <= 1.0)
#             Predict: 2.0
#            Else (feature 6 > 1.0)
#             If (feature 0 <= 1.0)
#              Predict: 2.0
#             Else (feature 0 > 1.0)
#              Predict: 1.0
#           Else (feature 9 > 4.0)
#            If (feature 1 <= 1.0)
#             If (feature 0 <= 1.0)
#              Predict: 1.0
#             Else (feature 0 > 1.0)
#              Predict: 2.0
#            Else (feature 1 > 1.0)
#             If (feature 6 <= 1.0)
#              If (feature 3 <= 3.0)
#               Predict: 0.0
#              Else (feature 3 > 3.0)
#               Predict: 1.0
#             Else (feature 6 > 1.0)
#              Predict: 1.0
#          Else (feature 9 > 11.0)
#           If (feature 3 <= 1.0)
#            Predict: 3.0
#           Else (feature 3 > 1.0)
#            If (feature 3 <= 3.0)
#             Predict: 2.0
#            Else (feature 3 > 3.0)
#             Predict: 1.0
#        Else (feature 9 > 12.0)
#         If (feature 0 <= 2.0)
#          Predict: 1.0
#         Else (feature 0 > 2.0)
#          If (feature 5 <= 10.0)
#           Predict: 3.0
#          Else (feature 5 > 10.0)
#           If (feature 0 <= 3.0)
#            Predict: 2.0
#           Else (feature 0 > 3.0)
#            Predict: 1.0
#       Else (feature 3 > 5.0)
#        If (feature 9 <= 4.0)
#         If (feature 8 <= 3.0)
#          If (feature 4 <= 2.0)
#           If (feature 0 <= 1.0)
#            Predict: 0.0
#           Else (feature 0 > 1.0)
#            If (feature 9 <= 3.0)
#             If (feature 0 <= 2.0)
#              Predict: 1.0
#             Else (feature 0 > 2.0)
#              If (feature 5 <= 8.0)
#               Predict: 0.0
#              Else (feature 5 > 8.0)
#               If (feature 5 <= 9.0)
#                Predict: 1.0
#               Else (feature 5 > 9.0)
#                Predict: 0.0
#            Else (feature 9 > 3.0)
#             Predict: 1.0
#          Else (feature 4 > 2.0)
#           If (feature 5 <= 3.0)
#            Predict: 2.0
#           Else (feature 5 > 3.0)
#            If (feature 0 <= 3.0)
#             If (feature 8 <= 2.0)
#              Predict: 1.0
#             Else (feature 8 > 2.0)
#              If (feature 1 <= 1.0)
#               Predict: 1.0
#              Else (feature 1 > 1.0)
#               Predict: 2.0
#            Else (feature 0 > 3.0)
#             If (feature 3 <= 10.0)
#              If (feature 3 <= 8.0)
#               Predict: 1.0
#              Else (feature 3 > 8.0)
#               Predict: 0.0
#             Else (feature 3 > 10.0)
#              Predict: 1.0
#         Else (feature 8 > 3.0)
#          If (feature 7 <= 1.0)
#           Predict: 1.0
#          Else (feature 7 > 1.0)
#           Predict: 0.0
#        Else (feature 9 > 4.0)
#         If (feature 9 <= 7.0)
#          If (feature 7 <= 1.0)
#           If (feature 1 <= 1.0)
#            Predict: 1.0
#           Else (feature 1 > 1.0)
#            If (feature 8 <= 1.0)
#             If (feature 0 <= 2.0)
#              Predict: 0.0
#             Else (feature 0 > 2.0)
#              Predict: 1.0
#            Else (feature 8 > 1.0)
#             Predict: 0.0
#          Else (feature 7 > 1.0)
#           If (feature 1 <= 1.0)
#            If (feature 3 <= 6.0)
#             Predict: 1.0
#            Else (feature 3 > 6.0)
#             If (feature 3 <= 9.0)
#              If (feature 5 <= 8.0)
#               Predict: 0.0
#              Else (feature 5 > 8.0)
#               If (feature 5 <= 9.0)
#                Predict: 1.0
#               Else (feature 5 > 9.0)
#                If (feature 9 <= 5.0)
#                 Predict: 0.0
#                Else (feature 9 > 5.0)
#                 Predict: 1.0
#             Else (feature 3 > 9.0)
#              Predict: 0.0
#           Else (feature 1 > 1.0)
#            If (feature 8 <= 3.0)
#             If (feature 0 <= 3.0)
#              Predict: 1.0
#             Else (feature 0 > 3.0)
#              If (feature 2 <= 2.0)
#               Predict: 1.0
#              Else (feature 2 > 2.0)
#               Predict: 2.0
#            Else (feature 8 > 3.0)
#             Predict: 2.0
#         Else (feature 9 > 7.0)
#          If (feature 6 <= 2.0)
#           If (feature 3 <= 7.0)
#            If (feature 0 <= 3.0)
#             If (feature 5 <= 12.0)
#              If (feature 5 <= 4.0)
#               Predict: 1.0
#              Else (feature 5 > 4.0)
#               If (feature 5 <= 9.0)
#                Predict: 0.0
#               Else (feature 5 > 9.0)
#                If (feature 2 <= 1.0)
#                 Predict: 1.0
#                Else (feature 2 > 1.0)
#                 Predict: 0.0
#             Else (feature 5 > 12.0)
#              Predict: 1.0
#            Else (feature 0 > 3.0)
#             Predict: 1.0
#           Else (feature 3 > 7.0)
#            If (feature 3 <= 9.0)
#             If (feature 5 <= 3.0)
#              Predict: 0.0
#             Else (feature 5 > 3.0)
#              If (feature 9 <= 10.0)
#               If (feature 2 <= 3.0)
#                Predict: 2.0
#               Else (feature 2 > 3.0)
#                If (feature 0 <= 1.0)
#                 Predict: 1.0
#                Else (feature 0 > 1.0)
#                 Predict: 2.0
#              Else (feature 9 > 10.0)
#               Predict: 1.0
#            Else (feature 3 > 9.0)
#             If (feature 8 <= 2.0)
#              If (feature 4 <= 3.0)
#               If (feature 5 <= 7.0)
#                If (feature 9 <= 9.0)
#                 Predict: 0.0
#                Else (feature 9 > 9.0)
#                 If (feature 1 <= 1.0)
#                  Predict: 1.0
#                 Else (feature 1 > 1.0)
#                  If (feature 0 <= 2.0)
#                   Predict: 0.0
#                  Else (feature 0 > 2.0)
#                   Predict: 1.0
#               Else (feature 5 > 7.0)
#                Predict: 0.0
#              Else (feature 4 > 3.0)
#               If (feature 2 <= 1.0)
#                Predict: 2.0
#               Else (feature 2 > 1.0)
#                Predict: 1.0
#             Else (feature 8 > 2.0)
#              If (feature 5 <= 3.0)
#               Predict: 2.0
#              Else (feature 5 > 3.0)
#               Predict: 1.0
#          Else (feature 6 > 2.0)
#           If (feature 3 <= 11.0)
#            If (feature 1 <= 1.0)
#             If (feature 7 <= 1.0)
#              Predict: 1.0
#             Else (feature 7 > 1.0)
#              If (feature 3 <= 9.0)
#               Predict: 0.0
#              Else (feature 3 > 9.0)
#               If (feature 0 <= 3.0)
#                If (feature 2 <= 3.0)
#                 Predict: 1.0
#                Else (feature 2 > 3.0)
#                 Predict: 0.0
#               Else (feature 0 > 3.0)
#                Predict: 0.0
#            Else (feature 1 > 1.0)
#             If (feature 3 <= 8.0)
#              If (feature 7 <= 1.0)
#               If (feature 0 <= 2.0)
#                Predict: 0.0
#               Else (feature 0 > 2.0)
#                Predict: 1.0
#              Else (feature 7 > 1.0)
#               Predict: 1.0
#             Else (feature 3 > 8.0)
#              Predict: 2.0
#           Else (feature 3 > 11.0)
#            If (feature 5 <= 12.0)
#             If (feature 0 <= 3.0)
#              Predict: 0.0
#             Else (feature 0 > 3.0)
#              If (feature 2 <= 1.0)
#               Predict: 0.0
#              Else (feature 2 > 1.0)
#               Predict: 1.0
#            Else (feature 5 > 12.0)
#             Predict: 1.0
#    Else (feature 1 > 2.0)
#     If (feature 5 <= 2.0)
#      If (feature 3 <= 2.0)
#       If (feature 9 <= 2.0)
#        Predict: 2.0
#       Else (feature 9 > 2.0)
#        If (feature 9 <= 7.0)
#         Predict: 1.0
#        Else (feature 9 > 7.0)
#         If (feature 8 <= 3.0)
#          If (feature 0 <= 1.0)
#           If (feature 4 <= 2.0)
#            Predict: 1.0
#           Else (feature 4 > 2.0)
#            If (feature 1 <= 6.0)
#             Predict: 3.0
#            Else (feature 1 > 6.0)
#             Predict: 2.0
#          Else (feature 0 > 1.0)
#           If (feature 6 <= 3.0)
#            Predict: 1.0
#           Else (feature 6 > 3.0)
#            If (feature 1 <= 3.0)
#             Predict: 1.0
#            Else (feature 1 > 3.0)
#             Predict: 2.0
#         Else (feature 8 > 3.0)
#          If (feature 0 <= 2.0)
#           Predict: 1.0
#          Else (feature 0 > 2.0)
#           Predict: 3.0
#      Else (feature 3 > 2.0)
#       If (feature 9 <= 2.0)
#        If (feature 0 <= 1.0)
#         If (feature 1 <= 12.0)
#          If (feature 5 <= 1.0)
#           Predict: 3.0
#          Else (feature 5 > 1.0)
#           Predict: 1.0
#         Else (feature 1 > 12.0)
#          Predict: 3.0
#        Else (feature 0 > 1.0)
#         If (feature 2 <= 1.0)
#          If (feature 5 <= 1.0)
#           Predict: 1.0
#          Else (feature 5 > 1.0)
#           If (feature 0 <= 2.0)
#            Predict: 3.0
#           Else (feature 0 > 2.0)
#            Predict: 1.0
#         Else (feature 2 > 1.0)
#          Predict: 1.0
#       Else (feature 9 > 2.0)
#        If (feature 4 <= 3.0)
#         If (feature 6 <= 3.0)
#          If (feature 3 <= 6.0)
#           If (feature 3 <= 4.0)
#            If (feature 9 <= 3.0)
#             If (feature 0 <= 2.0)
#              Predict: 2.0
#             Else (feature 0 > 2.0)
#              If (feature 1 <= 3.0)
#               Predict: 1.0
#              Else (feature 1 > 3.0)
#               If (feature 1 <= 11.0)
#                Predict: 0.0
#               Else (feature 1 > 11.0)
#                Predict: 1.0
#            Else (feature 9 > 3.0)
#             If (feature 8 <= 1.0)
#              Predict: 0.0
#             Else (feature 8 > 1.0)
#              If (feature 2 <= 3.0)
#               If (feature 1 <= 6.0)
#                If (feature 1 <= 4.0)
#                 Predict: 1.0
#                Else (feature 1 > 4.0)
#                 If (feature 0 <= 1.0)
#                  If (feature 3 <= 3.0)
#                   Predict: 1.0
#                  Else (feature 3 > 3.0)
#                   Predict: 0.0
#                 Else (feature 0 > 1.0)
#                  Predict: 0.0
#               Else (feature 1 > 6.0)
#                If (feature 1 <= 10.0)
#                 Predict: 1.0
#                Else (feature 1 > 10.0)
#                 If (feature 1 <= 11.0)
#                  Predict: 0.0
#                 Else (feature 1 > 11.0)
#                  If (feature 9 <= 5.0)
#                   Predict: 0.0
#                  Else (feature 9 > 5.0)
#                   Predict: 1.0
#              Else (feature 2 > 3.0)
#               If (feature 1 <= 9.0)
#                Predict: 0.0
#               Else (feature 1 > 9.0)
#                If (feature 0 <= 1.0)
#                 Predict: 0.0
#                Else (feature 0 > 1.0)
#                 Predict: 1.0
#           Else (feature 3 > 4.0)
#            If (feature 1 <= 4.0)
#             Predict: 1.0
#            Else (feature 1 > 4.0)
#             If (feature 1 <= 9.0)
#              Predict: 0.0
#             Else (feature 1 > 9.0)
#              If (feature 1 <= 11.0)
#               Predict: 1.0
#              Else (feature 1 > 11.0)
#               Predict: 0.0
#          Else (feature 3 > 6.0)
#           If (feature 1 <= 7.0)
#            If (feature 4 <= 1.0)
#             If (feature 3 <= 8.0)
#              Predict: 0.0
#             Else (feature 3 > 8.0)
#              If (feature 6 <= 1.0)
#               Predict: 0.0
#              Else (feature 6 > 1.0)
#               If (feature 0 <= 2.0)
#                If (feature 1 <= 4.0)
#                 If (feature 1 <= 3.0)
#                  Predict: 1.0
#                 Else (feature 1 > 3.0)
#                  Predict: 2.0
#                Else (feature 1 > 4.0)
#                 Predict: 1.0
#               Else (feature 0 > 2.0)
#                If (feature 8 <= 1.0)
#                 Predict: 0.0
#                Else (feature 8 > 1.0)
#                 Predict: 1.0
#            Else (feature 4 > 1.0)
#             If (feature 0 <= 2.0)
#              If (feature 9 <= 3.0)
#               Predict: 1.0
#              Else (feature 9 > 3.0)
#               Predict: 0.0
#             Else (feature 0 > 2.0)
#              If (feature 3 <= 10.0)
#               If (feature 1 <= 4.0)
#                If (feature 1 <= 3.0)
#                 Predict: 1.0
#                Else (feature 1 > 3.0)
#                 Predict: 2.0
#               Else (feature 1 > 4.0)
#                If (feature 8 <= 2.0)
#                 Predict: 1.0
#                Else (feature 8 > 2.0)
#                 If (feature 9 <= 4.0)
#                  Predict: 1.0
#                 Else (feature 9 > 4.0)
#                  Predict: 0.0
#              Else (feature 3 > 10.0)
#               Predict: 0.0
#           Else (feature 1 > 7.0)
#            If (feature 7 <= 1.0)
#             If (feature 5 <= 1.0)
#              If (feature 3 <= 10.0)
#               If (feature 8 <= 2.0)
#                If (feature 2 <= 2.0)
#                 Predict: 1.0
#                Else (feature 2 > 2.0)
#                 Predict: 2.0
#               Else (feature 8 > 2.0)
#                If (feature 0 <= 2.0)
#                 Predict: 2.0
#                Else (feature 0 > 2.0)
#                 Predict: 1.0
#              Else (feature 3 > 10.0)
#               Predict: 1.0
#             Else (feature 5 > 1.0)
#              If (feature 2 <= 2.0)
#               If (feature 2 <= 1.0)
#                Predict: 0.0
#               Else (feature 2 > 1.0)
#                Predict: 1.0
#              Else (feature 2 > 2.0)
#               Predict: 0.0
#            Else (feature 7 > 1.0)
#             If (feature 5 <= 1.0)
#              If (feature 3 <= 12.0)
#               If (feature 0 <= 3.0)
#                If (feature 1 <= 9.0)
#                 If (feature 4 <= 1.0)
#                  Predict: 1.0
#                 Else (feature 4 > 1.0)
#                  Predict: 0.0
#                Else (feature 1 > 9.0)
#                 Predict: 0.0
#               Else (feature 0 > 3.0)
#                If (feature 1 <= 9.0)
#                 Predict: 0.0
#                Else (feature 1 > 9.0)
#                 Predict: 1.0
#              Else (feature 3 > 12.0)
#               Predict: 1.0
#             Else (feature 5 > 1.0)
#              Predict: 1.0
#         Else (feature 6 > 3.0)
#          If (feature 8 <= 3.0)
#           If (feature 9 <= 3.0)
#            If (feature 3 <= 3.0)
#             If (feature 1 <= 3.0)
#              Predict: 3.0
#             Else (feature 1 > 3.0)
#              Predict: 2.0
#            Else (feature 3 > 3.0)
#             Predict: 1.0
#           Else (feature 9 > 3.0)
#            If (feature 0 <= 3.0)
#             If (feature 3 <= 4.0)
#              Predict: 0.0
#             Else (feature 3 > 4.0)
#              If (feature 9 <= 7.0)
#               If (feature 8 <= 1.0)
#                If (feature 2 <= 2.0)
#                 Predict: 0.0
#                Else (feature 2 > 2.0)
#                 If (feature 0 <= 1.0)
#                  Predict: 1.0
#                 Else (feature 0 > 1.0)
#                  Predict: 0.0
#               Else (feature 8 > 1.0)
#                If (feature 1 <= 8.0)
#                 Predict: 1.0
#                Else (feature 1 > 8.0)
#                 If (feature 1 <= 10.0)
#                  Predict: 0.0
#                 Else (feature 1 > 10.0)
#                  Predict: 1.0
#              Else (feature 9 > 7.0)
#               If (feature 8 <= 2.0)
#                If (feature 9 <= 9.0)
#                 If (feature 2 <= 2.0)
#                  Predict: 1.0
#                 Else (feature 2 > 2.0)
#                  Predict: 2.0
#                Else (feature 9 > 9.0)
#                 Predict: 1.0
#               Else (feature 8 > 2.0)
#                If (feature 5 <= 1.0)
#                 Predict: 1.0
#                Else (feature 5 > 1.0)
#                 If (feature 4 <= 1.0)
#                  Predict: 1.0
#                 Else (feature 4 > 1.0)
#                  Predict: 0.0
#            Else (feature 0 > 3.0)
#             If (feature 1 <= 8.0)
#              If (feature 1 <= 6.0)
#               If (feature 2 <= 2.0)
#                Predict: 1.0
#               Else (feature 2 > 2.0)
#                Predict: 2.0
#              Else (feature 1 > 6.0)
#               If (feature 4 <= 2.0)
#                Predict: 0.0
#               Else (feature 4 > 2.0)
#                Predict: 1.0
#             Else (feature 1 > 8.0)
#              If (feature 1 <= 9.0)
#               Predict: 2.0
#              Else (feature 1 > 9.0)
#               If (feature 2 <= 3.0)
#                Predict: 1.0
#               Else (feature 2 > 3.0)
#                Predict: 2.0
#          Else (feature 8 > 3.0)
#           If (feature 3 <= 5.0)
#            If (feature 2 <= 3.0)
#             If (feature 5 <= 1.0)
#              If (feature 3 <= 3.0)
#               Predict: 0.0
#              Else (feature 3 > 3.0)
#               Predict: 1.0
#             Else (feature 5 > 1.0)
#              Predict: 0.0
#            Else (feature 2 > 3.0)
#             Predict: 0.0
#           Else (feature 3 > 5.0)
#            If (feature 4 <= 1.0)
#             Predict: 1.0
#            Else (feature 4 > 1.0)
#             If (feature 0 <= 3.0)
#              If (feature 2 <= 1.0)
#               Predict: 1.0
#              Else (feature 2 > 1.0)
#               If (feature 1 <= 6.0)
#                Predict: 0.0
#               Else (feature 1 > 6.0)
#                If (feature 0 <= 1.0)
#                 Predict: 0.0
#                Else (feature 0 > 1.0)
#                 Predict: 1.0
#             Else (feature 0 > 3.0)
#              Predict: 1.0
#        Else (feature 4 > 3.0)
#         If (feature 2 <= 3.0)
#          If (feature 6 <= 2.0)
#           If (feature 3 <= 7.0)
#            If (feature 8 <= 2.0)
#             If (feature 3 <= 3.0)
#              Predict: 0.0
#             Else (feature 3 > 3.0)
#              If (feature 1 <= 10.0)
#               Predict: 1.0
#              Else (feature 1 > 10.0)
#               Predict: 0.0
#            Else (feature 8 > 2.0)
#             Predict: 1.0
#           Else (feature 3 > 7.0)
#            If (feature 0 <= 2.0)
#             If (feature 5 <= 1.0)
#              If (feature 7 <= 1.0)
#               Predict: 1.0
#              Else (feature 7 > 1.0)
#               Predict: 0.0
#             Else (feature 5 > 1.0)
#              If (feature 1 <= 11.0)
#               Predict: 1.0
#              Else (feature 1 > 11.0)
#               Predict: 2.0
#            Else (feature 0 > 2.0)
#             If (feature 5 <= 1.0)
#              Predict: 2.0
#             Else (feature 5 > 1.0)
#              If (feature 3 <= 8.0)
#               Predict: 2.0
#              Else (feature 3 > 8.0)
#               Predict: 1.0
#          Else (feature 6 > 2.0)
#           If (feature 3 <= 7.0)
#            If (feature 7 <= 1.0)
#             If (feature 3 <= 4.0)
#              Predict: 1.0
#             Else (feature 3 > 4.0)
#              Predict: 2.0
#            Else (feature 7 > 1.0)
#             If (feature 0 <= 1.0)
#              If (feature 2 <= 1.0)
#               Predict: 0.0
#              Else (feature 2 > 1.0)
#               Predict: 1.0
#             Else (feature 0 > 1.0)
#              Predict: 0.0
#           Else (feature 3 > 7.0)
#            If (feature 8 <= 1.0)
#             If (feature 0 <= 3.0)
#              Predict: 1.0
#             Else (feature 0 > 3.0)
#              Predict: 0.0
#            Else (feature 8 > 1.0)
#             If (feature 7 <= 1.0)
#              Predict: 0.0
#             Else (feature 7 > 1.0)
#              If (feature 2 <= 2.0)
#               If (feature 0 <= 1.0)
#                If (feature 1 <= 4.0)
#                 Predict: 0.0
#                Else (feature 1 > 4.0)
#                 Predict: 1.0
#               Else (feature 0 > 1.0)
#                Predict: 0.0
#              Else (feature 2 > 2.0)
#               Predict: 1.0
#         Else (feature 2 > 3.0)
#          If (feature 3 <= 4.0)
#           If (feature 0 <= 3.0)
#            If (feature 0 <= 1.0)
#             Predict: 2.0
#            Else (feature 0 > 1.0)
#             Predict: 1.0
#           Else (feature 0 > 3.0)
#            Predict: 5.0
#          Else (feature 3 > 4.0)
#           If (feature 6 <= 3.0)
#            If (feature 6 <= 1.0)
#             If (feature 0 <= 1.0)
#              Predict: 1.0
#             Else (feature 0 > 1.0)
#              If (feature 1 <= 6.0)
#               Predict: 1.0
#              Else (feature 1 > 6.0)
#               Predict: 0.0
#            Else (feature 6 > 1.0)
#             Predict: 1.0
#           Else (feature 6 > 3.0)
#            Predict: 0.0
#     Else (feature 5 > 2.0)
#      If (feature 3 <= 2.0)
#       If (feature 9 <= 2.0)
#        If (feature 6 <= 3.0)
#         If (feature 2 <= 1.0)
#          If (feature 7 <= 1.0)
#           If (feature 1 <= 5.0)
#            If (feature 0 <= 2.0)
#             Predict: 1.0
#            Else (feature 0 > 2.0)
#             Predict: 2.0
#           Else (feature 1 > 5.0)
#            Predict: 3.0
#          Else (feature 7 > 1.0)
#           Predict: 1.0
#         Else (feature 2 > 1.0)
#          If (feature 0 <= 3.0)
#           Predict: 1.0
#          Else (feature 0 > 3.0)
#           If (feature 1 <= 8.0)
#            Predict: 2.0
#           Else (feature 1 > 8.0)
#            Predict: 1.0
#        Else (feature 6 > 3.0)
#         If (feature 1 <= 8.0)
#          If (feature 0 <= 1.0)
#           Predict: 3.0
#          Else (feature 0 > 1.0)
#           Predict: 1.0
#         Else (feature 1 > 8.0)
#          Predict: 3.0
#       Else (feature 9 > 2.0)
#        If (feature 8 <= 3.0)
#         If (feature 0 <= 1.0)
#          If (feature 1 <= 4.0)
#           If (feature 9 <= 5.0)
#            If (feature 1 <= 3.0)
#             Predict: 4.0
#            Else (feature 1 > 3.0)
#             Predict: 1.0
#           Else (feature 9 > 5.0)
#            If (feature 5 <= 11.0)
#             If (feature 6 <= 3.0)
#              If (feature 9 <= 11.0)
#               If (feature 1 <= 3.0)
#                If (feature 4 <= 2.0)
#                 Predict: 0.0
#                Else (feature 4 > 2.0)
#                 Predict: 1.0
#               Else (feature 1 > 3.0)
#                Predict: 1.0
#              Else (feature 9 > 11.0)
#               If (feature 5 <= 3.0)
#                Predict: 1.0
#               Else (feature 5 > 3.0)
#                Predict: 0.0
#             Else (feature 6 > 3.0)
#              If (feature 1 <= 3.0)
#               Predict: 1.0
#              Else (feature 1 > 3.0)
#               Predict: 2.0
#            Else (feature 5 > 11.0)
#             Predict: 2.0
#          Else (feature 1 > 4.0)
#           If (feature 8 <= 2.0)
#            If (feature 2 <= 3.0)
#             If (feature 1 <= 7.0)
#              If (feature 9 <= 8.0)
#               If (feature 2 <= 2.0)
#                If (feature 3 <= 1.0)
#                 Predict: 0.0
#                Else (feature 3 > 1.0)
#                 Predict: 1.0
#               Else (feature 2 > 2.0)
#                Predict: 1.0
#              Else (feature 9 > 8.0)
#               Predict: 0.0
#             Else (feature 1 > 7.0)
#              If (feature 4 <= 2.0)
#               Predict: 1.0
#              Else (feature 4 > 2.0)
#               If (feature 6 <= 1.0)
#                Predict: 1.0
#               Else (feature 6 > 1.0)
#                If (feature 1 <= 8.0)
#                 Predict: 1.0
#                Else (feature 1 > 8.0)
#                 Predict: 0.0
#            Else (feature 2 > 3.0)
#             If (feature 3 <= 1.0)
#              Predict: 0.0
#             Else (feature 3 > 1.0)
#              Predict: 1.0
#           Else (feature 8 > 2.0)
#            If (feature 2 <= 3.0)
#             If (feature 5 <= 11.0)
#              If (feature 2 <= 2.0)
#               If (feature 4 <= 1.0)
#                If (feature 1 <= 6.0)
#                 Predict: 0.0
#                Else (feature 1 > 6.0)
#                 Predict: 1.0
#               Else (feature 4 > 1.0)
#                Predict: 1.0
#              Else (feature 2 > 2.0)
#               If (feature 1 <= 9.0)
#                Predict: 0.0
#               Else (feature 1 > 9.0)
#                Predict: 1.0
#             Else (feature 5 > 11.0)
#              Predict: 2.0
#            Else (feature 2 > 3.0)
#             If (feature 4 <= 3.0)
#              Predict: 2.0
#             Else (feature 4 > 3.0)
#              Predict: 1.0
#         Else (feature 0 > 1.0)
#          If (feature 2 <= 1.0)
#           If (feature 6 <= 1.0)
#            If (feature 8 <= 2.0)
#             Predict: 0.0
#            Else (feature 8 > 2.0)
#             Predict: 1.0
#           Else (feature 6 > 1.0)
#            If (feature 1 <= 3.0)
#             Predict: 0.0
#            Else (feature 1 > 3.0)
#             If (feature 9 <= 12.0)
#              If (feature 0 <= 3.0)
#               If (feature 5 <= 12.0)
#                If (feature 7 <= 1.0)
#                 If (feature 8 <= 2.0)
#                  Predict: 1.0
#                 Else (feature 8 > 2.0)
#                  If (feature 1 <= 9.0)
#                   Predict: 0.0
#                  Else (feature 1 > 9.0)
#                   Predict: 1.0
#                Else (feature 7 > 1.0)
#                 If (feature 1 <= 8.0)
#                  Predict: 1.0
#                 Else (feature 1 > 8.0)
#                  If (feature 1 <= 9.0)
#                   Predict: 2.0
#                  Else (feature 1 > 9.0)
#                   Predict: 1.0
#               Else (feature 5 > 12.0)
#                If (feature 6 <= 2.0)
#                 Predict: 1.0
#                Else (feature 6 > 2.0)
#                 Predict: 0.0
#              Else (feature 0 > 3.0)
#               If (feature 7 <= 1.0)
#                If (feature 1 <= 5.0)
#                 Predict: 1.0
#                Else (feature 1 > 5.0)
#                 Predict: 0.0
#               Else (feature 7 > 1.0)
#                Predict: 0.0
#             Else (feature 9 > 12.0)
#              Predict: 2.0
#          Else (feature 2 > 1.0)
#           If (feature 2 <= 2.0)
#            If (feature 9 <= 5.0)
#             If (feature 1 <= 8.0)
#              If (feature 5 <= 4.0)
#               Predict: 2.0
#              Else (feature 5 > 4.0)
#               Predict: 1.0
#             Else (feature 1 > 8.0)
#              Predict: 1.0
#            Else (feature 9 > 5.0)
#             If (feature 9 <= 9.0)
#              If (feature 6 <= 1.0)
#               If (feature 1 <= 3.0)
#                If (feature 0 <= 2.0)
#                 Predict: 1.0
#                Else (feature 0 > 2.0)
#                 Predict: 2.0
#               Else (feature 1 > 3.0)
#                If (feature 1 <= 8.0)
#                 Predict: 0.0
#                Else (feature 1 > 8.0)
#                 Predict: 1.0
#              Else (feature 6 > 1.0)
#               If (feature 1 <= 9.0)
#                Predict: 0.0
#               Else (feature 1 > 9.0)
#                If (feature 8 <= 1.0)
#                 If (feature 1 <= 10.0)
#                  Predict: 1.0
#                 Else (feature 1 > 10.0)
#                  Predict: 0.0
#                Else (feature 8 > 1.0)
#                 Predict: 1.0
#             Else (feature 9 > 9.0)
#              If (feature 5 <= 10.0)
#               If (feature 0 <= 3.0)
#                Predict: 1.0
#               Else (feature 0 > 3.0)
#                If (feature 1 <= 11.0)
#                 Predict: 2.0
#                Else (feature 1 > 11.0)
#                 Predict: 1.0
#              Else (feature 5 > 10.0)
#               Predict: 2.0
#           Else (feature 2 > 2.0)
#            If (feature 9 <= 12.0)
#             If (feature 9 <= 5.0)
#              If (feature 8 <= 1.0)
#               If (feature 1 <= 10.0)
#                Predict: 1.0
#               Else (feature 1 > 10.0)
#                Predict: 0.0
#              Else (feature 8 > 1.0)
#               If (feature 6 <= 2.0)
#                If (feature 5 <= 5.0)
#                 Predict: 0.0
#                Else (feature 5 > 5.0)
#                 Predict: 1.0
#               Else (feature 6 > 2.0)
#                Predict: 0.0
#             Else (feature 9 > 5.0)
#              If (feature 1 <= 4.0)
#               If (feature 3 <= 1.0)
#                If (feature 7 <= 1.0)
#                 Predict: 1.0
#                Else (feature 7 > 1.0)
#                 If (feature 4 <= 3.0)
#                  Predict: 0.0
#                 Else (feature 4 > 3.0)
#                  If (feature 1 <= 3.0)
#                   Predict: 1.0
#                  Else (feature 1 > 3.0)
#                   Predict: 0.0
#               Else (feature 3 > 1.0)
#                If (feature 1 <= 3.0)
#                 If (feature 2 <= 3.0)
#                  Predict: 0.0
#                 Else (feature 2 > 3.0)
#                  Predict: 1.0
#                Else (feature 1 > 3.0)
#                 Predict: 1.0
#              Else (feature 1 > 4.0)
#               If (feature 1 <= 5.0)
#                Predict: 2.0
#               Else (feature 1 > 5.0)
#                If (feature 7 <= 1.0)
#                 If (feature 3 <= 1.0)
#                  If (feature 1 <= 11.0)
#                   Predict: 1.0
#                  Else (feature 1 > 11.0)
#                   If (feature 0 <= 2.0)
#                    Predict: 2.0
#                   Else (feature 0 > 2.0)
#                    Predict: 1.0
#                 Else (feature 3 > 1.0)
#                  If (feature 4 <= 2.0)
#                   Predict: 0.0
#                  Else (feature 4 > 2.0)
#                   If (feature 0 <= 3.0)
#                    Predict: 0.0
#                   Else (feature 0 > 3.0)
#                    Predict: 1.0
#                Else (feature 7 > 1.0)
#                 If (feature 3 <= 1.0)
#                  If (feature 6 <= 2.0)
#                   Predict: 0.0
#                  Else (feature 6 > 2.0)
#                   If (feature 8 <= 2.0)
#                    Predict: 1.0
#                   Else (feature 8 > 2.0)
#                    Predict: 0.0
#                 Else (feature 3 > 1.0)
#                  If (feature 0 <= 3.0)
#                   If (feature 1 <= 8.0)
#                    Predict: 1.0
#                   Else (feature 1 > 8.0)
#                    If (feature 1 <= 10.0)
#                     If (feature 5 <= 3.0)
#                      Predict: 1.0
#                     Else (feature 5 > 3.0)
#                      Predict: 2.0
#                    Else (feature 1 > 10.0)
#                     Predict: 1.0
#                  Else (feature 0 > 3.0)
#                   If (feature 4 <= 3.0)
#                    Predict: 2.0
#                   Else (feature 4 > 3.0)
#                    Predict: 1.0
#            Else (feature 9 > 12.0)
#             If (feature 5 <= 5.0)
#              If (feature 1 <= 6.0)
#               If (feature 1 <= 4.0)
#                If (feature 2 <= 3.0)
#                 Predict: 0.0
#                Else (feature 2 > 3.0)
#                 Predict: 1.0
#               Else (feature 1 > 4.0)
#                Predict: 0.0
#              Else (feature 1 > 6.0)
#               Predict: 1.0
#             Else (feature 5 > 5.0)
#              Predict: 0.0
#        Else (feature 8 > 3.0)
#         If (feature 9 <= 5.0)
#          If (feature 5 <= 5.0)
#           If (feature 1 <= 11.0)
#            Predict: 1.0
#           Else (feature 1 > 11.0)
#            Predict: 0.0
#          Else (feature 5 > 5.0)
#           If (feature 1 <= 3.0)
#            If (feature 0 <= 3.0)
#             Predict: 1.0
#            Else (feature 0 > 3.0)
#             Predict: 0.0
#           Else (feature 1 > 3.0)
#            Predict: 0.0
#         Else (feature 9 > 5.0)
#          If (feature 1 <= 7.0)
#           If (feature 5 <= 10.0)
#            If (feature 4 <= 1.0)
#             If (feature 7 <= 1.0)
#              Predict: 1.0
#             Else (feature 7 > 1.0)
#              If (feature 1 <= 3.0)
#               Predict: 1.0
#              Else (feature 1 > 3.0)
#               Predict: 0.0
#            Else (feature 4 > 1.0)
#             If (feature 0 <= 3.0)
#              Predict: 0.0
#             Else (feature 0 > 3.0)
#              If (feature 1 <= 6.0)
#               Predict: 1.0
#              Else (feature 1 > 6.0)
#               Predict: 0.0
#           Else (feature 5 > 10.0)
#            If (feature 5 <= 12.0)
#             Predict: 1.0
#            Else (feature 5 > 12.0)
#             Predict: 0.0
#          Else (feature 1 > 7.0)
#           If (feature 2 <= 3.0)
#            If (feature 1 <= 12.0)
#             If (feature 3 <= 1.0)
#              If (feature 7 <= 1.0)
#               Predict: 1.0
#              Else (feature 7 > 1.0)
#               If (feature 2 <= 2.0)
#                Predict: 0.0
#               Else (feature 2 > 2.0)
#                Predict: 1.0
#             Else (feature 3 > 1.0)
#              If (feature 7 <= 1.0)
#               If (feature 6 <= 2.0)
#                Predict: 0.0
#               Else (feature 6 > 2.0)
#                Predict: 1.0
#              Else (feature 7 > 1.0)
#               If (feature 9 <= 9.0)
#                Predict: 1.0
#               Else (feature 9 > 9.0)
#                Predict: 2.0
#            Else (feature 1 > 12.0)
#             If (feature 5 <= 6.0)
#              Predict: 2.0
#             Else (feature 5 > 6.0)
#              Predict: 1.0
#           Else (feature 2 > 3.0)
#            If (feature 7 <= 1.0)
#             If (feature 3 <= 1.0)
#              Predict: 1.0
#             Else (feature 3 > 1.0)
#              Predict: 0.0
#            Else (feature 7 > 1.0)
#             If (feature 3 <= 1.0)
#              Predict: 0.0
#             Else (feature 3 > 1.0)
#              Predict: 1.0
#      Else (feature 3 > 2.0)
#       If (feature 9 <= 2.0)
#        If (feature 5 <= 4.0)
#         If (feature 1 <= 4.0)
#          If (feature 4 <= 1.0)
#           If (feature 0 <= 1.0)
#            Predict: 5.0
#           Else (feature 0 > 1.0)
#            Predict: 6.0
#          Else (feature 4 > 1.0)
#           If (feature 3 <= 4.0)
#            Predict: 3.0
#           Else (feature 3 > 4.0)
#            If (feature 8 <= 3.0)
#             If (feature 3 <= 12.0)
#              Predict: 0.0
#             Else (feature 3 > 12.0)
#              Predict: 1.0
#            Else (feature 8 > 3.0)
#             If (feature 0 <= 1.0)
#              Predict: 2.0
#             Else (feature 0 > 1.0)
#              Predict: 1.0
#         Else (feature 1 > 4.0)
#          If (feature 7 <= 1.0)
#           If (feature 9 <= 1.0)
#            If (feature 3 <= 4.0)
#             Predict: 2.0
#            Else (feature 3 > 4.0)
#             Predict: 1.0
#           Else (feature 9 > 1.0)
#            If (feature 8 <= 2.0)
#             If (feature 0 <= 1.0)
#              Predict: 0.0
#             Else (feature 0 > 1.0)
#              Predict: 1.0
#            Else (feature 8 > 2.0)
#             Predict: 0.0
#          Else (feature 7 > 1.0)
#           If (feature 9 <= 1.0)
#            Predict: 0.0
#           Else (feature 9 > 1.0)
#            If (feature 3 <= 4.0)
#             If (feature 0 <= 1.0)
#              Predict: 2.0
#             Else (feature 0 > 1.0)
#              Predict: 1.0
#            Else (feature 3 > 4.0)
#             Predict: 1.0
#        Else (feature 5 > 4.0)
#         If (feature 3 <= 5.0)
#          If (feature 4 <= 1.0)
#           If (feature 3 <= 4.0)
#            If (feature 5 <= 12.0)
#             If (feature 0 <= 2.0)
#              Predict: 1.0
#             Else (feature 0 > 2.0)
#              If (feature 2 <= 1.0)
#               Predict: 1.0
#              Else (feature 2 > 1.0)
#               If (feature 5 <= 5.0)
#                Predict: 1.0
#               Else (feature 5 > 5.0)
#                Predict: 0.0
#            Else (feature 5 > 12.0)
#             Predict: 0.0
#           Else (feature 3 > 4.0)
#            Predict: 0.0
#          Else (feature 4 > 1.0)
#           If (feature 1 <= 3.0)
#            Predict: 1.0
#           Else (feature 1 > 3.0)
#            If (feature 1 <= 8.0)
#             If (feature 1 <= 5.0)
#              If (feature 4 <= 3.0)
#               Predict: 0.0
#              Else (feature 4 > 3.0)
#               Predict: 1.0
#             Else (feature 1 > 5.0)
#              Predict: 0.0
#            Else (feature 1 > 8.0)
#             If (feature 9 <= 1.0)
#              If (feature 7 <= 1.0)
#               Predict: 1.0
#              Else (feature 7 > 1.0)
#               Predict: 0.0
#             Else (feature 9 > 1.0)
#              If (feature 7 <= 1.0)
#               Predict: 0.0
#              Else (feature 7 > 1.0)
#               If (feature 0 <= 1.0)
#                Predict: 1.0
#               Else (feature 0 > 1.0)
#                Predict: 2.0
#         Else (feature 3 > 5.0)
#          If (feature 7 <= 1.0)
#           If (feature 9 <= 1.0)
#            If (feature 0 <= 3.0)
#             If (feature 6 <= 1.0)
#              If (feature 1 <= 5.0)
#               Predict: 1.0
#              Else (feature 1 > 5.0)
#               If (feature 3 <= 10.0)
#                Predict: 2.0
#               Else (feature 3 > 10.0)
#                Predict: 1.0
#             Else (feature 6 > 1.0)
#              If (feature 2 <= 3.0)
#               Predict: 1.0
#              Else (feature 2 > 3.0)
#               If (feature 0 <= 1.0)
#                Predict: 2.0
#               Else (feature 0 > 1.0)
#                Predict: 1.0
#            Else (feature 0 > 3.0)
#             If (feature 3 <= 7.0)
#              Predict: 2.0
#             Else (feature 3 > 7.0)
#              Predict: 1.0
#           Else (feature 9 > 1.0)
#            If (feature 3 <= 9.0)
#             If (feature 2 <= 3.0)
#              If (feature 0 <= 2.0)
#               Predict: 0.0
#              Else (feature 0 > 2.0)
#               If (feature 3 <= 8.0)
#                If (feature 1 <= 8.0)
#                 Predict: 0.0
#                Else (feature 1 > 8.0)
#                 If (feature 1 <= 9.0)
#                  Predict: 1.0
#                 Else (feature 1 > 9.0)
#                  Predict: 0.0
#               Else (feature 3 > 8.0)
#                Predict: 1.0
#             Else (feature 2 > 3.0)
#              If (feature 1 <= 4.0)
#               Predict: 0.0
#              Else (feature 1 > 4.0)
#               Predict: 1.0
#            Else (feature 3 > 9.0)
#             If (feature 6 <= 2.0)
#              If (feature 3 <= 10.0)
#               If (feature 0 <= 2.0)
#                Predict: 3.0
#               Else (feature 0 > 2.0)
#                Predict: 1.0
#              Else (feature 3 > 10.0)
#               If (feature 8 <= 2.0)
#                If (feature 5 <= 5.0)
#                 Predict: 0.0
#                Else (feature 5 > 5.0)
#                 Predict: 1.0
#               Else (feature 8 > 2.0)
#                If (feature 5 <= 7.0)
#                 Predict: 1.0
#                Else (feature 5 > 7.0)
#                 Predict: 0.0
#             Else (feature 6 > 2.0)
#              If (feature 3 <= 11.0)
#               Predict: 0.0
#              Else (feature 3 > 11.0)
#               If (feature 0 <= 2.0)
#                Predict: 1.0
#               Else (feature 0 > 2.0)
#                Predict: 0.0
#          Else (feature 7 > 1.0)
#           If (feature 9 <= 1.0)
#            If (feature 3 <= 8.0)
#             If (feature 1 <= 3.0)
#              If (feature 3 <= 6.0)
#               Predict: 1.0
#              Else (feature 3 > 6.0)
#               Predict: 0.0
#             Else (feature 1 > 3.0)
#              Predict: 0.0
#            Else (feature 3 > 8.0)
#             If (feature 5 <= 8.0)
#              If (feature 2 <= 1.0)
#               If (feature 8 <= 1.0)
#                Predict: 0.0
#               Else (feature 8 > 1.0)
#                If (feature 0 <= 1.0)
#                 Predict: 0.0
#                Else (feature 0 > 1.0)
#                 Predict: 1.0
#              Else (feature 2 > 1.0)
#               Predict: 0.0
#             Else (feature 5 > 8.0)
#              If (feature 3 <= 12.0)
#               If (feature 3 <= 10.0)
#                If (feature 4 <= 1.0)
#                 Predict: 1.0
#                Else (feature 4 > 1.0)
#                 If (feature 1 <= 11.0)
#                  Predict: 0.0
#                 Else (feature 1 > 11.0)
#                  Predict: 1.0
#               Else (feature 3 > 10.0)
#                Predict: 1.0
#              Else (feature 3 > 12.0)
#               Predict: 0.0
#           Else (feature 9 > 1.0)
#            If (feature 3 <= 12.0)
#             Predict: 1.0
#            Else (feature 3 > 12.0)
#             If (feature 1 <= 7.0)
#              Predict: 2.0
#             Else (feature 1 > 7.0)
#              Predict: 1.0
#       Else (feature 9 > 2.0)
#        If (feature 9 <= 12.0)
#         If (feature 6 <= 1.0)
#          If (feature 9 <= 11.0)
#           If (feature 9 <= 9.0)
#            If (feature 1 <= 4.0)
#             If (feature 9 <= 4.0)
#              If (feature 0 <= 3.0)
#               If (feature 2 <= 1.0)
#                If (feature 0 <= 2.0)
#                 Predict: 1.0
#                Else (feature 0 > 2.0)
#                 Predict: 3.0
#               Else (feature 2 > 1.0)
#                Predict: 1.0
#              Else (feature 0 > 3.0)
#               Predict: 3.0
#             Else (feature 9 > 4.0)
#              If (feature 5 <= 9.0)
#               If (feature 3 <= 7.0)
#                Predict: 1.0
#               Else (feature 3 > 7.0)
#                If (feature 5 <= 5.0)
#                 Predict: 0.0
#                Else (feature 5 > 5.0)
#                 Predict: 1.0
#              Else (feature 5 > 9.0)
#               If (feature 3 <= 12.0)
#                If (feature 3 <= 7.0)
#                 If (feature 2 <= 2.0)
#                  If (feature 5 <= 11.0)
#                   Predict: 0.0
#                  Else (feature 5 > 11.0)
#                   Predict: 1.0
#                 Else (feature 2 > 2.0)
#                  Predict: 1.0
#                Else (feature 3 > 7.0)
#                 Predict: 0.0
#               Else (feature 3 > 12.0)
#                Predict: 1.0
#            Else (feature 1 > 4.0)
#             If (feature 4 <= 2.0)
#              If (feature 0 <= 1.0)
#               If (feature 8 <= 1.0)
#                If (feature 2 <= 1.0)
#                 Predict: 0.0
#                Else (feature 2 > 1.0)
#                 Predict: 3.0
#               Else (feature 8 > 1.0)
#                If (feature 5 <= 12.0)
#                 If (feature 2 <= 3.0)
#                  Predict: 0.0
#                 Else (feature 2 > 3.0)
#                  If (feature 3 <= 5.0)
#                   Predict: 1.0
#                  Else (feature 3 > 5.0)
#                   Predict: 0.0
#                Else (feature 5 > 12.0)
#                 If (feature 7 <= 1.0)
#                  Predict: 1.0
#                 Else (feature 7 > 1.0)
#                  Predict: 0.0
#              Else (feature 0 > 1.0)
#               If (feature 5 <= 11.0)
#                If (feature 5 <= 7.0)
#                 If (feature 0 <= 3.0)
#                  If (feature 8 <= 3.0)
#                   If (feature 7 <= 1.0)
#                    If (feature 0 <= 2.0)
#                     Predict: 0.0
#                    Else (feature 0 > 2.0)
#                     If (feature 3 <= 6.0)
#                      If (feature 3 <= 3.0)
#                       Predict: 1.0
#                      Else (feature 3 > 3.0)
#                       Predict: 0.0
#                     Else (feature 3 > 6.0)
#                      Predict: 1.0
#                   Else (feature 7 > 1.0)
#                    If (feature 3 <= 4.0)
#                     If (feature 1 <= 6.0)
#                      Predict: 1.0
#                     Else (feature 1 > 6.0)
#                      Predict: 0.0
#                    Else (feature 3 > 4.0)
#                     Predict: 1.0
#                  Else (feature 8 > 3.0)
#                   If (feature 0 <= 2.0)
#                    Predict: 1.0
#                   Else (feature 0 > 2.0)
#                    Predict: 3.0
#                 Else (feature 0 > 3.0)
#                  If (feature 3 <= 5.0)
#                   If (feature 5 <= 5.0)
#                    Predict: 1.0
#                   Else (feature 5 > 5.0)
#                    Predict: 0.0
#                  Else (feature 3 > 5.0)
#                   Predict: 0.0
#                Else (feature 5 > 7.0)
#                 If (feature 4 <= 1.0)
#                  If (feature 1 <= 11.0)
#                   If (feature 3 <= 9.0)
#                    If (feature 1 <= 7.0)
#                     Predict: 0.0
#                    Else (feature 1 > 7.0)
#                     If (feature 0 <= 2.0)
#                      Predict: 0.0
#                     Else (feature 0 > 2.0)
#                      If (feature 8 <= 2.0)
#                       Predict: 1.0
#                      Else (feature 8 > 2.0)
#                       If (feature 1 <= 8.0)
#                        Predict: 1.0
#                       Else (feature 1 > 8.0)
#                        Predict: 0.0
#                   Else (feature 3 > 9.0)
#                    Predict: 1.0
#                  Else (feature 1 > 11.0)
#                   If (feature 3 <= 3.0)
#                    Predict: 1.0
#                   Else (feature 3 > 3.0)
#                    Predict: 0.0
#                 Else (feature 4 > 1.0)
#                  Predict: 0.0
#               Else (feature 5 > 11.0)
#                If (feature 1 <= 11.0)
#                 If (feature 9 <= 7.0)
#                  If (feature 8 <= 3.0)
#                   Predict: 0.0
#                  Else (feature 8 > 3.0)
# ...
#                      If (feature 1 <= 7.0)
#                       If (feature 1 <= 5.0)
#                        Predict: 1.0
#                       Else (feature 1 > 5.0)
#                        Predict: 0.0
#                      Else (feature 1 > 7.0)
#                       Predict: 1.0
#                     Else (feature 3 > 10.0)
#                      If (feature 0 <= 1.0)
#                       Predict: 1.0
#                      Else (feature 0 > 1.0)
#                       Predict: 0.0
#                    Else (feature 5 > 6.0)
#                     If (feature 9 <= 12.0)
#                      If (feature 7 <= 6.0)
#                       Predict: 0.0
#                      Else (feature 7 > 6.0)
#                       If (feature 2 <= 2.0)
#                        If (feature 8 <= 3.0)
#                         Predict: 1.0
#                        Else (feature 8 > 3.0)
#                         If (feature 0 <= 1.0)
#                          Predict: 1.0
#                         Else (feature 0 > 1.0)
#                          If (feature 3 <= 9.0)
#                           Predict: 1.0
#                          Else (feature 3 > 9.0)
#                           Predict: 0.0
#                       Else (feature 2 > 2.0)
#                        If (feature 5 <= 7.0)
#                         If (feature 1 <= 7.0)
#                          If (feature 3 <= 10.0)
#                           Predict: 2.0
#                          Else (feature 3 > 10.0)
#                           Predict: 1.0
#                         Else (feature 1 > 7.0)
#                          Predict: 2.0
#                        Else (feature 5 > 7.0)
#                         Predict: 1.0
#                     Else (feature 9 > 12.0)
#                      Predict: 2.0
#                   Else (feature 1 > 12.0)
#                    Predict: 0.0
#                  Else (feature 5 > 8.0)
#                   If (feature 1 <= 8.0)
#                    If (feature 5 <= 9.0)
#                     If (feature 3 <= 10.0)
#                      If (feature 0 <= 1.0)
#                       If (feature 1 <= 7.0)
#                        Predict: 3.0
#                       Else (feature 1 > 7.0)
#                        Predict: 2.0
#                      Else (feature 0 > 1.0)
#                       Predict: 1.0
#                     Else (feature 3 > 10.0)
#                      Predict: 0.0
#                    Else (feature 5 > 9.0)
#                     If (feature 8 <= 1.0)
#                      Predict: 0.0
#                     Else (feature 8 > 1.0)
#                      If (feature 2 <= 3.0)
#                       If (feature 1 <= 6.0)
#                        Predict: 1.0
#                       Else (feature 1 > 6.0)
#                        If (feature 1 <= 7.0)
#                         If (feature 0 <= 1.0)
#                          Predict: 0.0
#                         Else (feature 0 > 1.0)
#                          Predict: 1.0
#                        Else (feature 1 > 7.0)
#                         Predict: 1.0
#                      Else (feature 2 > 3.0)
#                       If (feature 4 <= 2.0)
#                        If (feature 0 <= 1.0)
#                         Predict: 2.0
#                        Else (feature 0 > 1.0)
#                         Predict: 3.0
#                       Else (feature 4 > 2.0)
#                        If (feature 4 <= 3.0)
#                         Predict: 1.0
#                        Else (feature 4 > 3.0)
#                         Predict: 0.0
#                   Else (feature 1 > 8.0)
#                    If (feature 4 <= 2.0)
#                     If (feature 7 <= 8.0)
#                      If (feature 1 <= 11.0)
#                       If (feature 0 <= 1.0)
#                        Predict: 3.0
#                       Else (feature 0 > 1.0)
#                        Predict: 2.0
#                      Else (feature 1 > 11.0)
#                       Predict: 1.0
#                     Else (feature 7 > 8.0)
#                      If (feature 0 <= 1.0)
#                       If (feature 1 <= 10.0)
#                        Predict: 3.0
#                       Else (feature 1 > 10.0)
#                        Predict: 2.0
#                      Else (feature 0 > 1.0)
#                       Predict: 4.0
#                    Else (feature 4 > 2.0)
#                     If (feature 1 <= 9.0)
#                      Predict: 3.0
#                     Else (feature 1 > 9.0)
#                      If (feature 3 <= 8.0)
#                       Predict: 0.0
#                      Else (feature 3 > 8.0)
#                       If (feature 7 <= 7.0)
#                        If (feature 0 <= 1.0)
#                         Predict: 1.0
#                        Else (feature 0 > 1.0)
#                         Predict: 0.0
#                       Else (feature 7 > 7.0)
#                        If (feature 1 <= 11.0)
#                         Predict: 1.0
#                        Else (feature 1 > 11.0)
#                         If (feature 3 <= 9.0)
#                          Predict: 1.0
#                         Else (feature 3 > 9.0)
#                          Predict: 2.0
#                 Else (feature 3 > 12.0)
#                  If (feature 2 <= 2.0)
#                   If (feature 7 <= 9.0)
#                    Predict: 0.0
#                   Else (feature 7 > 9.0)
#                    If (feature 0 <= 1.0)
#                     Predict: 0.0
#                    Else (feature 0 > 1.0)
#                     Predict: 1.0
#                  Else (feature 2 > 2.0)
#                   If (feature 0 <= 1.0)
#                    If (feature 1 <= 9.0)
#                     If (feature 1 <= 5.0)
#                      Predict: 1.0
#                     Else (feature 1 > 5.0)
#                      Predict: 0.0
#                    Else (feature 1 > 9.0)
#                     Predict: 1.0
#                   Else (feature 0 > 1.0)
#                    Predict: 1.0
#              Else (feature 0 > 2.0)
#               If (feature 1 <= 7.0)
#                If (feature 3 <= 7.0)
#                 If (feature 1 <= 6.0)
#                  If (feature 4 <= 1.0)
#                   If (feature 7 <= 7.0)
#                    Predict: 3.0
#                   Else (feature 7 > 7.0)
#                    Predict: 2.0
#                  Else (feature 4 > 1.0)
#                   If (feature 7 <= 12.0)
#                    If (feature 1 <= 5.0)
#                     Predict: 1.0
#                    Else (feature 1 > 5.0)
#                     If (feature 4 <= 3.0)
#                      Predict: 0.0
#                     Else (feature 4 > 3.0)
#                      Predict: 1.0
#                   Else (feature 7 > 12.0)
#                    Predict: 0.0
#                 Else (feature 1 > 6.0)
#                  If (feature 4 <= 2.0)
#                   Predict: 2.0
#                  Else (feature 4 > 2.0)
#                   Predict: 3.0
#                Else (feature 3 > 7.0)
#                 If (feature 4 <= 3.0)
#                  If (feature 2 <= 2.0)
#                   If (feature 1 <= 5.0)
#                    If (feature 5 <= 10.0)
#                     If (feature 5 <= 6.0)
#                      Predict: 0.0
#                     Else (feature 5 > 6.0)
#                      Predict: 1.0
#                    Else (feature 5 > 10.0)
#                     Predict: 0.0
#                   Else (feature 1 > 5.0)
#                    If (feature 2 <= 1.0)
#                     If (feature 7 <= 11.0)
#                      Predict: 1.0
#                     Else (feature 7 > 11.0)
#                      Predict: 2.0
#                    Else (feature 2 > 1.0)
#                     If (feature 3 <= 10.0)
#                      If (feature 3 <= 8.0)
#                       Predict: 1.0
#                      Else (feature 3 > 8.0)
#                       Predict: 0.0
#                     Else (feature 3 > 10.0)
#                      Predict: 1.0
#                  Else (feature 2 > 2.0)
#                   If (feature 7 <= 10.0)
#                    If (feature 5 <= 7.0)
#                     Predict: 1.0
#                    Else (feature 5 > 7.0)
#                     Predict: 0.0
#                   Else (feature 7 > 10.0)
#                    If (feature 7 <= 11.0)
#                     If (feature 0 <= 3.0)
#                      Predict: 3.0
#                     Else (feature 0 > 3.0)
#                      Predict: 2.0
#                    Else (feature 7 > 11.0)
#                     If (feature 9 <= 11.0)
#                      Predict: 1.0
#                     Else (feature 9 > 11.0)
#                      Predict: 2.0
#                 Else (feature 4 > 3.0)
#                  If (feature 0 <= 3.0)
#                   Predict: 0.0
#                  Else (feature 0 > 3.0)
#                   If (feature 2 <= 3.0)
#                    Predict: 1.0
#                   Else (feature 2 > 3.0)
#                    Predict: 0.0
#               Else (feature 1 > 7.0)
#                If (feature 3 <= 12.0)
#                 If (feature 9 <= 10.0)
#                  If (feature 3 <= 11.0)
#                   If (feature 9 <= 7.0)
#                    If (feature 3 <= 6.0)
#                     If (feature 1 <= 11.0)
#                      Predict: 2.0
#                     Else (feature 1 > 11.0)
#                      Predict: 1.0
#                    Else (feature 3 > 6.0)
#                     If (feature 8 <= 1.0)
#                      If (feature 1 <= 9.0)
#                       Predict: 1.0
#                      Else (feature 1 > 9.0)
#                       Predict: 2.0
#                     Else (feature 8 > 1.0)
#                      If (feature 0 <= 3.0)
#                       If (feature 9 <= 6.0)
#                        Predict: 1.0
#                       Else (feature 9 > 6.0)
#                        If (feature 1 <= 9.0)
#                         Predict: 1.0
#                        Else (feature 1 > 9.0)
#                         Predict: 0.0
#                      Else (feature 0 > 3.0)
#                       If (feature 1 <= 10.0)
#                        If (feature 1 <= 9.0)
#                         Predict: 0.0
#                        Else (feature 1 > 9.0)
#                         Predict: 1.0
#                       Else (feature 1 > 10.0)
#                        Predict: 0.0
#                   Else (feature 9 > 7.0)
#                    If (feature 5 <= 7.0)
#                     If (feature 8 <= 3.0)
#                      If (feature 1 <= 11.0)
#                       Predict: 1.0
#                      Else (feature 1 > 11.0)
#                       If (feature 1 <= 12.0)
#                        Predict: 2.0
#                       Else (feature 1 > 12.0)
#                        Predict: 1.0
#                     Else (feature 8 > 3.0)
#                      Predict: 0.0
#                    Else (feature 5 > 7.0)
#                     If (feature 8 <= 3.0)
#                      If (feature 7 <= 11.0)
#                       If (feature 7 <= 8.0)
#                        If (feature 4 <= 3.0)
#                         If (feature 5 <= 12.0)
#                          Predict: 1.0
#                         Else (feature 5 > 12.0)
#                          Predict: 2.0
#                        Else (feature 4 > 3.0)
#                         Predict: 1.0
#                       Else (feature 7 > 8.0)
#                        If (feature 2 <= 2.0)
#                         Predict: 3.0
#                        Else (feature 2 > 2.0)
#                         If (feature 0 <= 3.0)
#                          If (feature 1 <= 10.0)
#                           Predict: 2.0
#                          Else (feature 1 > 10.0)
#                           Predict: 3.0
#                         Else (feature 0 > 3.0)
#                          Predict: 1.0
#                      Else (feature 7 > 11.0)
#                       Predict: 1.0
#                     Else (feature 8 > 3.0)
#                      If (feature 0 <= 3.0)
#                       Predict: 4.0
#                      Else (feature 0 > 3.0)
#                       Predict: 2.0
#                  Else (feature 3 > 11.0)
#                   If (feature 2 <= 3.0)
#                    If (feature 9 <= 6.0)
#                     If (feature 1 <= 12.0)
#                      Predict: 3.0
#                     Else (feature 1 > 12.0)
#                      Predict: 1.0
#                    Else (feature 9 > 6.0)
#                     If (feature 0 <= 3.0)
#                      Predict: 2.0
#                     Else (feature 0 > 3.0)
#                      If (feature 7 <= 9.0)
#                       If (feature 1 <= 9.0)
#                        Predict: 1.0
#                       Else (feature 1 > 9.0)
#                        If (feature 1 <= 10.0)
#                         Predict: 0.0
#                        Else (feature 1 > 10.0)
#                         If (feature 1 <= 12.0)
#                          Predict: 1.0
#                         Else (feature 1 > 12.0)
#                          Predict: 0.0
#                      Else (feature 7 > 9.0)
#                       Predict: 2.0
#                   Else (feature 2 > 3.0)
#                    Predict: 5.0
#                 Else (feature 9 > 10.0)
#                  If (feature 7 <= 11.0)
#                   If (feature 4 <= 3.0)
#                    If (feature 7 <= 9.0)
#                     If (feature 9 <= 12.0)
#                      If (feature 1 <= 8.0)
#                       Predict: 0.0
#                      Else (feature 1 > 8.0)
#                       If (feature 5 <= 8.0)
#                        If (feature 5 <= 7.0)
#                         Predict: 1.0
#                        Else (feature 5 > 7.0)
#                         Predict: 0.0
#                       Else (feature 5 > 8.0)
#                        If (feature 7 <= 6.0)
#                         Predict: 0.0
#                        Else (feature 7 > 6.0)
#                         Predict: 1.0
#                     Else (feature 9 > 12.0)
#                      If (feature 4 <= 1.0)
#                       Predict: 1.0
#                      Else (feature 4 > 1.0)
#                       Predict: 0.0
#                    Else (feature 7 > 9.0)
#                     If (feature 3 <= 10.0)
#                      If (feature 0 <= 3.0)
#                       Predict: 1.0
#                      Else (feature 0 > 3.0)
#                       If (feature 3 <= 9.0)
#                        Predict: 0.0
#                       Else (feature 3 > 9.0)
#                        Predict: 1.0
#                     Else (feature 3 > 10.0)
#                      If (feature 1 <= 11.0)
#                       Predict: 1.0
#                      Else (feature 1 > 11.0)
#                       Predict: 2.0
#                   Else (feature 4 > 3.0)
#                    If (feature 2 <= 3.0)
#                     If (feature 2 <= 2.0)
#                      If (feature 5 <= 6.0)
#                       Predict: 0.0
#                      Else (feature 5 > 6.0)
#                       If (feature 3 <= 9.0)
#                        Predict: 1.0
#                       Else (feature 3 > 9.0)
#                        Predict: 2.0
#                     Else (feature 2 > 2.0)
#                      Predict: 0.0
#                    Else (feature 2 > 3.0)
#                     Predict: 5.0
#                  Else (feature 7 > 11.0)
#                   If (feature 2 <= 3.0)
#                    If (feature 1 <= 9.0)
#                     Predict: 2.0
#                    Else (feature 1 > 9.0)
#                     If (feature 2 <= 2.0)
#                      Predict: 1.0
#                     Else (feature 2 > 2.0)
#                      Predict: 2.0
#                   Else (feature 2 > 3.0)
#                    If (feature 3 <= 11.0)
#                     Predict: 1.0
#                    Else (feature 3 > 11.0)
#                     Predict: 0.0
#                Else (feature 3 > 12.0)
#                 If (feature 7 <= 11.0)
#                  If (feature 5 <= 9.0)
#                   If (feature 1 <= 8.0)
#                    Predict: 2.0
#                   Else (feature 1 > 8.0)
#                    Predict: 1.0
#                  Else (feature 5 > 9.0)
#                   If (feature 0 <= 3.0)
#                    If (feature 1 <= 11.0)
#                     Predict: 3.0
#                    Else (feature 1 > 11.0)
#                     Predict: 2.0
#                   Else (feature 0 > 3.0)
#                    Predict: 2.0
#                 Else (feature 7 > 11.0)
#                  Predict: 4.0

# %% [markdown]
# With a large value for maxDepth, you can see that the run-time increased greatly, along with the size of the tree. The MSE has increased greatly compared to the original, which is due to overfitting of the training data from having a deep tree.

# %% [markdown]
# ### maxBins Parameter
# Now let's tune the <b>maxBins</b> variable. Start by decreasing the value to 2, to see what the lower end of this value does to the tree.

# %%
regDT_tuner(5, 2, 1, 0.0)
# Out:
# 1.18987512589
# Test Mean Squared Error = 0.608460553012
# Learned Regression Tree Model: DecisionTreeModel regressor of depth 5 with 63 nodes
#   If (feature 7 <= 6.0)
#    If (feature 5 <= 7.0)
#     If (feature 9 <= 7.0)
#      If (feature 1 <= 6.0)
#       If (feature 3 <= 7.0)
#        Predict: 1.2367906066536203
#       Else (feature 3 > 7.0)
#        Predict: 0.7012195121951219
#      Else (feature 1 > 6.0)
#       If (feature 3 <= 7.0)
#        Predict: 0.7216338880484114
#       Else (feature 3 > 7.0)
#        Predict: 0.5072463768115942
#     Else (feature 9 > 7.0)
#      If (feature 1 <= 6.0)
#       If (feature 3 <= 7.0)
#        Predict: 0.6706827309236948
#       Else (feature 3 > 7.0)
#        Predict: 0.5178571428571429
#      Else (feature 1 > 6.0)
#       If (feature 2 <= 2.0)
#        Predict: 0.5333333333333333
#       Else (feature 2 > 2.0)
#        Predict: 0.46923076923076923
#    Else (feature 5 > 7.0)
#     If (feature 9 <= 7.0)
#      If (feature 1 <= 6.0)
#       If (feature 3 <= 7.0)
#        Predict: 0.6536885245901639
#       Else (feature 3 > 7.0)
#        Predict: 0.5254629629629629
#      Else (feature 1 > 6.0)
#       If (feature 2 <= 2.0)
#        Predict: 0.44346289752650175
#       Else (feature 2 > 2.0)
#        Predict: 0.49225473321858865
#     Else (feature 9 > 7.0)
#      If (feature 1 <= 6.0)
#       If (feature 0 <= 2.0)
#        Predict: 0.42039800995024873
#       Else (feature 0 > 2.0)
#        Predict: 0.4988235294117647
#      Else (feature 1 > 6.0)
#       If (feature 3 <= 7.0)
#        Predict: 0.5315487571701721
#       Else (feature 3 > 7.0)
#        Predict: 0.7658536585365854
#   Else (feature 7 > 6.0)
#    If (feature 5 <= 7.0)
#     If (feature 0 <= 2.0)
#      If (feature 6 <= 2.0)
#       If (feature 8 <= 2.0)
#        Predict: 0.490787269681742
#       Else (feature 8 > 2.0)
#        Predict: 0.5553846153846154
#      Else (feature 6 > 2.0)
#       If (feature 9 <= 7.0)
#        Predict: 0.5976331360946746
#       Else (feature 9 > 7.0)
#        Predict: 0.5371329879101899
#     Else (feature 0 > 2.0)
#      If (feature 4 <= 2.0)
#       If (feature 2 <= 2.0)
#        Predict: 0.5886970172684458
#       Else (feature 2 > 2.0)
#        Predict: 0.6416666666666667
#      Else (feature 4 > 2.0)
#       If (feature 2 <= 2.0)
#        Predict: 0.6106060606060606
#       Else (feature 2 > 2.0)
#        Predict: 0.5297202797202797
#    Else (feature 5 > 7.0)
#     If (feature 3 <= 7.0)
#      If (feature 9 <= 7.0)
#       If (feature 0 <= 2.0)
#        Predict: 0.4889589905362776
#       Else (feature 0 > 2.0)
#        Predict: 0.581570996978852
#      Else (feature 9 > 7.0)
#       If (feature 1 <= 6.0)
#        Predict: 0.5161290322580645
#       Else (feature 1 > 6.0)
#        Predict: 0.7453531598513011
#     Else (feature 3 > 7.0)
#      If (feature 1 <= 6.0)
#       If (feature 9 <= 7.0)
#        Predict: 0.5449101796407185
#       Else (feature 9 > 7.0)
#        Predict: 0.7092198581560284
#      Else (feature 1 > 6.0)
#       If (feature 9 <= 7.0)
#        Predict: 0.7826887661141805
#       Else (feature 9 > 7.0)
#        Predict: 1.3818615751789975

# %% [markdown]
# Comparing this to the original tree, we can see a small decrease in the training time, but not much of a difference in regards to MSE or the size of the tree.

# %% [markdown]
# Now let's take a look at the upper end, with a value of 15000

# %%
regDT_tuner(5, 15000, 1, 0.0)
# Out:
# 1.2347369194
# Test Mean Squared Error = 0.604814685923
# Learned Regression Tree Model: DecisionTreeModel regressor of depth 5 with 61 nodes
#   If (feature 7 <= 2.0)
#    If (feature 1 <= 2.0)
#     If (feature 5 <= 2.0)
#      If (feature 9 <= 2.0)
#       Predict: 3.0
#      Else (feature 9 > 2.0)
#       If (feature 3 <= 2.0)
#        Predict: 2.25
#       Else (feature 3 > 2.0)
#        Predict: 1.425
#     Else (feature 5 > 2.0)
#      If (feature 9 <= 2.0)
#       If (feature 3 <= 2.0)
#        Predict: 2.25
#       Else (feature 3 > 2.0)
#        Predict: 1.2941176470588236
#      Else (feature 9 > 2.0)
#       If (feature 3 <= 5.0)
#        Predict: 1.030612244897959
#       Else (feature 3 > 5.0)
#        Predict: 0.5538461538461539
#    Else (feature 1 > 2.0)
#     If (feature 5 <= 2.0)
#      If (feature 3 <= 2.0)
#       If (feature 9 <= 2.0)
#        Predict: 2.0
#       Else (feature 9 > 2.0)
#        Predict: 1.1951219512195121
#      Else (feature 3 > 2.0)
#       If (feature 9 <= 2.0)
#        Predict: 1.2222222222222223
#       Else (feature 9 > 2.0)
#        Predict: 0.6666666666666666
#     Else (feature 5 > 2.0)
#      If (feature 3 <= 2.0)
#       If (feature 9 <= 2.0)
#        Predict: 1.3870967741935485
#       Else (feature 9 > 2.0)
#        Predict: 0.6546762589928058
#      Else (feature 3 > 2.0)
#       If (feature 9 <= 2.0)
#        Predict: 0.61328125
#       Else (feature 9 > 2.0)
#        Predict: 0.41295546558704455
#   Else (feature 7 > 2.0)
#    If (feature 5 <= 2.0)
#     If (feature 3 <= 2.0)
#      If (feature 9 <= 2.0)
#       If (feature 1 <= 5.0)
#        Predict: 1.8666666666666667
#       Else (feature 1 > 5.0)
#        Predict: 1.3243243243243243
#      Else (feature 9 > 2.0)
#       If (feature 1 <= 2.0)
#        Predict: 1.4594594594594594
#       Else (feature 1 > 2.0)
#        Predict: 0.6722689075630253
#     Else (feature 3 > 2.0)
#      If (feature 9 <= 2.0)
#       If (feature 1 <= 2.0)
#        Predict: 1.3265306122448979
#       Else (feature 1 > 2.0)
#        Predict: 0.6345381526104418
#      Else (feature 9 > 2.0)
#       If (feature 1 <= 2.0)
#        Predict: 0.6343612334801763
#       Else (feature 1 > 2.0)
#        Predict: 0.4488355681016232
#    Else (feature 5 > 2.0)
#     If (feature 9 <= 2.0)
#      If (feature 1 <= 2.0)
#       If (feature 3 <= 2.0)
#        Predict: 1.5490196078431373
#       Else (feature 3 > 2.0)
#        Predict: 0.7374517374517374
#      Else (feature 1 > 2.0)
#       If (feature 3 <= 2.0)
#        Predict: 0.6197183098591549
#       Else (feature 3 > 2.0)
#        Predict: 0.44049247606019154
#     Else (feature 9 > 2.0)
#      If (feature 1 <= 2.0)
#       If (feature 3 <= 2.0)
#        Predict: 0.676923076923077
#       Else (feature 3 > 2.0)
#        Predict: 0.44680851063829785
#      Else (feature 1 > 2.0)
#       If (feature 3 <= 2.0)
#        Predict: 0.45174825174825173
#       Else (feature 3 > 2.0)
#        Predict: 0.736391268306162

# %% [markdown]
# With a very large maxBin value, we don't see too much of a change in the overall time or in the MSE. The model still has the same depth and nodes, as expected.

# %% [markdown]
# ### minInstancesPerNode parameter
# Next we will look at tuning the <b>minInstancesPerNode</b> parameter. It starts off at the lowest value of 1, but let's see what happens if we keep increasing the value. Starting off with the value <b>100</b>

# %%
regDT_tuner(5, 32, 100, 0.0)
# Out:
# 1.22303390503
# Test Mean Squared Error = 0.617423137205
# Learned Regression Tree Model: DecisionTreeModel regressor of depth 5 with 49 nodes
#   If (feature 7 <= 2.0)
#    If (feature 1 <= 2.0)
#     If (feature 9 <= 4.0)
#      Predict: 1.2357723577235773
#     Else (feature 9 > 4.0)
#      If (feature 3 <= 6.0)
#       Predict: 0.9528301886792453
#      Else (feature 3 > 6.0)
#       Predict: 0.6233766233766234
#    Else (feature 1 > 2.0)
#     If (feature 5 <= 2.0)
#      If (feature 3 <= 4.0)
#       Predict: 0.9454545454545454
#      Else (feature 3 > 4.0)
#       If (feature 9 <= 7.0)
#        Predict: 0.8057553956834532
#       Else (feature 9 > 7.0)
#        Predict: 0.6132075471698113
#     Else (feature 5 > 2.0)
#      If (feature 3 <= 2.0)
#       If (feature 0 <= 2.0)
#        Predict: 0.8289473684210527
#       Else (feature 0 > 2.0)
#        Predict: 0.6305732484076433
#      Else (feature 3 > 2.0)
#       If (feature 9 <= 2.0)
#        Predict: 0.61328125
#       Else (feature 9 > 2.0)
#        Predict: 0.41295546558704455
#   Else (feature 7 > 2.0)
#    If (feature 5 <= 2.0)
#     If (feature 3 <= 2.0)
#      If (feature 1 <= 5.0)
#       Predict: 1.180952380952381
#      Else (feature 1 > 5.0)
#       If (feature 9 <= 6.0)
#        Predict: 0.8962264150943396
#       Else (feature 9 > 6.0)
#        Predict: 0.6206896551724138
#     Else (feature 3 > 2.0)
#      If (feature 9 <= 2.0)
#       If (feature 1 <= 5.0)
#        Predict: 0.9026548672566371
#       Else (feature 1 > 5.0)
#        Predict: 0.654054054054054
#      Else (feature 9 > 2.0)
#       If (feature 1 <= 2.0)
#        Predict: 0.6343612334801763
#       Else (feature 1 > 2.0)
#        Predict: 0.4488355681016232
#    Else (feature 5 > 2.0)
#     If (feature 9 <= 2.0)
#      If (feature 1 <= 2.0)
#       If (feature 3 <= 5.0)
#        Predict: 1.1932773109243697
#       Else (feature 3 > 5.0)
#        Predict: 0.6701570680628273
#      Else (feature 1 > 2.0)
#       If (feature 3 <= 2.0)
#        Predict: 0.6197183098591549
#       Else (feature 3 > 2.0)
#        Predict: 0.44049247606019154
#     Else (feature 9 > 2.0)
#      If (feature 1 <= 2.0)
#       If (feature 3 <= 2.0)
#        Predict: 0.676923076923077
#       Else (feature 3 > 2.0)
#        Predict: 0.44680851063829785
#      Else (feature 1 > 2.0)
#       If (feature 3 <= 2.0)
#        Predict: 0.45174825174825173
#       Else (feature 3 > 2.0)
#        Predict: 0.736391268306162

# %% [markdown]
# With minInstancesPerNode set to 100, we don't see much of a change in time and MSE, but we can see that there are less nodes in the tree. Try now with a value of <b>1000</b>

# %%
regDT_tuner(5, 32, 1000, 0.0)
# Out:
# 1.12289094925
# Test Mean Squared Error = 0.634591568985
# Learned Regression Tree Model: DecisionTreeModel regressor of depth 5 with 15 nodes
#   If (feature 7 <= 2.0)
#    If (feature 5 <= 5.0)
#     Predict: 0.6787072243346007
#    Else (feature 5 > 5.0)
#     Predict: 0.5251009809578765
#   Else (feature 7 > 2.0)
#    If (feature 5 <= 2.0)
#     If (feature 3 <= 6.0)
#      Predict: 0.6546341463414634
#     Else (feature 3 > 6.0)
#      Predict: 0.5008038585209004
#    Else (feature 5 > 2.0)
#     If (feature 9 <= 2.0)
#      Predict: 0.5269521410579345
#     Else (feature 9 > 2.0)
#      If (feature 1 <= 2.0)
#       Predict: 0.48072562358276644
#      Else (feature 1 > 2.0)
#       If (feature 3 <= 2.0)
#        Predict: 0.45174825174825173
#       Else (feature 3 > 2.0)
#        Predict: 0.736391268306162

# %% [markdown]
# With a value of 1000, we may see more of a decrease in the time, but the MSE has also increased a little bit. As well, the number of nodes in the model has decreased once again. Let's take it one step further and try with a value of <b>8000</b>

# %%
regDT_tuner(5, 32, 8000, 0.0)
# Out:
# 0.940607070923
# Test Mean Squared Error = 0.649847290714
# Learned Regression Tree Model: DecisionTreeModel regressor of depth 1 with 3 nodes
#   If (feature 7 <= 6.0)
#    Predict: 0.6062953399729497
#   Else (feature 7 > 6.0)
#    Predict: 0.6272221032340972

# %% [markdown]
# With a value of 8000, we may see that the run-time to build the model is starting to decrease a lot more, with only a small increase in MSE compared to when the value was set to 1000. The main difference we see is that the tree has become a lot smaller! This is to be expected since we are tuning a stopping parameter, which determines when the model finishes building.

# %% [markdown]
# ### minInfoGain Parameter
# For the last parameter, we will look at the minInfoGain parameter, which was initially set to 0.0. This value works well with negative values, and is very sensitive with values greater than 0.0. Try setting the value to a low number, such as -100.0

# %%
regDT_tuner(5, 32, 1, -100.0)
# Out:
# 1.16571116447
# Test Mean Squared Error = 0.604814685923
# Learned Regression Tree Model: DecisionTreeModel regressor of depth 5 with 61 nodes
#   If (feature 7 <= 2.0)
#    If (feature 1 <= 2.0)
#     If (feature 5 <= 2.0)
#      If (feature 9 <= 2.0)
#       Predict: 3.0
#      Else (feature 9 > 2.0)
#       If (feature 3 <= 2.0)
#        Predict: 2.25
#       Else (feature 3 > 2.0)
#        Predict: 1.425
#     Else (feature 5 > 2.0)
#      If (feature 9 <= 2.0)
#       If (feature 3 <= 2.0)
#        Predict: 2.25
#       Else (feature 3 > 2.0)
#        Predict: 1.2941176470588236
#      Else (feature 9 > 2.0)
#       If (feature 3 <= 5.0)
#        Predict: 1.030612244897959
#       Else (feature 3 > 5.0)
#        Predict: 0.5538461538461539
#    Else (feature 1 > 2.0)
#     If (feature 5 <= 2.0)
#      If (feature 3 <= 2.0)
#       If (feature 9 <= 2.0)
#        Predict: 2.0
#       Else (feature 9 > 2.0)
#        Predict: 1.1951219512195121
#      Else (feature 3 > 2.0)
#       If (feature 9 <= 2.0)
#        Predict: 1.2222222222222223
#       Else (feature 9 > 2.0)
#        Predict: 0.6666666666666666
#     Else (feature 5 > 2.0)
#      If (feature 3 <= 2.0)
#       If (feature 9 <= 2.0)
#        Predict: 1.3870967741935485
#       Else (feature 9 > 2.0)
#        Predict: 0.6546762589928058
#      Else (feature 3 > 2.0)
#       If (feature 9 <= 2.0)
#        Predict: 0.61328125
#       Else (feature 9 > 2.0)
#        Predict: 0.41295546558704455
#   Else (feature 7 > 2.0)
#    If (feature 5 <= 2.0)
#     If (feature 3 <= 2.0)
#      If (feature 9 <= 2.0)
#       If (feature 1 <= 5.0)
#        Predict: 1.8666666666666667
#       Else (feature 1 > 5.0)
#        Predict: 1.3243243243243243
#      Else (feature 9 > 2.0)
#       If (feature 1 <= 2.0)
#        Predict: 1.4594594594594594
#       Else (feature 1 > 2.0)
#        Predict: 0.6722689075630253
#     Else (feature 3 > 2.0)
#      If (feature 9 <= 2.0)
#       If (feature 1 <= 2.0)
#        Predict: 1.3265306122448979
#       Else (feature 1 > 2.0)
#        Predict: 0.6345381526104418
#      Else (feature 9 > 2.0)
#       If (feature 1 <= 2.0)
#        Predict: 0.6343612334801763
#       Else (feature 1 > 2.0)
#        Predict: 0.4488355681016232
#    Else (feature 5 > 2.0)
#     If (feature 9 <= 2.0)
#      If (feature 1 <= 2.0)
#       If (feature 3 <= 2.0)
#        Predict: 1.5490196078431373
#       Else (feature 3 > 2.0)
#        Predict: 0.7374517374517374
#      Else (feature 1 > 2.0)
#       If (feature 3 <= 2.0)
#        Predict: 0.6197183098591549
#       Else (feature 3 > 2.0)
#        Predict: 0.44049247606019154
#     Else (feature 9 > 2.0)
#      If (feature 1 <= 2.0)
#       If (feature 3 <= 2.0)
#        Predict: 0.676923076923077
#       Else (feature 3 > 2.0)
#        Predict: 0.44680851063829785
#      Else (feature 1 > 2.0)
#       If (feature 3 <= 2.0)
#        Predict: 0.45174825174825173
#       Else (feature 3 > 2.0)
#        Predict: 0.736391268306162

# %% [markdown]
# Overall, we don't see much of a change at all to anything. Now try changing the value to 0.0003

# %%
regDT_tuner(5, 32, 1, 0.0003)
# Out:
# 0.994264125824
# Test Mean Squared Error = 0.649837699394
# Learned Regression Tree Model: DecisionTreeModel regressor of depth 0 with 1 nodes
#   Predict: 0.6174803960849408

# %% [markdown]
# We can see that small values greater than zero can cause drastic changes in how the model looks. Here, we see a small decrease in the training time, and small increase in the MSE value. But now the tree only contains one node in it. The affect of this parameter on the tree is similar to minInstancesPerNode, since they are both stopping parameters.

# %% [markdown]
# ---

# %% [markdown]
# ## DecisionTree (Classification)

# %% [markdown]
# Now it's time for you to try it out for yourself! Build a Classification DecisionTree in a similar way that the Regression DecisionTree was built. Please note that you will be using the same dataset in this section (regDT_train, regDT_test), therefore you do not need to re-initialize that section.<br> <br>
#
# Try to only reference the above section when you are experiencing a lot of difficulty. This section is mainly for you to apply your learning.

# %% [markdown]
# For some help with the variables:
# <ul>
#     <li><b>numClasses</b>: The number of classes for this dataset is <b>10</b> (parameter doesn't require tuning)</li>
#     <li><b>categoricalFeaturesInfo</b>: Has a value of <b>{}</b> (parameter doesn't require tuning)</li>
#     <li><b>impurity</b>: There are two types of impurites you can use -- <b>'gini'</b> or <b>'entropy'</b> <i>(Default: 'gini')</i></li>
#     <li><b>maxDepth</b>: Values range between <b>0 and 30</b> <i>(Default: 5)</i></li>
#     <li><b>maxBins</b>: Value ranges between <b>2 and 2147483647</b> (largest value for 32-bits) <i>(Default: 32)</i></li>
#     <li><b>minInstancesPerNode</b> ranges between <b>1 and 2147483647</b> <i>(Default: 1)</i></li>
#     <li><b>minInfoGain</b>: Ensure it is a float (has a decimal in the value) <i>(Default: 0.0)</i></li>
# </ul>
#
# When displaying the <b>Training Error</b>, use the following formula and print statement instead of MSE: <br>
# <b>classDT_error = classDT_label_pred.filter(lambda (v, p): v != p).count() / float(regDT_test.count())</b> <br>
# <b>print('Test Error = ' + str(classDT_error))</b>

# %% [markdown]
# ### The Goal
# Try to create a model that is better than the model with default values. Challenge yourself by trying to create the best model you can!
#
#
# ### Note
# We want a model that doesn't take too long to train and will cause overfitting. Remember that a very large model with high accuracy but long run time may not be good because the model may have overfit the data.

# %%
start = time.time()
classDT_model = DecisionTree.trainClassifier(regDT_train, numClasses = 10, 
                                     categoricalFeaturesInfo = {},
                                     impurity = 'gini', maxDepth = 9,
                                     maxBins = 25, minInstancesPerNode = 4,
                                     minInfoGain = -3.0)
print(time.time() - start)
# Evaluate model on test instances and compute test error
classDT_pred = classDT_model.predict(regDT_test.map(lambda x: x.features))
classDT_label_pred = regDT_test.map(lambda lp: lp.label).zip(classDT_pred)
classDT_error = classDT_label_pred.filter(lambda (v, p): v != p).count() / float(regDT_test.count())
print('Test Error = ' + str(classDT_error))
print('Learned classification tree model:' + classDT_model.toDebugString())
# Out:
# 1.55005598068
# Test Error = 0.460140602202
# Learned classification tree model:DecisionTreeModel classifier of depth 9 with 891 nodes
#   If (feature 5 <= 4.0)
#    If (feature 9 <= 4.0)
#     If (feature 3 <= 4.0)
#      If (feature 1 <= 4.0)
#       If (feature 7 <= 4.0)
#        If (feature 3 <= 2.0)
#         If (feature 7 <= 1.0)
#          Predict: 1.0
#         Else (feature 7 > 1.0)
#          If (feature 4 <= 3.0)
#           Predict: 2.0
#          Else (feature 4 > 3.0)
#           Predict: 2.0
#        Else (feature 3 > 2.0)
#         If (feature 9 <= 3.0)
#          If (feature 4 <= 2.0)
#           Predict: 1.0
#          Else (feature 4 > 2.0)
#           Predict: 3.0
#         Else (feature 9 > 3.0)
#          Predict: 1.0
#       Else (feature 7 > 4.0)
#        If (feature 3 <= 3.0)
#         If (feature 8 <= 2.0)
#          If (feature 9 <= 2.0)
#           If (feature 5 <= 1.0)
#            Predict: 1.0
#           Else (feature 5 > 1.0)
#            Predict: 1.0
#          Else (feature 9 > 2.0)
#           If (feature 8 <= 1.0)
#            Predict: 1.0
#           Else (feature 8 > 1.0)
#            Predict: 1.0
#         Else (feature 8 > 2.0)
#          If (feature 5 <= 2.0)
#           If (feature 5 <= 1.0)
#            Predict: 1.0
#           Else (feature 5 > 1.0)
#            Predict: 1.0
#          Else (feature 5 > 2.0)
#           If (feature 3 <= 2.0)
#            Predict: 1.0
#           Else (feature 3 > 2.0)
#            Predict: 3.0
#        Else (feature 3 > 3.0)
#         If (feature 9 <= 3.0)
#          If (feature 5 <= 2.0)
#           If (feature 1 <= 1.0)
#            Predict: 3.0
#           Else (feature 1 > 1.0)
#            Predict: 0.0
#          Else (feature 5 > 2.0)
#           Predict: 1.0
#         Else (feature 9 > 3.0)
#          Predict: 2.0
#      Else (feature 1 > 4.0)
#       If (feature 1 <= 10.0)
#        If (feature 7 <= 4.0)
#         If (feature 3 <= 1.0)
#          If (feature 1 <= 7.0)
#           Predict: 1.0
#          Else (feature 1 > 7.0)
#           Predict: 1.0
#         Else (feature 3 > 1.0)
#          If (feature 2 <= 1.0)
#           If (feature 3 <= 2.0)
#            Predict: 1.0
#           Else (feature 3 > 2.0)
#            Predict: 1.0
#          Else (feature 2 > 1.0)
#           If (feature 2 <= 3.0)
#            Predict: 2.0
#           Else (feature 2 > 3.0)
#            Predict: 1.0
#        Else (feature 7 > 4.0)
#         If (feature 6 <= 1.0)
#          If (feature 8 <= 3.0)
#           If (feature 7 <= 10.0)
#            Predict: 1.0
#           Else (feature 7 > 10.0)
#            Predict: 0.0
#          Else (feature 8 > 3.0)
#           If (feature 0 <= 2.0)
#            Predict: 1.0
#           Else (feature 0 > 2.0)
#            Predict: 1.0
#         Else (feature 6 > 1.0)
#          If (feature 1 <= 5.0)
#           If (feature 4 <= 2.0)
#            Predict: 1.0
#           Else (feature 4 > 2.0)
#            Predict: 0.0
#          Else (feature 1 > 5.0)
#           If (feature 7 <= 10.0)
#            Predict: 1.0
#           Else (feature 7 > 10.0)
#            Predict: 0.0
#       Else (feature 1 > 10.0)
#        If (feature 3 <= 2.0)
#         If (feature 9 <= 2.0)
#          If (feature 7 <= 5.0)
#           If (feature 2 <= 2.0)
#            Predict: 1.0
#           Else (feature 2 > 2.0)
#            Predict: 1.0
#          Else (feature 7 > 5.0)
#           If (feature 7 <= 10.0)
#            Predict: 1.0
#           Else (feature 7 > 10.0)
#            Predict: 1.0
#         Else (feature 9 > 2.0)
#          If (feature 7 <= 9.0)
#           If (feature 7 <= 6.0)
#            Predict: 1.0
#           Else (feature 7 > 6.0)
#            Predict: 0.0
#          Else (feature 7 > 9.0)
#           If (feature 6 <= 2.0)
#            Predict: 1.0
#           Else (feature 6 > 2.0)
#            Predict: 1.0
#        Else (feature 3 > 2.0)
#         If (feature 7 <= 4.0)
#          If (feature 6 <= 1.0)
#           Predict: 1.0
#          Else (feature 6 > 1.0)
#           If (feature 4 <= 1.0)
#            Predict: 1.0
#           Else (feature 4 > 1.0)
#            Predict: 1.0
#         Else (feature 7 > 4.0)
#          If (feature 8 <= 3.0)
#           If (feature 3 <= 3.0)
#            Predict: 0.0
#           Else (feature 3 > 3.0)
#            Predict: 1.0
#          Else (feature 8 > 3.0)
#           Predict: 1.0
#     Else (feature 3 > 4.0)
#      If (feature 7 <= 4.0)
#       If (feature 1 <= 4.0)
#        If (feature 3 <= 6.0)
#         If (feature 6 <= 2.0)
#          Predict: 1.0
#         Else (feature 6 > 2.0)
#          If (feature 4 <= 3.0)
#           Predict: 1.0
#          Else (feature 4 > 3.0)
#           Predict: 1.0
#        Else (feature 3 > 6.0)
#         If (feature 4 <= 1.0)
#          If (feature 3 <= 9.0)
#           If (feature 9 <= 1.0)
#            Predict: 1.0
#           Else (feature 9 > 1.0)
#            Predict: 2.0
#          Else (feature 3 > 9.0)
#           Predict: 1.0
#         Else (feature 4 > 1.0)
#          If (feature 8 <= 1.0)
#           If (feature 1 <= 3.0)
#            Predict: 1.0
#           Else (feature 1 > 3.0)
#            Predict: 1.0
#          Else (feature 8 > 1.0)
#           If (feature 0 <= 2.0)
#            Predict: 1.0
#           Else (feature 0 > 2.0)
#            Predict: 3.0
#       Else (feature 1 > 4.0)
#        If (feature 7 <= 2.0)
#         If (feature 9 <= 3.0)
#          If (feature 5 <= 3.0)
#           If (feature 8 <= 2.0)
#            Predict: 1.0
#           Else (feature 8 > 2.0)
#            Predict: 1.0
#          Else (feature 5 > 3.0)
#           If (feature 8 <= 2.0)
#            Predict: 0.0
#           Else (feature 8 > 2.0)
#            Predict: 1.0
#         Else (feature 9 > 3.0)
#          If (feature 5 <= 3.0)
#           If (feature 5 <= 1.0)
#            Predict: 1.0
#           Else (feature 5 > 1.0)
#            Predict: 0.0
#          Else (feature 5 > 3.0)
#           If (feature 3 <= 9.0)
#            Predict: 1.0
#           Else (feature 3 > 9.0)
#            Predict: 1.0
#        Else (feature 7 > 2.0)
#         If (feature 9 <= 3.0)
#          If (feature 5 <= 3.0)
#           If (feature 7 <= 3.0)
#            Predict: 1.0
#           Else (feature 7 > 3.0)
#            Predict: 0.0
#          Else (feature 5 > 3.0)
#           If (feature 7 <= 3.0)
#            Predict: 0.0
#           Else (feature 7 > 3.0)
#            Predict: 1.0
#         Else (feature 9 > 3.0)
#          If (feature 2 <= 2.0)
#           Predict: 1.0
#          Else (feature 2 > 2.0)
#           If (feature 5 <= 2.0)
#            Predict: 0.0
#           Else (feature 5 > 2.0)
#            Predict: 1.0
#      Else (feature 7 > 4.0)
#       If (feature 1 <= 4.0)
#        If (feature 0 <= 3.0)
#         If (feature 7 <= 6.0)
#          If (feature 7 <= 5.0)
#           If (feature 3 <= 6.0)
#            Predict: 0.0
#           Else (feature 3 > 6.0)
#            Predict: 1.0
#          Else (feature 7 > 5.0)
#           If (feature 6 <= 2.0)
#            Predict: 1.0
#           Else (feature 6 > 2.0)
#            Predict: 1.0
#         Else (feature 7 > 6.0)
#          If (feature 2 <= 1.0)
#           If (feature 1 <= 3.0)
#            Predict: 0.0
#           Else (feature 1 > 3.0)
#            Predict: 1.0
#          Else (feature 2 > 1.0)
#           If (feature 6 <= 1.0)
#            Predict: 1.0
#           Else (feature 6 > 1.0)
#            Predict: 1.0
#        Else (feature 0 > 3.0)
#         If (feature 8 <= 3.0)
#          If (feature 5 <= 2.0)
#           If (feature 9 <= 2.0)
#            Predict: 1.0
#           Else (feature 9 > 2.0)
#            Predict: 0.0
#          Else (feature 5 > 2.0)
#           If (feature 1 <= 1.0)
#            Predict: 0.0
#           Else (feature 1 > 1.0)
#            Predict: 0.0
#         Else (feature 8 > 3.0)
#          If (feature 2 <= 2.0)
#           Predict: 0.0
#          Else (feature 2 > 2.0)
#           Predict: 0.0
#       Else (feature 1 > 4.0)
#        If (feature 8 <= 2.0)
#         If (feature 7 <= 6.0)
#          If (feature 4 <= 2.0)
#           If (feature 2 <= 1.0)
#            Predict: 0.0
#           Else (feature 2 > 1.0)
#            Predict: 1.0
#          Else (feature 4 > 2.0)
#           If (feature 3 <= 12.0)
#            Predict: 1.0
#           Else (feature 3 > 12.0)
#            Predict: 0.0
#         Else (feature 7 > 6.0)
#          If (feature 9 <= 2.0)
#           If (feature 6 <= 3.0)
#            Predict: 1.0
#           Else (feature 6 > 3.0)
#            Predict: 0.0
#          Else (feature 9 > 2.0)
#           If (feature 5 <= 1.0)
#            Predict: 0.0
#           Else (feature 5 > 1.0)
#            Predict: 0.0
#        Else (feature 8 > 2.0)
#         If (feature 7 <= 11.0)
#          If (feature 9 <= 2.0)
#           If (feature 5 <= 2.0)
#            Predict: 0.0
#           Else (feature 5 > 2.0)
#            Predict: 0.0
#          Else (feature 9 > 2.0)
#           If (feature 5 <= 2.0)
#            Predict: 0.0
#           Else (feature 5 > 2.0)
#            Predict: 1.0
#         Else (feature 7 > 11.0)
#          If (feature 1 <= 11.0)
#           If (feature 3 <= 10.0)
#            Predict: 0.0
#           Else (feature 3 > 10.0)
#            Predict: 1.0
#          Else (feature 1 > 11.0)
#           If (feature 2 <= 2.0)
#            Predict: 0.0
#           Else (feature 2 > 2.0)
#            Predict: 1.0
#    Else (feature 9 > 4.0)
#     If (feature 1 <= 4.0)
#      If (feature 3 <= 4.0)
#       If (feature 7 <= 4.0)
#        If (feature 6 <= 3.0)
#         If (feature 1 <= 3.0)
#          If (feature 8 <= 3.0)
#           If (feature 4 <= 3.0)
#            Predict: 1.0
#           Else (feature 4 > 3.0)
#            Predict: 1.0
#          Else (feature 8 > 3.0)
#           If (feature 3 <= 3.0)
#            Predict: 1.0
#           Else (feature 3 > 3.0)
#            Predict: 1.0
#         Else (feature 1 > 3.0)
#          If (feature 5 <= 1.0)
#           Predict: 1.0
#          Else (feature 5 > 1.0)
#           If (feature 3 <= 1.0)
#            Predict: 0.0
#           Else (feature 3 > 1.0)
#            Predict: 1.0
#        Else (feature 6 > 3.0)
#         If (feature 9 <= 11.0)
#          If (feature 9 <= 7.0)
#           Predict: 2.0
#          Else (feature 9 > 7.0)
#           If (feature 2 <= 2.0)
#            Predict: 1.0
#           Else (feature 2 > 2.0)
#            Predict: 1.0
#         Else (feature 9 > 11.0)
#          Predict: 2.0
#       Else (feature 7 > 4.0)
#        If (feature 2 <= 2.0)
#         If (feature 6 <= 1.0)
#          If (feature 7 <= 10.0)
#           If (feature 3 <= 2.0)
#            Predict: 0.0
#           Else (feature 3 > 2.0)
#            Predict: 0.0
#          Else (feature 7 > 10.0)
#           Predict: 1.0
#         Else (feature 6 > 1.0)
#          If (feature 9 <= 6.0)
#           If (feature 7 <= 8.0)
#            Predict: 1.0
#           Else (feature 7 > 8.0)
#            Predict: 0.0
#          Else (feature 9 > 6.0)
#           If (feature 3 <= 1.0)
#            Predict: 1.0
#           Else (feature 3 > 1.0)
#            Predict: 1.0
#        Else (feature 2 > 2.0)
#         If (feature 9 <= 12.0)
#          If (feature 5 <= 3.0)
#           If (feature 9 <= 7.0)
#            Predict: 0.0
#           Else (feature 9 > 7.0)
#            Predict: 1.0
#          Else (feature 5 > 3.0)
#           If (feature 0 <= 1.0)
#            Predict: 0.0
#           Else (feature 0 > 1.0)
#            Predict: 1.0
#         Else (feature 9 > 12.0)
#          If (feature 6 <= 3.0)
#           Predict: 0.0
#          Else (feature 6 > 3.0)
#           Predict: 1.0
#      Else (feature 3 > 4.0)
#       If (feature 7 <= 4.0)
#        If (feature 9 <= 11.0)
#         If (feature 3 <= 7.0)
#          If (feature 9 <= 6.0)
#           If (feature 3 <= 6.0)
#            Predict: 1.0
#           Else (feature 3 > 6.0)
#            Predict: 1.0
#          Else (feature 9 > 6.0)
#           If (feature 5 <= 1.0)
#            Predict: 0.0
#           Else (feature 5 > 1.0)
#            Predict: 1.0
#         Else (feature 3 > 7.0)
#          If (feature 8 <= 3.0)
#           If (feature 3 <= 8.0)
#            Predict: 0.0
#           Else (feature 3 > 8.0)
#            Predict: 0.0
#          Else (feature 8 > 3.0)
#           If (feature 3 <= 10.0)
#            Predict: 0.0
#           Else (feature 3 > 10.0)
#            Predict: 1.0
#        Else (feature 9 > 11.0)
#         If (feature 5 <= 2.0)
#          If (feature 1 <= 3.0)
#           If (feature 6 <= 1.0)
#            Predict: 1.0
#           Else (feature 6 > 1.0)
#            Predict: 1.0
#          Else (feature 1 > 3.0)
#           Predict: 0.0
#         Else (feature 5 > 2.0)
#          If (feature 9 <= 12.0)
#           If (feature 1 <= 2.0)
#            Predict: 0.0
#           Else (feature 1 > 2.0)
#            Predict: 1.0
#          Else (feature 9 > 12.0)
#           If (feature 4 <= 3.0)
#            Predict: 0.0
#           Else (feature 4 > 3.0)
#            Predict: 1.0
#       Else (feature 7 > 4.0)
#        If (feature 1 <= 3.0)
#         If (feature 5 <= 3.0)
#          If (feature 9 <= 10.0)
#           If (feature 9 <= 6.0)
#            Predict: 0.0
#           Else (feature 9 > 6.0)
#            Predict: 1.0
#          Else (feature 9 > 10.0)
#           If (feature 5 <= 2.0)
#            Predict: 0.0
#           Else (feature 5 > 2.0)
#            Predict: 0.0
#         Else (feature 5 > 3.0)
#          If (feature 3 <= 12.0)
#           If (feature 4 <= 2.0)
#            Predict: 0.0
#           Else (feature 4 > 2.0)
#            Predict: 0.0
#          Else (feature 3 > 12.0)
#           If (feature 7 <= 10.0)
#            Predict: 0.0
#           Else (feature 7 > 10.0)
#            Predict: 1.0
#        Else (feature 1 > 3.0)
#         If (feature 5 <= 3.0)
#          If (feature 0 <= 3.0)
#           If (feature 9 <= 8.0)
#            Predict: 0.0
#           Else (feature 9 > 8.0)
#            Predict: 0.0
#          Else (feature 0 > 3.0)
#           If (feature 7 <= 7.0)
#            Predict: 0.0
#           Else (feature 7 > 7.0)
#            Predict: 0.0
#         Else (feature 5 > 3.0)
#          If (feature 2 <= 3.0)
#           If (feature 4 <= 2.0)
#            Predict: 1.0
#           Else (feature 4 > 2.0)
#            Predict: 1.0
#          Else (feature 2 > 3.0)
#           If (feature 9 <= 12.0)
#            Predict: 1.0
#           Else (feature 9 > 12.0)
#            Predict: 2.0
#     Else (feature 1 > 4.0)
#      If (feature 9 <= 5.0)
#       If (feature 1 <= 5.0)
#        If (feature 3 <= 4.0)
#         Predict: 2.0
#        Else (feature 3 > 4.0)
#         If (feature 3 <= 9.0)
#          If (feature 7 <= 4.0)
#           Predict: 2.0
#          Else (feature 7 > 4.0)
#           If (feature 5 <= 2.0)
#            Predict: 2.0
#           Else (feature 5 > 2.0)
#            Predict: 1.0
#         Else (feature 3 > 9.0)
#          If (feature 0 <= 2.0)
#           Predict: 1.0
#          Else (feature 0 > 2.0)
#           Predict: 1.0
#       Else (feature 1 > 5.0)
#        If (feature 7 <= 5.0)
#         If (feature 7 <= 4.0)
#          If (feature 3 <= 6.0)
#           If (feature 1 <= 7.0)
#            Predict: 1.0
#           Else (feature 1 > 7.0)
#            Predict: 1.0
#          Else (feature 3 > 6.0)
#           If (feature 3 <= 12.0)
#            Predict: 0.0
#           Else (feature 3 > 12.0)
#            Predict: 1.0
#         Else (feature 7 > 4.0)
#          If (feature 6 <= 2.0)
#           If (feature 1 <= 9.0)
#            Predict: 1.0
#           Else (feature 1 > 9.0)
#            Predict: 1.0
#          Else (feature 6 > 2.0)
#           Predict: 1.0
#        Else (feature 7 > 5.0)
#         If (feature 3 <= 7.0)
#          If (feature 1 <= 7.0)
#           If (feature 3 <= 4.0)
#            Predict: 0.0
#           Else (feature 3 > 4.0)
#            Predict: 1.0
#          Else (feature 1 > 7.0)
#           If (feature 7 <= 7.0)
#            Predict: 0.0
#           Else (feature 7 > 7.0)
#            Predict: 0.0
#         Else (feature 3 > 7.0)
#          If (feature 1 <= 7.0)
#           If (feature 7 <= 7.0)
#            Predict: 0.0
#           Else (feature 7 > 7.0)
#            Predict: 0.0
#          Else (feature 1 > 7.0)
#           If (feature 7 <= 10.0)
#            Predict: 0.0
#           Else (feature 7 > 10.0)
#            Predict: 0.0
#      Else (feature 9 > 5.0)
#       If (feature 1 <= 6.0)
#        If (feature 7 <= 6.0)
#         If (feature 7 <= 3.0)
#          If (feature 9 <= 11.0)
#           If (feature 3 <= 5.0)
#            Predict: 1.0
#           Else (feature 3 > 5.0)
#            Predict: 0.0
#          Else (feature 9 > 11.0)
#           If (feature 7 <= 2.0)
#            Predict: 0.0
#           Else (feature 7 > 2.0)
#            Predict: 0.0
#         Else (feature 7 > 3.0)
#          If (feature 5 <= 3.0)
#           If (feature 7 <= 5.0)
#            Predict: 0.0
#           Else (feature 7 > 5.0)
#            Predict: 1.0
#          Else (feature 5 > 3.0)
#           If (feature 7 <= 4.0)
#            Predict: 1.0
#           Else (feature 7 > 4.0)
#            Predict: 1.0
#        Else (feature 7 > 6.0)
#         If (feature 9 <= 6.0)
#          If (feature 1 <= 5.0)
#           If (feature 3 <= 6.0)
#            Predict: 1.0
#           Else (feature 3 > 6.0)
#            Predict: 0.0
#          Else (feature 1 > 5.0)
#           If (feature 5 <= 3.0)
#            Predict: 2.0
#           Else (feature 5 > 3.0)
#            Predict: 1.0
#         Else (feature 9 > 6.0)
#          If (feature 0 <= 1.0)
#           If (feature 6 <= 3.0)
#            Predict: 0.0
#           Else (feature 6 > 3.0)
#            Predict: 0.0
#          Else (feature 0 > 1.0)
#           If (feature 3 <= 4.0)
#            Predict: 0.0
#           Else (feature 3 > 4.0)
#            Predict: 0.0
#       Else (feature 1 > 6.0)
#        If (feature 3 <= 5.0)
#         If (feature 7 <= 3.0)
#          If (feature 3 <= 3.0)
#           If (feature 0 <= 1.0)
#            Predict: 1.0
#           Else (feature 0 > 1.0)
#            Predict: 1.0
#          Else (feature 3 > 3.0)
#           If (feature 5 <= 3.0)
#            Predict: 0.0
#           Else (feature 5 > 3.0)
#            Predict: 1.0
#         Else (feature 7 > 3.0)
#          If (feature 7 <= 9.0)
#           If (feature 9 <= 10.0)
#            Predict: 0.0
#           Else (feature 9 > 10.0)
#            Predict: 0.0
#          Else (feature 7 > 9.0)
#           If (feature 1 <= 9.0)
#            Predict: 0.0
#           Else (feature 1 > 9.0)
#            Predict: 1.0
#        Else (feature 3 > 5.0)
#         If (feature 3 <= 9.0)
#          If (feature 1 <= 8.0)
#           If (feature 2 <= 1.0)
#            Predict: 1.0
#           Else (feature 2 > 1.0)
#            Predict: 1.0
#          Else (feature 1 > 8.0)
#           If (feature 3 <= 8.0)
#            Predict: 0.0
#           Else (feature 3 > 8.0)
#            Predict: 1.0
#         Else (feature 3 > 9.0)
#          If (feature 8 <= 2.0)
#           If (feature 4 <= 2.0)
#            Predict: 1.0
#           Else (feature 4 > 2.0)
#            Predict: 0.0
#          Else (feature 8 > 2.0)
#           If (feature 7 <= 6.0)
#            Predict: 0.0
#           Else (feature 7 > 6.0)
#            Predict: 0.0
#   Else (feature 5 > 4.0)
#    If (feature 7 <= 4.0)
#     If (feature 1 <= 4.0)
#      If (feature 9 <= 4.0)
#       If (feature 3 <= 4.0)
#        If (feature 2 <= 3.0)
#         If (feature 4 <= 3.0)
#          If (feature 1 <= 3.0)
#           If (feature 5 <= 6.0)
#            Predict: 1.0
#           Else (feature 5 > 6.0)
#            Predict: 1.0
#          Else (feature 1 > 3.0)
#           If (feature 0 <= 2.0)
#            Predict: 1.0
#           Else (feature 0 > 2.0)
#            Predict: 0.0
#         Else (feature 4 > 3.0)
#          If (feature 1 <= 1.0)
#           Predict: 3.0
#          Else (feature 1 > 1.0)
#           If (feature 7 <= 3.0)
#            Predict: 1.0
#           Else (feature 7 > 3.0)
#            Predict: 0.0
#        Else (feature 2 > 3.0)
#         If (feature 5 <= 9.0)
#          If (feature 8 <= 2.0)
#           Predict: 2.0
#          Else (feature 8 > 2.0)
#           Predict: 2.0
#         Else (feature 5 > 9.0)
#          If (feature 1 <= 2.0)
#           If (feature 6 <= 1.0)
#            Predict: 1.0
#           Else (feature 6 > 1.0)
#            Predict: 1.0
#          Else (feature 1 > 2.0)
#           Predict: 0.0
#       Else (feature 3 > 4.0)
#        If (feature 3 <= 10.0)
#         If (feature 2 <= 1.0)
#          If (feature 5 <= 6.0)
#           If (feature 1 <= 3.0)
#            Predict: 0.0
#           Else (feature 1 > 3.0)
#            Predict: 0.0
#          Else (feature 5 > 6.0)
#           If (feature 7 <= 2.0)
#            Predict: 1.0
#           Else (feature 7 > 2.0)
#            Predict: 0.0
#         Else (feature 2 > 1.0)
#          If (feature 0 <= 2.0)
#           If (feature 5 <= 5.0)
#            Predict: 1.0
#           Else (feature 5 > 5.0)
#            Predict: 0.0
#          Else (feature 0 > 2.0)
#           If (feature 1 <= 2.0)
#            Predict: 0.0
#           Else (feature 1 > 2.0)
#            Predict: 1.0
#        Else (feature 3 > 10.0)
#         If (feature 5 <= 12.0)
#          If (feature 0 <= 2.0)
#           If (feature 5 <= 10.0)
#            Predict: 1.0
#           Else (feature 5 > 10.0)
#            Predict: 0.0
#          Else (feature 0 > 2.0)
#           If (feature 4 <= 2.0)
#            Predict: 1.0
#           Else (feature 4 > 2.0)
#            Predict: 0.0
#         Else (feature 5 > 12.0)
#          Predict: 1.0
#      Else (feature 9 > 4.0)
#       If (feature 3 <= 4.0)
#        If (feature 6 <= 2.0)
#         If (feature 7 <= 3.0)
#          If (feature 4 <= 3.0)
#           If (feature 9 <= 11.0)
#            Predict: 1.0
#           Else (feature 9 > 11.0)
#            Predict: 1.0
#          Else (feature 4 > 3.0)
#           If (feature 7 <= 2.0)
#            Predict: 0.0
#           Else (feature 7 > 2.0)
#            Predict: 0.0
#         Else (feature 7 > 3.0)
#          If (feature 1 <= 3.0)
#           If (feature 4 <= 2.0)
#            Predict: 0.0
#           Else (feature 4 > 2.0)
#            Predict: 0.0
#          Else (feature 1 > 3.0)
#           Predict: 1.0
#        Else (feature 6 > 2.0)
#         If (feature 9 <= 12.0)
#          If (feature 5 <= 5.0)
#           Predict: 0.0
#          Else (feature 5 > 5.0)
#           If (feature 2 <= 1.0)
#            Predict: 1.0
#           Else (feature 2 > 1.0)
#            Predict: 1.0
#         Else (feature 9 > 12.0)
#          If (feature 1 <= 2.0)
#           Predict: 0.0
#          Else (feature 1 > 2.0)
#           Predict: 0.0
#       Else (feature 3 > 4.0)
#        If (feature 4 <= 2.0)
#         If (feature 7 <= 1.0)
#          If (feature 1 <= 1.0)
#           Predict: 1.0
#          Else (feature 1 > 1.0)
#           If (feature 5 <= 8.0)
#            Predict: 0.0
#           Else (feature 5 > 8.0)
#            Predict: 0.0
#         Else (feature 7 > 1.0)
#          If (feature 1 <= 1.0)
#           If (feature 2 <= 1.0)
#            Predict: 0.0
#           Else (feature 2 > 1.0)
#            Predict: 0.0
#          Else (feature 1 > 1.0)
#           If (feature 1 <= 3.0)
#            Predict: 0.0
#           Else (feature 1 > 3.0)
#            Predict: 0.0
#        Else (feature 4 > 2.0)
#         If (feature 6 <= 3.0)
#          If (feature 7 <= 2.0)
#           If (feature 1 <= 2.0)
#            Predict: 1.0
#           Else (feature 1 > 2.0)
#            Predict: 0.0
#          Else (feature 7 > 2.0)
#           If (feature 1 <= 2.0)
#            Predict: 0.0
#           Else (feature 1 > 2.0)
#            Predict: 1.0
#         Else (feature 6 > 3.0)
#          If (feature 7 <= 3.0)
#           If (feature 0 <= 1.0)
#            Predict: 0.0
#           Else (feature 0 > 1.0)
#            Predict: 0.0
#          Else (feature 7 > 3.0)
#           If (feature 1 <= 3.0)
#            Predict: 0.0
#           Else (feature 1 > 3.0)
#            Predict: 1.0
#     Else (feature 1 > 4.0)
#      If (feature 8 <= 2.0)
#       If (feature 1 <= 8.0)
#        If (feature 5 <= 8.0)
#         If (feature 3 <= 10.0)
#          If (feature 0 <= 3.0)
#           If (feature 1 <= 5.0)
#            Predict: 1.0
#           Else (feature 1 > 5.0)
#            Predict: 1.0
#          Else (feature 0 > 3.0)
#           If (feature 9 <= 4.0)
#            Predict: 0.0
#           Else (feature 9 > 4.0)
#            Predict: 0.0
#         Else (feature 3 > 10.0)
#          If (feature 9 <= 9.0)
#           If (feature 9 <= 4.0)
#            Predict: 0.0
#           Else (feature 9 > 4.0)
#            Predict: 1.0
#          Else (feature 9 > 9.0)
#           If (feature 0 <= 3.0)
#            Predict: 0.0
#           Else (feature 0 > 3.0)
#            Predict: 0.0
#        Else (feature 5 > 8.0)
#         If (feature 6 <= 2.0)
#          If (feature 9 <= 10.0)
#           If (feature 7 <= 3.0)
#            Predict: 0.0
#           Else (feature 7 > 3.0)
#            Predict: 0.0
#          Else (feature 9 > 10.0)
#           If (feature 8 <= 1.0)
#            Predict: 0.0
#           Else (feature 8 > 1.0)
#            Predict: 1.0
#         Else (feature 6 > 2.0)
#          If (feature 9 <= 11.0)
#           If (feature 3 <= 3.0)
#            Predict: 0.0
#           Else (feature 3 > 3.0)
#            Predict: 0.0
#          Else (feature 9 > 11.0)
#           If (feature 5 <= 11.0)
#            Predict: 0.0
#           Else (feature 5 > 11.0)
#            Predict: 0.0
#       Else (feature 1 > 8.0)
#        If (feature 9 <= 7.0)
#         If (feature 3 <= 3.0)
#          If (feature 1 <= 10.0)
#           If (feature 5 <= 10.0)
#            Predict: 1.0
#           Else (feature 5 > 10.0)
#            Predict: 0.0
#          Else (feature 1 > 10.0)
#           If (feature 9 <= 3.0)
#            Predict: 1.0
#           Else (feature 9 > 3.0)
#            Predict: 0.0
#         Else (feature 3 > 3.0)
#          If (feature 4 <= 1.0)
#           If (feature 2 <= 1.0)
#            Predict: 0.0
#           Else (feature 2 > 1.0)
#            Predict: 1.0
#          Else (feature 4 > 1.0)
#           If (feature 6 <= 2.0)
#            Predict: 0.0
#           Else (feature 6 > 2.0)
#            Predict: 0.0
#        Else (feature 9 > 7.0)
#         If (feature 3 <= 7.0)
#          If (feature 5 <= 7.0)
#           If (feature 3 <= 3.0)
#            Predict: 0.0
#           Else (feature 3 > 3.0)
#            Predict: 0.0
#          Else (feature 5 > 7.0)
#           If (feature 9 <= 9.0)
#            Predict: 1.0
#           Else (feature 9 > 9.0)
#            Predict: 0.0
#         Else (feature 3 > 7.0)
#          If (feature 1 <= 12.0)
#           If (feature 5 <= 11.0)
#            Predict: 1.0
#           Else (feature 5 > 11.0)
#            Predict: 1.0
#          Else (feature 1 > 12.0)
#           If (feature 6 <= 1.0)
#            Predict: 0.0
#           Else (feature 6 > 1.0)
#            Predict: 0.0
#      Else (feature 8 > 2.0)
#       If (feature 9 <= 11.0)
#        If (feature 5 <= 12.0)
#         If (feature 1 <= 12.0)
#          If (feature 3 <= 12.0)
#           If (feature 3 <= 9.0)
#            Predict: 0.0
#           Else (feature 3 > 9.0)
#            Predict: 0.0
#          Else (feature 3 > 12.0)
#           If (feature 8 <= 3.0)
#            Predict: 0.0
#           Else (feature 8 > 3.0)
#            Predict: 0.0
#         Else (feature 1 > 12.0)
#          If (feature 3 <= 4.0)
#           If (feature 5 <= 8.0)
#            Predict: 0.0
#           Else (feature 5 > 8.0)
#            Predict: 1.0
#          Else (feature 3 > 4.0)
#           If (feature 0 <= 1.0)
#            Predict: 0.0
#           Else (feature 0 > 1.0)
#            Predict: 0.0
#        Else (feature 5 > 12.0)
#         If (feature 1 <= 12.0)
#          If (feature 3 <= 12.0)
#           If (feature 6 <= 1.0)
#            Predict: 0.0
#           Else (feature 6 > 1.0)
#            Predict: 0.0
#          Else (feature 3 > 12.0)
#           If (feature 9 <= 4.0)
#            Predict: 2.0
#           Else (feature 9 > 4.0)
#            Predict: 1.0
#         Else (feature 1 > 12.0)
#          If (feature 6 <= 1.0)
#           Predict: 1.0
#          Else (feature 6 > 1.0)
#           Predict: 1.0
#       Else (feature 9 > 11.0)
#        If (feature 3 <= 11.0)
#         If (feature 5 <= 11.0)
#          If (feature 7 <= 2.0)
#           If (feature 1 <= 12.0)
#            Predict: 0.0
#           Else (feature 1 > 12.0)
#            Predict: 1.0
#          Else (feature 7 > 2.0)
#           If (feature 4 <= 3.0)
#            Predict: 0.0
#           Else (feature 4 > 3.0)
#            Predict: 0.0
#         Else (feature 5 > 11.0)
#          If (feature 1 <= 8.0)
#           If (feature 0 <= 3.0)
#            Predict: 0.0
#           Else (feature 0 > 3.0)
#            Predict: 1.0
#          Else (feature 1 > 8.0)
#           If (feature 7 <= 1.0)
#            Predict: 0.0
#           Else (feature 7 > 1.0)
#            Predict: 1.0
#        Else (feature 3 > 11.0)
#         If (feature 5 <= 8.0)
#          If (feature 0 <= 2.0)
#           If (feature 6 <= 2.0)
#            Predict: 1.0
#           Else (feature 6 > 2.0)
#            Predict: 0.0
#          Else (feature 0 > 2.0)
#           Predict: 0.0
#         Else (feature 5 > 8.0)
#          If (feature 0 <= 2.0)
#           If (feature 1 <= 11.0)
#            Predict: 1.0
#           Else (feature 1 > 11.0)
#            Predict: 1.0
#          Else (feature 0 > 2.0)
#           If (feature 3 <= 12.0)
#            Predict: 2.0
#           Else (feature 3 > 12.0)
#            Predict: 1.0
#    Else (feature 7 > 4.0)
#     If (feature 9 <= 4.0)
#      If (feature 5 <= 7.0)
#       If (feature 3 <= 8.0)
#        If (feature 1 <= 9.0)
#         If (feature 7 <= 9.0)
#          If (feature 4 <= 2.0)
#           If (feature 1 <= 7.0)
#            Predict: 0.0
#           Else (feature 1 > 7.0)
#            Predict: 1.0
#          Else (feature 4 > 2.0)
#           If (feature 9 <= 1.0)
#            Predict: 1.0
#           Else (feature 9 > 1.0)
#            Predict: 1.0
#         Else (feature 7 > 9.0)
#          If (feature 4 <= 1.0)
#           If (feature 7 <= 10.0)
#            Predict: 0.0
#           Else (feature 7 > 10.0)
#            Predict: 0.0
#          Else (feature 4 > 1.0)
#           If (feature 2 <= 3.0)
#            Predict: 0.0
#           Else (feature 2 > 3.0)
#            Predict: 1.0
#        Else (feature 1 > 9.0)
#         If (feature 7 <= 11.0)
#          If (feature 3 <= 6.0)
#           If (feature 0 <= 1.0)
#            Predict: 0.0
#           Else (feature 0 > 1.0)
#            Predict: 0.0
#          Else (feature 3 > 6.0)
#           If (feature 3 <= 7.0)
#            Predict: 1.0
#           Else (feature 3 > 7.0)
#            Predict: 0.0
#         Else (feature 7 > 11.0)
#          If (feature 1 <= 12.0)
#           If (feature 2 <= 2.0)
#            Predict: 0.0
#           Else (feature 2 > 2.0)
#            Predict: 0.0
#          Else (feature 1 > 12.0)
#           Predict: 0.0
#       Else (feature 3 > 8.0)
#        If (feature 7 <= 11.0)
#         If (feature 9 <= 1.0)
#          If (feature 5 <= 5.0)
#           If (feature 2 <= 1.0)
#            Predict: 0.0
#           Else (feature 2 > 1.0)
#            Predict: 0.0
#          Else (feature 5 > 5.0)
#           If (feature 2 <= 2.0)
#            Predict: 0.0
#           Else (feature 2 > 2.0)
#            Predict: 0.0
#         Else (feature 9 > 1.0)
#          If (feature 8 <= 3.0)
#           If (feature 8 <= 1.0)
#            Predict: 0.0
#           Else (feature 8 > 1.0)
#            Predict: 0.0
#          Else (feature 8 > 3.0)
#           If (feature 6 <= 2.0)
#            Predict: 0.0
#           Else (feature 6 > 2.0)
#            Predict: 0.0
#        Else (feature 7 > 11.0)
#         If (feature 3 <= 11.0)
#          If (feature 4 <= 2.0)
#           If (feature 9 <= 3.0)
#            Predict: 0.0
#           Else (feature 9 > 3.0)
#            Predict: 0.0
#          Else (feature 4 > 2.0)
#           If (feature 1 <= 4.0)
#            Predict: 0.0
#           Else (feature 1 > 4.0)
#            Predict: 0.0
#         Else (feature 3 > 11.0)
#          If (feature 6 <= 3.0)
#           If (feature 1 <= 4.0)
#            Predict: 0.0
#           Else (feature 1 > 4.0)
#            Predict: 1.0
#          Else (feature 6 > 3.0)
#           If (feature 1 <= 6.0)
#            Predict: 1.0
#           Else (feature 1 > 6.0)
#            Predict: 1.0
#      Else (feature 5 > 7.0)
#       If (feature 7 <= 7.0)
#        If (feature 1 <= 7.0)
#         If (feature 2 <= 1.0)
#          If (feature 5 <= 9.0)
#           If (feature 6 <= 2.0)
#            Predict: 0.0
#           Else (feature 6 > 2.0)
#            Predict: 1.0
#          Else (feature 5 > 9.0)
#           If (feature 3 <= 1.0)
#            Predict: 1.0
#           Else (feature 3 > 1.0)
#            Predict: 0.0
#         Else (feature 2 > 1.0)
#          If (feature 2 <= 2.0)
#           If (feature 5 <= 10.0)
#            Predict: 1.0
#           Else (feature 5 > 10.0)
#            Predict: 0.0
#          Else (feature 2 > 2.0)
#           If (feature 1 <= 4.0)
#            Predict: 0.0
#           Else (feature 1 > 4.0)
#            Predict: 1.0
#        Else (feature 1 > 7.0)
#         If (feature 3 <= 3.0)
#          If (feature 9 <= 3.0)
#           If (feature 2 <= 1.0)
#            Predict: 0.0
#           Else (feature 2 > 1.0)
#            Predict: 0.0
#          Else (feature 9 > 3.0)
#           If (feature 4 <= 3.0)
#            Predict: 0.0
#           Else (feature 4 > 3.0)
#            Predict: 0.0
#         Else (feature 3 > 3.0)
#          If (feature 8 <= 2.0)
#           If (feature 0 <= 3.0)
#            Predict: 0.0
#           Else (feature 0 > 3.0)
#            Predict: 1.0
#          Else (feature 8 > 2.0)
#           If (feature 3 <= 5.0)
#            Predict: 1.0
#           Else (feature 3 > 5.0)
#            Predict: 0.0
#       Else (feature 7 > 7.0)
#        If (feature 3 <= 7.0)
#         If (feature 3 <= 4.0)
#          If (feature 9 <= 3.0)
#           If (feature 1 <= 1.0)
#            Predict: 1.0
#           Else (feature 1 > 1.0)
#            Predict: 0.0
#          Else (feature 9 > 3.0)
#           If (feature 3 <= 3.0)
#            Predict: 0.0
#           Else (feature 3 > 3.0)
#            Predict: 1.0
#         Else (feature 3 > 4.0)
#          If (feature 0 <= 1.0)
#           If (feature 1 <= 12.0)
#            Predict: 0.0
#           Else (feature 1 > 12.0)
#            Predict: 0.0
#          Else (feature 0 > 1.0)
#           If (feature 3 <= 6.0)
#            Predict: 0.0
#           Else (feature 3 > 6.0)
#            Predict: 0.0
#        Else (feature 3 > 7.0)
#         If (feature 1 <= 9.0)
#          If (feature 6 <= 1.0)
#           If (feature 7 <= 8.0)
#            Predict: 1.0
#           Else (feature 7 > 8.0)
#            Predict: 0.0
#          Else (feature 6 > 1.0)
#           If (feature 9 <= 1.0)
#            Predict: 1.0
#           Else (feature 9 > 1.0)
#            Predict: 0.0
#         Else (feature 1 > 9.0)
#          If (feature 7 <= 9.0)
#           If (feature 3 <= 11.0)
#            Predict: 1.0
#           Else (feature 3 > 11.0)
#            Predict: 0.0
#          Else (feature 7 > 9.0)
#           If (feature 8 <= 2.0)
#            Predict: 1.0
#           Else (feature 8 > 2.0)
#            Predict: 1.0
#     Else (feature 9 > 4.0)
#      If (feature 1 <= 4.0)
#       If (feature 9 <= 11.0)
#        If (feature 5 <= 11.0)
#         If (feature 3 <= 11.0)
#          If (feature 7 <= 11.0)
#           If (feature 0 <= 3.0)
#            Predict: 1.0
#           Else (feature 0 > 3.0)
#            Predict: 0.0
#          Else (feature 7 > 11.0)
#           If (feature 6 <= 3.0)
#            Predict: 0.0
#           Else (feature 6 > 3.0)
#            Predict: 0.0
#         Else (feature 3 > 11.0)
#          If (feature 7 <= 11.0)
#           If (feature 7 <= 10.0)
#            Predict: 0.0
#           Else (feature 7 > 10.0)
#            Predict: 0.0
#          Else (feature 7 > 11.0)
#           If (feature 5 <= 9.0)
#            Predict: 0.0
#           Else (feature 5 > 9.0)
#            Predict: 1.0
#        Else (feature 5 > 11.0)
#         If (feature 7 <= 11.0)
#          If (feature 9 <= 10.0)
#           If (feature 6 <= 2.0)
#            Predict: 0.0
#           Else (feature 6 > 2.0)
#            Predict: 0.0
#          Else (feature 9 > 10.0)
#           If (feature 3 <= 9.0)
#            Predict: 0.0
#           Else (feature 3 > 9.0)
#            Predict: 1.0
#         Else (feature 7 > 11.0)
#          If (feature 2 <= 2.0)
#           If (feature 3 <= 8.0)
#            Predict: 0.0
#           Else (feature 3 > 8.0)
#            Predict: 3.0
#          Else (feature 2 > 2.0)
#           If (feature 5 <= 12.0)
#            Predict: 1.0
#           Else (feature 5 > 12.0)
#            Predict: 1.0
#       Else (feature 9 > 11.0)
#        If (feature 5 <= 11.0)
#         If (feature 7 <= 11.0)
#          If (feature 3 <= 11.0)
#           If (feature 6 <= 1.0)
#            Predict: 0.0
#           Else (feature 6 > 1.0)
#            Predict: 0.0
#          Else (feature 3 > 11.0)
#           If (feature 9 <= 12.0)
#            Predict: 0.0
#           Else (feature 9 > 12.0)
#            Predict: 1.0
#         Else (feature 7 > 11.0)
#          If (feature 3 <= 10.0)
#           If (feature 6 <= 1.0)
#            Predict: 1.0
#           Else (feature 6 > 1.0)
#            Predict: 0.0
#          Else (feature 3 > 10.0)
#           Predict: 1.0
#        Else (feature 5 > 11.0)
#         If (feature 7 <= 11.0)
#          If (feature 3 <= 10.0)
#           If (feature 2 <= 2.0)
#            Predict: 0.0
#           Else (feature 2 > 2.0)
#            Predict: 1.0
#          Else (feature 3 > 10.0)
#           If (feature 1 <= 3.0)
#            Predict: 1.0
#           Else (feature 1 > 3.0)
#            Predict: 1.0
#         Else (feature 7 > 11.0)
#          If (feature 0 <= 2.0)
#           Predict: 1.0
#          Else (feature 0 > 2.0)
#           Predict: 1.0
#      Else (feature 1 > 4.0)
#       If (feature 3 <= 4.0)
#        If (feature 4 <= 1.0)
#         If (feature 3 <= 3.0)
#          If (feature 5 <= 12.0)
#           If (feature 6 <= 2.0)
#            Predict: 0.0
#           Else (feature 6 > 2.0)
#            Predict: 0.0
#          Else (feature 5 > 12.0)
#           If (feature 8 <= 2.0)
#            Predict: 1.0
#           Else (feature 8 > 2.0)
#            Predict: 0.0
#         Else (feature 3 > 3.0)
#          If (feature 8 <= 1.0)
#           If (feature 6 <= 3.0)
#            Predict: 0.0
#           Else (feature 6 > 3.0)
#            Predict: 1.0
#          Else (feature 8 > 1.0)
#           If (feature 7 <= 9.0)
#            Predict: 1.0
#           Else (feature 7 > 9.0)
#            Predict: 1.0
#        Else (feature 4 > 1.0)
#         If (feature 5 <= 7.0)
#          If (feature 7 <= 7.0)
#           If (feature 1 <= 5.0)
#            Predict: 1.0
#           Else (feature 1 > 5.0)
#            Predict: 0.0
#          Else (feature 7 > 7.0)
#           If (feature 9 <= 10.0)
#            Predict: 0.0
#           Else (feature 9 > 10.0)
#            Predict: 0.0
#         Else (feature 5 > 7.0)
#          If (feature 1 <= 7.0)
#           If (feature 9 <= 7.0)
#            Predict: 0.0
#           Else (feature 9 > 7.0)
#            Predict: 0.0
#          Else (feature 1 > 7.0)
#           If (feature 9 <= 7.0)
#            Predict: 0.0
#           Else (feature 9 > 7.0)
#            Predict: 1.0
#       Else (feature 3 > 4.0)
#        If (feature 5 <= 5.0)
#         If (feature 9 <= 5.0)
#          If (feature 4 <= 2.0)
#           If (feature 7 <= 8.0)
#            Predict: 3.0
#           Else (feature 7 > 8.0)
#            Predict: 1.0
#          Else (feature 4 > 2.0)
#           If (feature 2 <= 2.0)
#            Predict: 1.0
#           Else (feature 2 > 2.0)
#            Predict: 1.0
#         Else (feature 9 > 5.0)
#          If (feature 7 <= 5.0)
#           If (feature 1 <= 9.0)
#            Predict: 2.0
#           Else (feature 1 > 9.0)
#            Predict: 1.0
#          Else (feature 7 > 5.0)
#           If (feature 7 <= 8.0)
#            Predict: 0.0
#           Else (feature 7 > 8.0)
#            Predict: 1.0
#        Else (feature 5 > 5.0)
#         If (feature 5 <= 7.0)
#          If (feature 1 <= 12.0)
#           If (feature 7 <= 7.0)
#            Predict: 1.0
#           Else (feature 7 > 7.0)
#            Predict: 1.0
#          Else (feature 1 > 12.0)
#           If (feature 9 <= 12.0)
#            Predict: 0.0
#           Else (feature 9 > 12.0)
#            Predict: 1.0
#         Else (feature 5 > 7.0)
#          If (feature 9 <= 7.0)
#           If (feature 3 <= 10.0)
#            Predict: 1.0
#           Else (feature 3 > 10.0)
#            Predict: 0.0
#          Else (feature 9 > 7.0)
#           If (feature 7 <= 7.0)
#            Predict: 1.0
#           Else (feature 7 > 7.0)
#            Predict: 1.0

# %% [markdown]
# ---

# %% [markdown]
# ## RandomForest (Classifier)

# %% [markdown]
# Now that we've run through the DecisionTree model, let's work with RandomForests now. The process for this will be similar with the DecisionTree section.

# %% [markdown]
# Import the following libraries:
# <ul>
#     <li>RandomForest, RandomForestModel from pyspark.mllib.tree</li>
#     <li>MLUtils from pyspark.mllib.util</li>
#     <li>time</li>
# </ul>

# %%
from pyspark.mllib.tree import RandomForest, RandomForestModel
from pyspark.mllib.util import MLUtils
import time

# %% [markdown]
# Next, we will load in the <b>pendigits.txt</b> LibSVM file, which is a dataset based on Pen-Based Recognition of Handwritten Digits. Use <b>MLUtils.loadLibSVMFile</b> and pass in the spark context (<b>sc</b>) and the path to the file <b>'resources/pendigits.txt'</b>. Store this into a variable called <b>classRF_data</b> <br> <br>
#
# Note: You can also try out this section with the poker.txt dataset if you want to compare results from both sections!

# %%
classRF_data = MLUtils.loadLibSVMFile(sc, '/resources/data/poker.txt')

# %% [markdown]
# Next, we need to split the data into a training dataset (called <b>classRF_train</b>) and testing dataset (called <b>classRF_test</b>). This will be done by running the <b>.randomSplit</b> function on <b>classRF_data</b>. The input into .randomSplit will be <b>[0.7, 0.3]</b>. <br> <br>
#
# This will give us a training dataset containing 70% of the data, and a testing dataset containing 30% of the data.

# %%
(classRF_train, classRF_test) = classRF_data.randomSplit([0.7, 0.3])

# %% [markdown]
# Next, we need to create the Random Forest Classifier called <b>classRF_model</b>. To instantiate the classifier, use <b>RandomForest.trainClassifier</b>. We will pass in the following parameters:
# <ul>
#     <li>1st: The input data. In our case, we will use <b>classRF_train</b></li>
#     <li>2nd: The number of classes. For this dataset, there will be 10 classes, so set <b>numClasses</b> equal to <b>10</b>
#     <li>3rd: The categorical features info. For our dataset, have <b>categoricalFeaturesInfo</b> equal <b>{}</b></li>
#     <li>4th: The number of trees. We will set <b>numTrees = 3</b>
#     <li>5th: The feature Subset Strategy. There are various inputs for this parameter, but for the sake of this section we will set <b>featureSubsetStrategy</b> equal to <b>"auto"</b></li>
#     <li>6th: The type of impurity. Since we're dealing with <b>Classification</b>, we will be have <b>impurity</b> set to <b>'gini'</b></li>
#     <li>7th: The maximum depth of the tree. For now, set <b>maxDepth</b> to <b>5</b>, which is the default value</li>
#     <li>8th: The maximum number of bins. For now, set <b>maxBins</b> to <b>32</b>, which is the default value</li>
#     <li>9th: The seed to generate random data. For now, set <b>seed</b> to <b>None</b></li>
# </ul> <br> <br>
#
# We will also be timing how long it takes to create the model, so run <b>start = time.time()</b> before creating the model and <b>print(time.time()-start)</b> after the model has been created. <br>
# <b>Note</b>: The timings differ on run and by computer, therefore some statements throughout the lab may not directly align with the results you get, which is okay! There are many factors that can affect the time output.

# %%
start = time.time()
classRF_model = RandomForest.trainClassifier(classRF_train, numClasses = 10, categoricalFeaturesInfo={},
                                           featureSubsetStrategy="auto", numTrees=3,
                                           impurity='gini', maxDepth=4, maxBins=32, seed=None)
print (time.time()-start)
# Out:
# 1.26477193832

# %% [markdown]
# Next, we want to get the models prediction on the test data, which we will call <b>classRF_pred</b>. We will run <b>.predict</b> on classRF_model, passing in the testing data, <b>classRF_test</b> that is mapped using <b>.map</b> which maps the features using a lambda function (<b>lambda x: x.features</b>).

# %%
classRF_pred = classRF_model.predict(classRF_test.map(lambda x: x.features))

# %% [markdown]
# Now create a variable called <b>classRF_label_pred</b> which uses a <b>.map</b> on <b>classRF_test</b>. Pass <b>lambda l: l.label</b> into the mapping function. Outside of the mapping function, add a <b>.zip(classRF_pred)</b>. This will merge the label with the prediction</b>

# %%
classRF_label_pred = classRF_test.map(lambda l: l.label).zip(classRF_pred)

# %% [markdown]
# Now we will calculate the Test Error for this prediction, which we will call <b>classRF_error</b>. This will equate to <b>classRF_label_pred.filter(lambda (v, p): v != p).count() / float(classRF_test.count())</b>, which will count the number of incorrectly predicted values and divide it by the total number of predictions.

# %%
classRF_error = classRF_label_pred.filter(lambda (v, p): v != p).count() / float(classRF_test.count())

# %% [markdown]
# Next, print out the test error value (<b>str(classRF_error)</b>, as well as the learned regression tree model (<b>classRF_model.toDebugString()</b>), so you have an idea of what the ensemble looks like.

# %%
print('Test Error = ' + str(classRF_error))
print('Learned classification tree model:' + classRF_model.toDebugString())
# Out:
# Test Error = 0.495921914694
# Learned classification tree model:TreeEnsembleModel classifier with 3 trees
#
#   Tree 0:
#     If (feature 4 <= 2.0)
#      If (feature 5 <= 1.0)
#       If (feature 7 <= 1.0)
#        If (feature 3 <= 1.0)
#         Predict: 3.0
#        Else (feature 3 > 1.0)
#         Predict: 1.0
#       Else (feature 7 > 1.0)
#        If (feature 3 <= 1.0)
#         Predict: 1.0
#        Else (feature 3 > 1.0)
#         Predict: 0.0
#      Else (feature 5 > 1.0)
#       If (feature 9 <= 1.0)
#        If (feature 3 <= 1.0)
#         Predict: 1.0
#        Else (feature 3 > 1.0)
#         Predict: 0.0
#       Else (feature 9 > 1.0)
#        If (feature 7 <= 5.0)
#         Predict: 0.0
#        Else (feature 7 > 5.0)
#         Predict: 0.0
#     Else (feature 4 > 2.0)
#      If (feature 0 <= 3.0)
#       If (feature 5 <= 2.0)
#        If (feature 1 <= 2.0)
#         Predict: 1.0
#        Else (feature 1 > 2.0)
#         Predict: 0.0
#       Else (feature 5 > 2.0)
#        If (feature 1 <= 10.0)
#         Predict: 0.0
#        Else (feature 1 > 10.0)
#         Predict: 1.0
#      Else (feature 0 > 3.0)
#       If (feature 9 <= 6.0)
#        If (feature 7 <= 2.0)
#         Predict: 1.0
#        Else (feature 7 > 2.0)
#         Predict: 0.0
#       Else (feature 9 > 6.0)
#        If (feature 7 <= 7.0)
#         Predict: 0.0
#        Else (feature 7 > 7.0)
#         Predict: 0.0
#   Tree 1:
#     If (feature 8 <= 2.0)
#      If (feature 5 <= 1.0)
#       If (feature 1 <= 1.0)
#        If (feature 7 <= 1.0)
#         Predict: 3.0
#        Else (feature 7 > 1.0)
#         Predict: 1.0
#       Else (feature 1 > 1.0)
#        If (feature 1 <= 6.0)
#         Predict: 0.0
#        Else (feature 1 > 6.0)
#         Predict: 1.0
#      Else (feature 5 > 1.0)
#       If (feature 2 <= 1.0)
#        If (feature 7 <= 7.0)
#         Predict: 0.0
#        Else (feature 7 > 7.0)
#         Predict: 0.0
#       Else (feature 2 > 1.0)
#        If (feature 2 <= 3.0)
#         Predict: 0.0
#        Else (feature 2 > 3.0)
#         Predict: 0.0
#     Else (feature 8 > 2.0)
#      If (feature 1 <= 9.0)
#       If (feature 9 <= 7.0)
#        If (feature 5 <= 8.0)
#         Predict: 1.0
#        Else (feature 5 > 8.0)
#         Predict: 0.0
#       Else (feature 9 > 7.0)
#        If (feature 1 <= 7.0)
#         Predict: 0.0
#        Else (feature 1 > 7.0)
#         Predict: 0.0
#      Else (feature 1 > 9.0)
#       If (feature 7 <= 10.0)
#        If (feature 6 <= 1.0)
#         Predict: 0.0
#        Else (feature 6 > 1.0)
#         Predict: 0.0
#       Else (feature 7 > 10.0)
#        If (feature 9 <= 9.0)
#         Predict: 1.0
#        Else (feature 9 > 9.0)
#         Predict: 1.0
#   Tree 2:
#     If (feature 8 <= 2.0)
#      If (feature 1 <= 10.0)
#       If (feature 5 <= 9.0)
#        If (feature 3 <= 10.0)
#         Predict: 1.0
#        Else (feature 3 > 10.0)
#         Predict: 0.0
#       Else (feature 5 > 9.0)
#        If (feature 2 <= 2.0)
#         Predict: 0.0
#        Else (feature 2 > 2.0)
#         Predict: 0.0
#      Else (feature 1 > 10.0)
#       If (feature 3 <= 8.0)
#        If (feature 7 <= 9.0)
#         Predict: 0.0
#        Else (feature 7 > 9.0)
#         Predict: 1.0
#       Else (feature 3 > 8.0)
#        If (feature 7 <= 10.0)
#         Predict: 1.0
#        Else (feature 7 > 10.0)
#         Predict: 1.0
#     Else (feature 8 > 2.0)
#      If (feature 4 <= 2.0)
#       If (feature 9 <= 2.0)
#        If (feature 0 <= 2.0)
#         Predict: 0.0
#        Else (feature 0 > 2.0)
#         Predict: 0.0
#       Else (feature 9 > 2.0)
#        If (feature 7 <= 10.0)
#         Predict: 0.0
#        Else (feature 7 > 10.0)
#         Predict: 1.0
#      Else (feature 4 > 2.0)
#       If (feature 5 <= 11.0)
#        If (feature 0 <= 2.0)
#         Predict: 0.0
#        Else (feature 0 > 2.0)
#         Predict: 0.0
#       Else (feature 5 > 11.0)
#        If (feature 1 <= 11.0)
#         Predict: 0.0
#        Else (feature 1 > 11.0)
#         Predict: 1.0

# %% [markdown]
# Now that we've created the basic Classification Random Forest, let's start tuning some parameters! This is similar to the previous section, but since most of the tuning parameters have been covered in the Decision Tree section, there will only be two parameter to tune in this section. <br> <br>
#
# Read over the code and understand how to build the Classification Random Forest as a whole. For the inputs, we have:
# <ul>
#     <li>1st: numTreesValue is the value for numTrees (Type: Int, Range: > 0, Default: 3)</li>
#     <li>2nd: featureSubsetStrategyValue is the value for featureSubsetStrategyValue (Default: "auto")</li>
#     <ul>
#         <li>Values include: "auto", "all", "sqrt", "log2", "onethird"</li>
#     </ul>
# </ul>

# %%
def classRF_tuner(numTreesValue, featureSubsetStrategyValue):
    start = time.time()
    classRF_model = RandomForest.trainClassifier(classRF_train, numClasses = 10, categoricalFeaturesInfo={},
                                           featureSubsetStrategy=featureSubsetStrategyValue, numTrees=numTreesValue,
                                           impurity='gini', maxDepth=4, maxBins=32, seed=None)
    print (time.time()-start)

    classRF_pred = classRF_model.predict(classRF_test.map(lambda x: x.features))
    classRF_label_pred = classRF_test.map(lambda l: l.label).zip(classRF_pred)
    classRF_error = classRF_label_pred.filter(lambda (v, p): v != p).count() / float(classRF_test.count())
    
    print('Test Error = ' + str(classRF_error))
    print('Learned classification tree model:' + classRF_model.toDebugString())

# %% [markdown]
# Start off by re-creating the original Random Forest. That requires the input: <b>(3)</b> and <b>"auto"</b> into <b>classRF_tuner</b>

# %%
classRF_tuner(3, "auto")
# Out:
# 1.17312097549
# Test Error = 0.488166867228
# Learned classification tree model:TreeEnsembleModel classifier with 3 trees
#
#   Tree 0:
#     If (feature 9 <= 10.0)
#      If (feature 3 <= 10.0)
#       If (feature 7 <= 10.0)
#        If (feature 5 <= 10.0)
#         Predict: 1.0
#        Else (feature 5 > 10.0)
#         Predict: 0.0
#       Else (feature 7 > 10.0)
#        If (feature 1 <= 10.0)
#         Predict: 0.0
#        Else (feature 1 > 10.0)
#         Predict: 1.0
#      Else (feature 3 > 10.0)
#       If (feature 7 <= 11.0)
#        If (feature 3 <= 11.0)
#         Predict: 0.0
#        Else (feature 3 > 11.0)
#         Predict: 0.0
#       Else (feature 7 > 11.0)
#        If (feature 8 <= 2.0)
#         Predict: 1.0
#        Else (feature 8 > 2.0)
#         Predict: 1.0
#     Else (feature 9 > 10.0)
#      If (feature 1 <= 10.0)
#       If (feature 2 <= 3.0)
#        If (feature 8 <= 3.0)
#         Predict: 0.0
#        Else (feature 8 > 3.0)
#         Predict: 0.0
#       Else (feature 2 > 3.0)
#        If (feature 3 <= 6.0)
#         Predict: 0.0
#        Else (feature 3 > 6.0)
#         Predict: 0.0
#      Else (feature 1 > 10.0)
#       If (feature 5 <= 10.0)
#        If (feature 7 <= 10.0)
#         Predict: 0.0
#        Else (feature 7 > 10.0)
#         Predict: 1.0
#       Else (feature 5 > 10.0)
#        If (feature 0 <= 2.0)
#         Predict: 1.0
#        Else (feature 0 > 2.0)
#         Predict: 1.0
#   Tree 1:
#     If (feature 3 <= 2.0)
#      If (feature 9 <= 2.0)
#       If (feature 5 <= 6.0)
#        If (feature 7 <= 9.0)
#         Predict: 1.0
#        Else (feature 7 > 9.0)
#         Predict: 1.0
#       Else (feature 5 > 6.0)
#        If (feature 2 <= 2.0)
#         Predict: 1.0
#        Else (feature 2 > 2.0)
#         Predict: 0.0
#      Else (feature 9 > 2.0)
#       If (feature 7 <= 2.0)
#        If (feature 1 <= 2.0)
#         Predict: 1.0
#        Else (feature 1 > 2.0)
#         Predict: 1.0
#       Else (feature 7 > 2.0)
#        If (feature 5 <= 2.0)
#         Predict: 1.0
#        Else (feature 5 > 2.0)
#         Predict: 0.0
#     Else (feature 3 > 2.0)
#      If (feature 8 <= 2.0)
#       If (feature 8 <= 1.0)
#        If (feature 0 <= 1.0)
#         Predict: 0.0
#        Else (feature 0 > 1.0)
#         Predict: 0.0
#       Else (feature 8 > 1.0)
#        If (feature 7 <= 1.0)
#         Predict: 0.0
#        Else (feature 7 > 1.0)
#         Predict: 0.0
#      Else (feature 8 > 2.0)
#       If (feature 9 <= 2.0)
#        If (feature 7 <= 2.0)
#         Predict: 1.0
#        Else (feature 7 > 2.0)
#         Predict: 0.0
#       Else (feature 9 > 2.0)
#        If (feature 7 <= 2.0)
#         Predict: 0.0
#        Else (feature 7 > 2.0)
#         Predict: 0.0
#   Tree 2:
#     If (feature 7 <= 1.0)
#      If (feature 9 <= 1.0)
#       If (feature 0 <= 3.0)
#        If (feature 5 <= 1.0)
#         Predict: 3.0
#        Else (feature 5 > 1.0)
#         Predict: 1.0
#       Else (feature 0 > 3.0)
#        If (feature 3 <= 7.0)
#         Predict: 2.0
#        Else (feature 3 > 7.0)
#         Predict: 1.0
#      Else (feature 9 > 1.0)
#       If (feature 1 <= 1.0)
#        If (feature 8 <= 2.0)
#         Predict: 2.0
#        Else (feature 8 > 2.0)
#         Predict: 1.0
#       Else (feature 1 > 1.0)
#        If (feature 8 <= 3.0)
#         Predict: 0.0
#        Else (feature 8 > 3.0)
#         Predict: 0.0
#     Else (feature 7 > 1.0)
#      If (feature 1 <= 2.0)
#       If (feature 3 <= 2.0)
#        If (feature 4 <= 3.0)
#         Predict: 1.0
#        Else (feature 4 > 3.0)
#         Predict: 1.0
#       Else (feature 3 > 2.0)
#        If (feature 7 <= 2.0)
#         Predict: 1.0
#        Else (feature 7 > 2.0)
#         Predict: 0.0
#      Else (feature 1 > 2.0)
#       If (feature 7 <= 4.0)
#        If (feature 1 <= 4.0)
#         Predict: 1.0
#        Else (feature 1 > 4.0)
#         Predict: 0.0
#       Else (feature 7 > 4.0)
#        If (feature 3 <= 3.0)
#         Predict: 0.0
#        Else (feature 3 > 3.0)
#         Predict: 0.0

# %% [markdown]
# ### numTrees Parameter
# Let's start by tuning the <b>numTrees</b> parameter. Begin by setting it to a lower value, such as <b>1</b>

# %%
classRF_tuner(1, "auto")
# Out:
# 1.13493800163
# Test Error = 0.500334269287
# Learned classification tree model:TreeEnsembleModel classifier with 1 trees
#
#   Tree 0:
#     If (feature 8 <= 2.0)
#      If (feature 5 <= 1.0)
#       If (feature 7 <= 1.0)
#        If (feature 1 <= 9.0)
#         Predict: 1.0
#        Else (feature 1 > 9.0)
#         Predict: 1.0
#       Else (feature 7 > 1.0)
#        If (feature 9 <= 1.0)
#         Predict: 1.0
#        Else (feature 9 > 1.0)
#         Predict: 0.0
#      Else (feature 5 > 1.0)
#       If (feature 1 <= 10.0)
#        If (feature 5 <= 9.0)
#         Predict: 0.0
#        Else (feature 5 > 9.0)
#         Predict: 0.0
#       Else (feature 1 > 10.0)
#        If (feature 5 <= 10.0)
#         Predict: 0.0
#        Else (feature 5 > 10.0)
#         Predict: 1.0
#     Else (feature 8 > 2.0)
#      If (feature 2 <= 2.0)
#       If (feature 3 <= 2.0)
#        If (feature 9 <= 5.0)
#         Predict: 1.0
#        Else (feature 9 > 5.0)
#         Predict: 0.0
#       Else (feature 3 > 2.0)
#        If (feature 9 <= 2.0)
#         Predict: 0.0
#        Else (feature 9 > 2.0)
#         Predict: 0.0
#      Else (feature 2 > 2.0)
#       If (feature 4 <= 2.0)
#        If (feature 5 <= 4.0)
#         Predict: 0.0
#        Else (feature 5 > 4.0)
#         Predict: 0.0
#       Else (feature 4 > 2.0)
#        If (feature 0 <= 2.0)
#         Predict: 0.0
#        Else (feature 0 > 2.0)
#         Predict: 0.0

# %% [markdown]
# By setting numTrees to a value of 1, we see a slightly higher test error. Note that with numTrees equal to 1, the classifier acts as a Decision Tree, since there is only one tree in the ensemble.

# %% [markdown]
# Now let's try setting it to a numTrees to a larger value, such as 180.

# %%
classRF_tuner(180, "auto")
# Out:
# 4.18126797676
# Test Error = 0.501671346437
# Learned classification tree model:TreeEnsembleModel classifier with 180 trees
#
#   Tree 0:
#     If (feature 0 <= 3.0)
#      If (feature 1 <= 9.0)
#       If (feature 3 <= 10.0)
#        If (feature 9 <= 10.0)
#         Predict: 0.0
#        Else (feature 9 > 10.0)
#         Predict: 0.0
#       Else (feature 3 > 10.0)
#        If (feature 7 <= 10.0)
#         Predict: 0.0
#        Else (feature 7 > 10.0)
#         Predict: 1.0
#      Else (feature 1 > 9.0)
#       If (feature 5 <= 9.0)
#        If (feature 3 <= 7.0)
#         Predict: 0.0
#        Else (feature 3 > 7.0)
#         Predict: 0.0
#       Else (feature 5 > 9.0)
#        If (feature 9 <= 7.0)
#         Predict: 0.0
#        Else (feature 9 > 7.0)
#         Predict: 1.0
#     Else (feature 0 > 3.0)
#      If (feature 4 <= 2.0)
#       If (feature 8 <= 3.0)
#        If (feature 1 <= 6.0)
#         Predict: 0.0
#        Else (feature 1 > 6.0)
#         Predict: 1.0
#       Else (feature 8 > 3.0)
#        If (feature 5 <= 7.0)
#         Predict: 0.0
#        Else (feature 5 > 7.0)
#         Predict: 1.0
#      Else (feature 4 > 2.0)
#       If (feature 3 <= 12.0)
#        If (feature 2 <= 3.0)
#         Predict: 0.0
#        Else (feature 2 > 3.0)
#         Predict: 0.0
#       Else (feature 3 > 12.0)
#        If (feature 5 <= 12.0)
#         Predict: 1.0
#        Else (feature 5 > 12.0)
#         Predict: 1.0
#   Tree 1:
#     If (feature 8 <= 2.0)
#      If (feature 0 <= 3.0)
#       If (feature 6 <= 2.0)
#        If (feature 0 <= 2.0)
#         Predict: 0.0
#        Else (feature 0 > 2.0)
#         Predict: 1.0
#       Else (feature 6 > 2.0)
#        If (feature 7 <= 12.0)
#         Predict: 0.0
#        Else (feature 7 > 12.0)
#         Predict: 1.0
#      Else (feature 0 > 3.0)
#       If (feature 6 <= 3.0)
#        If (feature 8 <= 1.0)
#         Predict: 0.0
#        Else (feature 8 > 1.0)
#         Predict: 1.0
#       Else (feature 6 > 3.0)
#        If (feature 1 <= 8.0)
#         Predict: 0.0
#        Else (feature 1 > 8.0)
#         Predict: 0.0
#     Else (feature 8 > 2.0)
#      If (feature 0 <= 2.0)
#       If (feature 3 <= 4.0)
#        If (feature 1 <= 2.0)
#         Predict: 1.0
#        Else (feature 1 > 2.0)
#         Predict: 0.0
#       Else (feature 3 > 4.0)
#        If (feature 5 <= 2.0)
#         Predict: 0.0
#        Else (feature 5 > 2.0)
#         Predict: 0.0
#      Else (feature 0 > 2.0)
#       If (feature 5 <= 9.0)
#        If (feature 3 <= 9.0)
#         Predict: 0.0
#        Else (feature 3 > 9.0)
#         Predict: 0.0
#       Else (feature 5 > 9.0)
#        If (feature 7 <= 9.0)
#         Predict: 0.0
#        Else (feature 7 > 9.0)
#         Predict: 1.0
#   Tree 2:
#     If (feature 9 <= 6.0)
#      If (feature 3 <= 6.0)
#       If (feature 1 <= 6.0)
#        If (feature 5 <= 6.0)
#         Predict: 1.0
#        Else (feature 5 > 6.0)
#         Predict: 1.0
#       Else (feature 1 > 6.0)
#        If (feature 7 <= 7.0)
#         Predict: 1.0
#        Else (feature 7 > 7.0)
#         Predict: 0.0
#      Else (feature 3 > 6.0)
#       If (feature 6 <= 1.0)
#        If (feature 7 <= 3.0)
#         Predict: 0.0
#        Else (feature 7 > 3.0)
#         Predict: 0.0
#       Else (feature 6 > 1.0)
#        If (feature 7 <= 11.0)
#         Predict: 0.0
#        Else (feature 7 > 11.0)
#         Predict: 1.0
#     Else (feature 9 > 6.0)
#      If (feature 7 <= 5.0)
#       If (feature 9 <= 7.0)
#        If (feature 8 <= 2.0)
#         Predict: 0.0
#        Else (feature 8 > 2.0)
#         Predict: 0.0
#       Else (feature 9 > 7.0)
#        If (feature 1 <= 3.0)
#         Predict: 0.0
#        Else (feature 1 > 3.0)
#         Predict: 0.0
#      Else (feature 7 > 5.0)
#       If (feature 5 <= 6.0)
#        If (feature 5 <= 1.0)
#         Predict: 0.0
#        Else (feature 5 > 1.0)
#         Predict: 0.0
#       Else (feature 5 > 6.0)
#        If (feature 3 <= 7.0)
#         Predict: 0.0
#        Else (feature 3 > 7.0)
#         Predict: 1.0
#   Tree 3:
#     If (feature 1 <= 9.0)
#      If (feature 9 <= 10.0)
#       If (feature 6 <= 2.0)
#        If (feature 3 <= 9.0)
#         Predict: 0.0
#        Else (feature 3 > 9.0)
#         Predict: 0.0
#       Else (feature 6 > 2.0)
#        If (feature 3 <= 10.0)
#         Predict: 0.0
#        Else (feature 3 > 10.0)
#         Predict: 0.0
#      Else (feature 9 > 10.0)
#       If (feature 3 <= 10.0)
#        If (feature 5 <= 1.0)
#         Predict: 1.0
#        Else (feature 5 > 1.0)
#         Predict: 0.0
#       Else (feature 3 > 10.0)
#        If (feature 4 <= 2.0)
#         Predict: 0.0
#        Else (feature 4 > 2.0)
#         Predict: 1.0
#     Else (feature 1 > 9.0)
#      If (feature 7 <= 9.0)
#       If (feature 5 <= 9.0)
#        If (feature 4 <= 3.0)
#         Predict: 0.0
#        Else (feature 4 > 3.0)
#         Predict: 0.0
#       Else (feature 5 > 9.0)
#        If (feature 1 <= 10.0)
#         Predict: 0.0
#        Else (feature 1 > 10.0)
#         Predict: 1.0
#      Else (feature 7 > 9.0)
#       If (feature 5 <= 9.0)
#        If (feature 9 <= 9.0)
#         Predict: 0.0
#        Else (feature 9 > 9.0)
#         Predict: 1.0
#       Else (feature 5 > 9.0)
#        If (feature 4 <= 3.0)
#         Predict: 1.0
#        Else (feature 4 > 3.0)
#         Predict: 1.0
#   Tree 4:
#     If (feature 5 <= 1.0)
#      If (feature 9 <= 1.0)
#       If (feature 1 <= 1.0)
#        Predict: 3.0
#       Else (feature 1 > 1.0)
#        If (feature 3 <= 1.0)
#         Predict: 3.0
#        Else (feature 3 > 1.0)
#         Predict: 1.0
#      Else (feature 9 > 1.0)
#       If (feature 1 <= 1.0)
#        If (feature 9 <= 12.0)
#         Predict: 1.0
#        Else (feature 9 > 12.0)
#         Predict: 3.0
#       Else (feature 1 > 1.0)
#        If (feature 8 <= 3.0)
#         Predict: 0.0
#        Else (feature 8 > 3.0)
#         Predict: 0.0
#     Else (feature 5 > 1.0)
#      If (feature 4 <= 2.0)
#       If (feature 5 <= 8.0)
#        If (feature 7 <= 6.0)
#         Predict: 1.0
#        Else (feature 7 > 6.0)
#         Predict: 0.0
#       Else (feature 5 > 8.0)
#        If (feature 7 <= 8.0)
#         Predict: 0.0
#        Else (feature 7 > 8.0)
#         Predict: 1.0
#      Else (feature 4 > 2.0)
#       If (feature 1 <= 10.0)
#        If (feature 5 <= 11.0)
#         Predict: 0.0
#        Else (feature 5 > 11.0)
#         Predict: 0.0
#       Else (feature 1 > 10.0)
#        If (feature 9 <= 5.0)
#         Predict: 0.0
#        Else (feature 9 > 5.0)
#         Predict: 1.0
#   Tree 5:
#     If (feature 3 <= 2.0)
#      If (feature 7 <= 2.0)
#       If (feature 2 <= 3.0)
#        If (feature 5 <= 7.0)
#         Predict: 1.0
#        Else (feature 5 > 7.0)
#         Predict: 1.0
#       Else (feature 2 > 3.0)
#        If (feature 5 <= 2.0)
#         Predict: 1.0
#        Else (feature 5 > 2.0)
#         Predict: 0.0
#      Else (feature 7 > 2.0)
#       If (feature 6 <= 2.0)
#        If (feature 5 <= 3.0)
#         Predict: 1.0
#        Else (feature 5 > 3.0)
#         Predict: 0.0
#       Else (feature 6 > 2.0)
#        If (feature 1 <= 2.0)
#         Predict: 1.0
#        Else (feature 1 > 2.0)
#         Predict: 0.0
#     Else (feature 3 > 2.0)
#      If (feature 9 <= 2.0)
#       If (feature 5 <= 2.0)
#        If (feature 6 <= 1.0)
#         Predict: 0.0
#        Else (feature 6 > 1.0)
#         Predict: 1.0
#       Else (feature 5 > 2.0)
#        If (feature 5 <= 12.0)
#         Predict: 0.0
#        Else (feature 5 > 12.0)
#         Predict: 0.0
#      Else (feature 9 > 2.0)
#       If (feature 7 <= 2.0)
#        If (feature 2 <= 3.0)
#         Predict: 0.0
#        Else (feature 2 > 3.0)
#         Predict: 0.0
#       Else (feature 7 > 2.0)
#        If (feature 7 <= 10.0)
#         Predict: 0.0
#        Else (feature 7 > 10.0)
#         Predict: 0.0
#   Tree 6:
#     If (feature 8 <= 2.0)
#      If (feature 7 <= 7.0)
#       If (feature 9 <= 4.0)
#        If (feature 3 <= 3.0)
#         Predict: 1.0
#        Else (feature 3 > 3.0)
#         Predict: 0.0
#       Else (feature 9 > 4.0)
#        If (feature 7 <= 5.0)
#         Predict: 0.0
#        Else (feature 7 > 5.0)
#         Predict: 1.0
#      Else (feature 7 > 7.0)
#       If (feature 3 <= 7.0)
#        If (feature 1 <= 1.0)
#         Predict: 0.0
#        Else (feature 1 > 1.0)
#         Predict: 0.0
#       Else (feature 3 > 7.0)
#        If (feature 1 <= 7.0)
#         Predict: 0.0
#        Else (feature 1 > 7.0)
#         Predict: 1.0
#     Else (feature 8 > 2.0)
#      If (feature 9 <= 10.0)
#       If (feature 5 <= 11.0)
#        If (feature 5 <= 10.0)
#         Predict: 0.0
#        Else (feature 5 > 10.0)
#         Predict: 1.0
#       Else (feature 5 > 11.0)
#        If (feature 7 <= 10.0)
#         Predict: 0.0
#        Else (feature 7 > 10.0)
#         Predict: 1.0
#      Else (feature 9 > 10.0)
#       If (feature 7 <= 10.0)
#        If (feature 7 <= 7.0)
#         Predict: 0.0
#        Else (feature 7 > 7.0)
#         Predict: 0.0
#       Else (feature 7 > 10.0)
#        If (feature 4 <= 1.0)
#         Predict: 0.0
#        Else (feature 4 > 1.0)
#         Predict: 1.0
#   Tree 7:
#     If (feature 9 <= 10.0)
#      If (feature 7 <= 1.0)
#       If (feature 9 <= 1.0)
#        If (feature 4 <= 3.0)
#         Predict: 1.0
#        Else (feature 4 > 3.0)
#         Predict: 1.0
#       Else (feature 9 > 1.0)
#        If (feature 5 <= 1.0)
#         Predict: 1.0
#        Else (feature 5 > 1.0)
#         Predict: 0.0
#      Else (feature 7 > 1.0)
#       If (feature 3 <= 10.0)
#        If (feature 5 <= 11.0)
#         Predict: 0.0
#        Else (feature 5 > 11.0)
#         Predict: 0.0
#       Else (feature 3 > 10.0)
#        If (feature 5 <= 10.0)
#         Predict: 0.0
#        Else (feature 5 > 10.0)
#         Predict: 1.0
#     Else (feature 9 > 10.0)
#      If (feature 7 <= 10.0)
#       If (feature 3 <= 10.0)
#        If (feature 1 <= 8.0)
#         Predict: 0.0
#        Else (feature 1 > 8.0)
#         Predict: 0.0
#       Else (feature 3 > 10.0)
#        If (feature 6 <= 2.0)
#         Predict: 1.0
#        Else (feature 6 > 2.0)
#         Predict: 0.0
#      Else (feature 7 > 10.0)
#       If (feature 3 <= 9.0)
#        If (feature 6 <= 3.0)
#         Predict: 1.0
#        Else (feature 6 > 3.0)
#         Predict: 0.0
#       Else (feature 3 > 9.0)
#        If (feature 9 <= 11.0)
#         Predict: 1.0
#        Else (feature 9 > 11.0)
#         Predict: 1.0
#   Tree 8:
#     If (feature 7 <= 1.0)
#      If (feature 1 <= 1.0)
#       If (feature 3 <= 1.0)
#        If (feature 9 <= 7.0)
#         Predict: 3.0
#        Else (feature 9 > 7.0)
#         Predict: 3.0
#       Else (feature 3 > 1.0)
#        If (feature 6 <= 3.0)
#         Predict: 1.0
#        Else (feature 6 > 3.0)
#         Predict: 1.0
#      Else (feature 1 > 1.0)
#       If (feature 9 <= 1.0)
#        If (feature 0 <= 3.0)
#         Predict: 1.0
#        Else (feature 0 > 3.0)
#         Predict: 2.0
#       Else (feature 9 > 1.0)
#        If (feature 3 <= 1.0)
#         Predict: 1.0
#        Else (feature 3 > 1.0)
#         Predict: 0.0
#     Else (feature 7 > 1.0)
#      If (feature 3 <= 1.0)
#       If (feature 9 <= 1.0)
#        If (feature 5 <= 1.0)
#         Predict: 3.0
#        Else (feature 5 > 1.0)
#         Predict: 1.0
#       Else (feature 9 > 1.0)
#        If (feature 5 <= 1.0)
#         Predict: 1.0
#        Else (feature 5 > 1.0)
#         Predict: 0.0
#      Else (feature 3 > 1.0)
#       If (feature 5 <= 1.0)
#        If (feature 4 <= 2.0)
#         Predict: 0.0
#        Else (feature 4 > 2.0)
#         Predict: 0.0
#       Else (feature 5 > 1.0)
#        If (feature 0 <= 3.0)
#         Predict: 0.0
#        Else (feature 0 > 3.0)
#         Predict: 0.0
#   Tree 9:
#     If (feature 1 <= 9.0)
#      If (feature 5 <= 9.0)
#       If (feature 7 <= 9.0)
#        If (feature 3 <= 9.0)
#         Predict: 1.0
#        Else (feature 3 > 9.0)
#         Predict: 0.0
#       Else (feature 7 > 9.0)
#        If (feature 9 <= 7.0)
#         Predict: 0.0
#        Else (feature 9 > 7.0)
#         Predict: 0.0
#      Else (feature 5 > 9.0)
#       If (feature 3 <= 4.0)
#        If (feature 7 <= 11.0)
#         Predict: 0.0
#        Else (feature 7 > 11.0)
#         Predict: 0.0
#       Else (feature 3 > 4.0)
#        If (feature 3 <= 11.0)
#         Predict: 0.0
#        Else (feature 3 > 11.0)
#         Predict: 0.0
#     Else (feature 1 > 9.0)
#      If (feature 5 <= 9.0)
#       If (feature 8 <= 2.0)
#        If (feature 9 <= 9.0)
#         Predict: 0.0
#        Else (feature 9 > 9.0)
#         Predict: 1.0
#       Else (feature 8 > 2.0)
#        If (feature 9 <= 2.0)
#         Predict: 0.0
#        Else (feature 9 > 2.0)
#         Predict: 0.0
#      Else (feature 5 > 9.0)
#       If (feature 3 <= 9.0)
#        If (feature 9 <= 9.0)
#         Predict: 0.0
#        Else (feature 9 > 9.0)
#         Predict: 1.0
#       Else (feature 3 > 9.0)
#        If (feature 7 <= 9.0)
#         Predict: 1.0
#        Else (feature 7 > 9.0)
#         Predict: 1.0
#   Tree 10:
#     If (feature 3 <= 2.0)
#      If (feature 9 <= 2.0)
#       If (feature 5 <= 6.0)
#        If (feature 5 <= 1.0)
#         Predict: 1.0
#        Else (feature 5 > 1.0)
#         Predict: 1.0
#       Else (feature 5 > 6.0)
#        If (feature 8 <= 2.0)
#         Predict: 0.0
#        Else (feature 8 > 2.0)
#         Predict: 1.0
#      Else (feature 9 > 2.0)
#       If (feature 5 <= 2.0)
#        If (feature 9 <= 10.0)
#         Predict: 1.0
#        Else (feature 9 > 10.0)
#         Predict: 1.0
#       Else (feature 5 > 2.0)
#        If (feature 1 <= 2.0)
#         Predict: 1.0
#        Else (feature 1 > 2.0)
#         Predict: 0.0
#     Else (feature 3 > 2.0)
#      If (feature 1 <= 2.0)
#       If (feature 5 <= 2.0)
#        If (feature 7 <= 3.0)
#         Predict: 1.0
#        Else (feature 7 > 3.0)
#         Predict: 1.0
#       Else (feature 5 > 2.0)
#        If (feature 7 <= 2.0)
#         Predict: 1.0
#        Else (feature 7 > 2.0)
#         Predict: 0.0
#      Else (feature 1 > 2.0)
#       If (feature 9 <= 2.0)
#        If (feature 7 <= 2.0)
#         Predict: 1.0
#        Else (feature 7 > 2.0)
#         Predict: 0.0
#       Else (feature 9 > 2.0)
#        If (feature 5 <= 2.0)
#         Predict: 0.0
#        Else (feature 5 > 2.0)
#         Predict: 0.0
#   Tree 11:
#     If (feature 1 <= 10.0)
#      If (feature 3 <= 11.0)
#       If (feature 7 <= 11.0)
#        If (feature 9 <= 11.0)
#         Predict: 1.0
#        Else (feature 9 > 11.0)
#         Predict: 0.0
#       Else (feature 7 > 11.0)
#        If (feature 5 <= 11.0)
#         Predict: 0.0
#        Else (feature 5 > 11.0)
#         Predict: 1.0
#      Else (feature 3 > 11.0)
#       If (feature 9 <= 11.0)
#        If (feature 6 <= 2.0)
#         Predict: 0.0
#        Else (feature 6 > 2.0)
#         Predict: 0.0
#       Else (feature 9 > 11.0)
#        If (feature 5 <= 11.0)
#         Predict: 1.0
#        Else (feature 5 > 11.0)
#         Predict: 1.0
#     Else (feature 1 > 10.0)
#      If (feature 7 <= 10.0)
#       If (feature 2 <= 2.0)
#        If (feature 5 <= 10.0)
#         Predict: 0.0
#        Else (feature 5 > 10.0)
#         Predict: 1.0
#       Else (feature 2 > 2.0)
#        If (feature 3 <= 9.0)
#         Predict: 0.0
#        Else (feature 3 > 9.0)
#         Predict: 0.0
#      Else (feature 7 > 10.0)
#       If (feature 9 <= 10.0)
#        If (feature 1 <= 11.0)
#         Predict: 0.0
#        Else (feature 1 > 11.0)
#         Predict: 1.0
#       Else (feature 9 > 10.0)
#        If (feature 5 <= 8.0)
#         Predict: 1.0
#        Else (feature 5 > 8.0)
#         Predict: 1.0
#   Tree 12:
#     If (feature 1 <= 10.0)
#      If (feature 5 <= 9.0)
#       If (feature 7 <= 9.0)
#        If (feature 9 <= 9.0)
#         Predict: 1.0
#        Else (feature 9 > 9.0)
#         Predict: 0.0
#       Else (feature 7 > 9.0)
#        If (feature 9 <= 8.0)
#         Predict: 0.0
#        Else (feature 9 > 8.0)
#         Predict: 0.0
#      Else (feature 5 > 9.0)
#       If (feature 1 <= 9.0)
#        If (feature 7 <= 9.0)
#         Predict: 0.0
#        Else (feature 7 > 9.0)
#         Predict: 0.0
#       Else (feature 1 > 9.0)
#        If (feature 5 <= 10.0)
#         Predict: 1.0
#        Else (feature 5 > 10.0)
#         Predict: 0.0
#     Else (feature 1 > 10.0)
#      If (feature 6 <= 3.0)
#       If (feature 9 <= 10.0)
#        If (feature 5 <= 10.0)
#         Predict: 0.0
#        Else (feature 5 > 10.0)
#         Predict: 1.0
#       Else (feature 9 > 10.0)
#        If (feature 7 <= 10.0)
#         Predict: 1.0
#        Else (feature 7 > 10.0)
#         Predict: 1.0
#      Else (feature 6 > 3.0)
#       If (feature 3 <= 10.0)
#        If (feature 4 <= 1.0)
#         Predict: 1.0
#        Else (feature 4 > 1.0)
#         Predict: 0.0
#       Else (feature 3 > 10.0)
#        If (feature 5 <= 10.0)
#         Predict: 0.0
#        Else (feature 5 > 10.0)
#         Predict: 1.0
#   Tree 13:
#     If (feature 3 <= 2.0)
#      If (feature 9 <= 2.0)
#       If (feature 1 <= 2.0)
#        If (feature 7 <= 1.0)
#         Predict: 2.0
#        Else (feature 7 > 1.0)
#         Predict: 1.0
#       Else (feature 1 > 2.0)
#        If (feature 5 <= 6.0)
#         Predict: 1.0
#        Else (feature 5 > 6.0)
#         Predict: 1.0
#      Else (feature 9 > 2.0)
#       If (feature 5 <= 2.0)
#        If (feature 2 <= 1.0)
#         Predict: 1.0
#        Else (feature 2 > 1.0)
#         Predict: 1.0
#       Else (feature 5 > 2.0)
#        If (feature 7 <= 2.0)
#         Predict: 1.0
#        Else (feature 7 > 2.0)
#         Predict: 0.0
#     Else (feature 3 > 2.0)
#      If (feature 8 <= 2.0)
#       If (feature 1 <= 7.0)
#        If (feature 7 <= 7.0)
#         Predict: 0.0
#        Else (feature 7 > 7.0)
#         Predict: 0.0
#       Else (feature 1 > 7.0)
#        If (feature 7 <= 9.0)
#         Predict: 0.0
#        Else (feature 7 > 9.0)
#         Predict: 1.0
#      Else (feature 8 > 2.0)
#       If (feature 0 <= 2.0)
#        If (feature 3 <= 3.0)
#         Predict: 0.0
#        Else (feature 3 > 3.0)
#         Predict: 0.0
#       Else (feature 0 > 2.0)
#        If (feature 2 <= 2.0)
#         Predict: 0.0
#        Else (feature 2 > 2.0)
#         Predict: 0.0
#   Tree 14:
#     If (feature 3 <= 8.0)
#      If (feature 7 <= 7.0)
#       If (feature 1 <= 8.0)
#        If (feature 5 <= 8.0)
#         Predict: 1.0
#        Else (feature 5 > 8.0)
#         Predict: 0.0
#       Else (feature 1 > 8.0)
#        If (feature 3 <= 2.0)
#         Predict: 1.0
#        Else (feature 3 > 2.0)
#         Predict: 0.0
#      Else (feature 7 > 7.0)
#       If (feature 7 <= 12.0)
#        If (feature 3 <= 7.0)
#         Predict: 0.0
#        Else (feature 3 > 7.0)
#         Predict: 1.0
#       Else (feature 7 > 12.0)
#        If (feature 9 <= 12.0)
#         Predict: 0.0
#        Else (feature 9 > 12.0)
#         Predict: 1.0
#     Else (feature 3 > 8.0)
#      If (feature 7 <= 8.0)
#       If (feature 9 <= 8.0)
#        If (feature 5 <= 8.0)
#         Predict: 0.0
#        Else (feature 5 > 8.0)
#         Predict: 0.0
#       Else (feature 9 > 8.0)
#        If (feature 5 <= 8.0)
#         Predict: 0.0
#        Else (feature 5 > 8.0)
#         Predict: 1.0
#      Else (feature 7 > 8.0)
#       If (feature 8 <= 2.0)
#        If (feature 1 <= 8.0)
#         Predict: 0.0
#        Else (feature 1 > 8.0)
#         Predict: 1.0
#       Else (feature 8 > 2.0)
#        If (feature 1 <= 9.0)
#         Predict: 0.0
#        Else (feature 1 > 9.0)
#         Predict: 1.0
#   Tree 15:
#     If (feature 3 <= 11.0)
#      If (feature 5 <= 11.0)
#       If (feature 7 <= 12.0)
#        If (feature 5 <= 5.0)
#         Predict: 0.0
#        Else (feature 5 > 5.0)
#         Predict: 0.0
#       Else (feature 7 > 12.0)
#        If (feature 9 <= 12.0)
#         Predict: 0.0
#        Else (feature 9 > 12.0)
#         Predict: 1.0
#      Else (feature 5 > 11.0)
#       If (feature 1 <= 11.0)
#        If (feature 9 <= 11.0)
#         Predict: 0.0
#        Else (feature 9 > 11.0)
#         Predict: 1.0
#       Else (feature 1 > 11.0)
#        If (feature 9 <= 11.0)
#         Predict: 1.0
#        Else (feature 9 > 11.0)
#         Predict: 1.0
#     Else (feature 3 > 11.0)
#      If (feature 7 <= 11.0)
#       If (feature 0 <= 2.0)
#        If (feature 5 <= 11.0)
#         Predict: 0.0
#        Else (feature 5 > 11.0)
#         Predict: 1.0
#       Else (feature 0 > 2.0)
#        If (feature 8 <= 3.0)
#         Predict: 0.0
#        Else (feature 8 > 3.0)
#         Predict: 0.0
#      Else (feature 7 > 11.0)
#       If (feature 9 <= 11.0)
#        If (feature 8 <= 2.0)
#         Predict: 1.0
#        Else (feature 8 > 2.0)
#         Predict: 0.0
#       Else (feature 9 > 11.0)
#        If (feature 6 <= 2.0)
#         Predict: 1.0
#        Else (feature 6 > 2.0)
#         Predict: 1.0
#   Tree 16:
#     If (feature 9 <= 10.0)
#      If (feature 7 <= 10.0)
#       If (feature 5 <= 10.0)
#        If (feature 1 <= 10.0)
#         Predict: 1.0
#        Else (feature 1 > 10.0)
#         Predict: 0.0
#       Else (feature 5 > 10.0)
#        If (feature 1 <= 10.0)
#         Predict: 0.0
#        Else (feature 1 > 10.0)
#         Predict: 0.0
#      Else (feature 7 > 10.0)
#       If (feature 6 <= 1.0)
#        If (feature 5 <= 10.0)
#         Predict: 0.0
#        Else (feature 5 > 10.0)
#         Predict: 0.0
#       Else (feature 6 > 1.0)
#        If (feature 3 <= 9.0)
#         Predict: 0.0
#        Else (feature 3 > 9.0)
#         Predict: 1.0
#     Else (feature 9 > 10.0)
#      If (feature 8 <= 2.0)
#       If (feature 1 <= 9.0)
#        If (feature 5 <= 11.0)
#         Predict: 0.0
#        Else (feature 5 > 11.0)
#         Predict: 1.0
#       Else (feature 1 > 9.0)
#        If (feature 1 <= 12.0)
#         Predict: 1.0
#        Else (feature 1 > 12.0)
#         Predict: 0.0
#      Else (feature 8 > 2.0)
#       If (feature 5 <= 10.0)
#        If (feature 3 <= 5.0)
#         Predict: 0.0
#        Else (feature 3 > 5.0)
#         Predict: 0.0
#       Else (feature 5 > 10.0)
#        If (feature 7 <= 10.0)
#         Predict: 0.0
#        Else (feature 7 > 10.0)
#         Predict: 1.0
#   Tree 17:
#     If (feature 1 <= 7.0)
#      If (feature 7 <= 9.0)
#       If (feature 9 <= 9.0)
#        If (feature 2 <= 3.0)
#         Predict: 1.0
#        Else (feature 2 > 3.0)
#         Predict: 0.0
#       Else (feature 9 > 9.0)
#        If (feature 6 <= 3.0)
#         Predict: 0.0
#        Else (feature 6 > 3.0)
#         Predict: 0.0
#      Else (feature 7 > 9.0)
#       If (feature 5 <= 9.0)
#        If (feature 0 <= 2.0)
#         Predict: 0.0
#        Else (feature 0 > 2.0)
#         Predict: 0.0
#       Else (feature 5 > 9.0)
#        If (feature 9 <= 9.0)
#         Predict: 0.0
#        Else (feature 9 > 9.0)
#         Predict: 1.0
#     Else (feature 1 > 7.0)
#      If (feature 5 <= 7.0)
#       If (feature 0 <= 1.0)
#        If (feature 9 <= 2.0)
#         Predict: 0.0
#        Else (feature 9 > 2.0)
#         Predict: 0.0
#       Else (feature 0 > 1.0)
#        If (feature 6 <= 3.0)
#         Predict: 0.0
#        Else (feature 6 > 3.0)
#         Predict: 0.0
#      Else (feature 5 > 7.0)
#       If (feature 7 <= 7.0)
#        If (feature 9 <= 6.0)
#         Predict: 0.0
#        Else (feature 9 > 6.0)
#         Predict: 0.0
#       Else (feature 7 > 7.0)
#        If (feature 9 <= 7.0)
#         Predict: 0.0
#        Else (feature 9 > 7.0)
#         Predict: 1.0
#   Tree 18:
#     If (feature 3 <= 5.0)
#      If (feature 5 <= 5.0)
#       If (feature 7 <= 4.0)
#        If (feature 9 <= 5.0)
#         Predict: 1.0
#        Else (feature 9 > 5.0)
#         Predict: 1.0
#       Else (feature 7 > 4.0)
#        If (feature 9 <= 5.0)
#         Predict: 1.0
#        Else (feature 9 > 5.0)
#         Predict: 0.0
#      Else (feature 5 > 5.0)
#       If (feature 4 <= 2.0)
#        If (feature 1 <= 12.0)
#         Predict: 0.0
#        Else (feature 1 > 12.0)
#         Predict: 0.0
#       Else (feature 4 > 2.0)
#        If (feature 9 <= 11.0)
#         Predict: 0.0
#        Else (feature 9 > 11.0)
#         Predict: 0.0
#     Else (feature 3 > 5.0)
#      If (feature 7 <= 5.0)
#       If (feature 5 <= 4.0)
#        If (feature 6 <= 2.0)
#         Predict: 1.0
#        Else (feature 6 > 2.0)
#         Predict: 0.0
#       Else (feature 5 > 4.0)
#        If (feature 4 <= 1.0)
#         Predict: 0.0
#        Else (feature 4 > 1.0)
#         Predict: 0.0
#      Else (feature 7 > 5.0)
#       If (feature 2 <= 3.0)
#        If (feature 7 <= 6.0)
#         Predict: 1.0
#        Else (feature 7 > 6.0)
#         Predict: 0.0
#       Else (feature 2 > 3.0)
#        If (feature 3 <= 10.0)
#         Predict: 0.0
#        Else (feature 3 > 10.0)
#         Predict: 0.0
#   Tree 19:
#     If (feature 9 <= 12.0)
#      If (feature 5 <= 12.0)
#       If (feature 7 <= 12.0)
#        If (feature 7 <= 1.0)
#         Predict: 1.0
#        Else (feature 7 > 1.0)
#         Predict: 0.0
#       Else (feature 7 > 12.0)
#        If (feature 3 <= 12.0)
#         Predict: 0.0
#        Else (feature 3 > 12.0)
#         Predict: 1.0
#      Else (feature 5 > 12.0)
#       If (feature 8 <= 1.0)
#        If (feature 3 <= 12.0)
#         Predict: 0.0
#        Else (feature 3 > 12.0)
#         Predict: 1.0
#       Else (feature 8 > 1.0)
#        If (feature 1 <= 12.0)
#         Predict: 0.0
#        Else (feature 1 > 12.0)
#         Predict: 1.0
#     Else (feature 9 > 12.0)
#      If (feature 3 <= 12.0)
#       If (feature 7 <= 12.0)
#        If (feature 5 <= 12.0)
#         Predict: 0.0
#        Else (feature 5 > 12.0)
#         Predict: 1.0
#       Else (feature 7 > 12.0)
#        If (feature 3 <= 3.0)
#         Predict: 1.0
#        Else (feature 3 > 3.0)
#         Predict: 1.0
#      Else (feature 3 > 12.0)
#       If (feature 5 <= 12.0)
#        If (feature 5 <= 9.0)
#         Predict: 1.0
#        Else (feature 5 > 9.0)
#         Predict: 1.0
#       Else (feature 5 > 12.0)
#        Predict: 3.0
#   Tree 20:
#     If (feature 5 <= 4.0)
#      If (feature 9 <= 4.0)
#       If (feature 3 <= 4.0)
#        If (feature 4 <= 1.0)
#         Predict: 1.0
#        Else (feature 4 > 1.0)
#         Predict: 1.0
#       Else (feature 3 > 4.0)
#        If (feature 7 <= 3.0)
#         Predict: 1.0
#        Else (feature 7 > 3.0)
#         Predict: 0.0
#      Else (feature 9 > 4.0)
#       If (feature 7 <= 4.0)
#        If (feature 1 <= 4.0)
#         Predict: 1.0
#        Else (feature 1 > 4.0)
#         Predict: 0.0
#       Else (feature 7 > 4.0)
#        If (feature 4 <= 2.0)
#         Predict: 0.0
#        Else (feature 4 > 2.0)
#         Predict: 0.0
#     Else (feature 5 > 4.0)
#      If (feature 7 <= 4.0)
#       If (feature 3 <= 4.0)
#        If (feature 9 <= 4.0)
#         Predict: 1.0
#        Else (feature 9 > 4.0)
#         Predict: 0.0
#       Else (feature 3 > 4.0)
#        If (feature 2 <= 1.0)
#         Predict: 0.0
#        Else (feature 2 > 1.0)
#         Predict: 0.0
#      Else (feature 7 > 4.0)
#       If (feature 1 <= 4.0)
#        If (feature 9 <= 11.0)
#         Predict: 0.0
#        Else (feature 9 > 11.0)
#         Predict: 0.0
#       Else (feature 1 > 4.0)
#        If (feature 9 <= 4.0)
#         Predict: 0.0
#        Else (feature 9 > 4.0)
#         Predict: 1.0
#   Tree 21:
#     If (feature 4 <= 2.0)
#      If (feature 5 <= 8.0)
#       If (feature 7 <= 8.0)
#        If (feature 6 <= 2.0)
#         Predict: 0.0
#        Else (feature 6 > 2.0)
#         Predict: 1.0
#       Else (feature 7 > 8.0)
#        If (feature 1 <= 7.0)
#         Predict: 0.0
#        Else (feature 1 > 7.0)
#         Predict: 1.0
#      Else (feature 5 > 8.0)
#       If (feature 7 <= 9.0)
#        If (feature 7 <= 1.0)
#         Predict: 0.0
#        Else (feature 7 > 1.0)
#         Predict: 0.0
#       Else (feature 7 > 9.0)
#        If (feature 1 <= 8.0)
#         Predict: 0.0
#        Else (feature 1 > 8.0)
#         Predict: 1.0
#     Else (feature 4 > 2.0)
#      If (feature 0 <= 2.0)
#       If (feature 5 <= 6.0)
#        If (feature 7 <= 3.0)
#         Predict: 1.0
#        Else (feature 7 > 3.0)
#         Predict: 0.0
#       Else (feature 5 > 6.0)
#        If (feature 7 <= 4.0)
#         Predict: 0.0
#        Else (feature 7 > 4.0)
#         Predict: 1.0
#      Else (feature 0 > 2.0)
#       If (feature 8 <= 3.0)
#        If (feature 6 <= 3.0)
#         Predict: 0.0
#        Else (feature 6 > 3.0)
#         Predict: 0.0
#       Else (feature 8 > 3.0)
#        If (feature 1 <= 12.0)
#         Predict: 0.0
#        Else (feature 1 > 12.0)
#         Predict: 0.0
#   Tree 22:
#     If (feature 7 <= 1.0)
#      If (feature 5 <= 1.0)
#       If (feature 3 <= 1.0)
#        Predict: 3.0
#       Else (feature 3 > 1.0)
#        If (feature 1 <= 1.0)
#         Predict: 3.0
#        Else (feature 1 > 1.0)
#         Predict: 1.0
#      Else (feature 5 > 1.0)
#       If (feature 5 <= 5.0)
#        If (feature 3 <= 6.0)
#         Predict: 1.0
#        Else (feature 3 > 6.0)
#         Predict: 0.0
#       Else (feature 5 > 5.0)
#        If (feature 3 <= 1.0)
#         Predict: 1.0
#        Else (feature 3 > 1.0)
#         Predict: 0.0
#     Else (feature 7 > 1.0)
#      If (feature 1 <= 9.0)
#       If (feature 5 <= 9.0)
#        If (feature 7 <= 9.0)
#         Predict: 0.0
#        Else (feature 7 > 9.0)
#         Predict: 0.0
#       Else (feature 5 > 9.0)
#        If (feature 7 <= 9.0)
#         Predict: 0.0
#        Else (feature 7 > 9.0)
#         Predict: 0.0
#      Else (feature 1 > 9.0)
#       If (feature 3 <= 8.0)
#        If (feature 7 <= 9.0)
#         Predict: 0.0
#        Else (feature 7 > 9.0)
#         Predict: 1.0
#       Else (feature 3 > 8.0)
#        If (feature 9 <= 8.0)
#         Predict: 0.0
#        Else (feature 9 > 8.0)
#         Predict: 1.0
#   Tree 23:
#     If (feature 3 <= 1.0)
#      If (feature 7 <= 1.0)
#       If (feature 2 <= 1.0)
#        If (feature 6 <= 3.0)
#         Predict: 1.0
#        Else (feature 6 > 3.0)
#         Predict: 3.0
#       Else (feature 2 > 1.0)
#        If (feature 5 <= 12.0)
#         Predict: 1.0
#        Else (feature 5 > 12.0)
#         Predict: 2.0
#      Else (feature 7 > 1.0)
#       If (feature 5 <= 1.0)
#        If (feature 9 <= 1.0)
#         Predict: 3.0
#        Else (feature 9 > 1.0)
#         Predict: 1.0
#       Else (feature 5 > 1.0)
#        If (feature 4 <= 1.0)
#         Predict: 0.0
#        Else (feature 4 > 1.0)
#         Predict: 0.0
#     Else (feature 3 > 1.0)
#      If (feature 1 <= 11.0)
#       If (feature 9 <= 11.0)
#        If (feature 3 <= 11.0)
#         Predict: 0.0
#        Else (feature 3 > 11.0)
#         Predict: 0.0
#       Else (feature 9 > 11.0)
#        If (feature 5 <= 11.0)
#         Predict: 0.0
#        Else (feature 5 > 11.0)
#         Predict: 1.0
#      Else (feature 1 > 11.0)
#       If (feature 7 <= 10.0)
#        If (feature 3 <= 12.0)
#         Predict: 0.0
#        Else (feature 3 > 12.0)
#         Predict: 1.0
#       Else (feature 7 > 10.0)
#        If (feature 3 <= 8.0)
#         Predict: 0.0
#        Else (feature 3 > 8.0)
#         Predict: 1.0
#   Tree 24:
#     If (feature 3 <= 2.0)
#      If (feature 9 <= 2.0)
#       If (feature 5 <= 10.0)
#        If (feature 5 <= 5.0)
#         Predict: 1.0
#        Else (feature 5 > 5.0)
#         Predict: 1.0
#       Else (feature 5 > 10.0)
#        If (feature 0 <= 2.0)
#         Predict: 1.0
#        Else (feature 0 > 2.0)
#         Predict: 0.0
#      Else (feature 9 > 2.0)
#       If (feature 0 <= 1.0)
#        If (feature 5 <= 6.0)
#         Predict: 1.0
#        Else (feature 5 > 6.0)
#         Predict: 0.0
#       Else (feature 0 > 1.0)
#        If (feature 5 <= 2.0)
#         Predict: 1.0
#        Else (feature 5 > 2.0)
#         Predict: 0.0
#     Else (feature 3 > 2.0)
#      If (feature 1 <= 3.0)
#       If (feature 3 <= 3.0)
#        If (feature 5 <= 4.0)
#         Predict: 1.0
#        Else (feature 5 > 4.0)
#         Predict: 0.0
#       Else (feature 3 > 3.0)
#        If (feature 7 <= 3.0)
#         Predict: 1.0
#        Else (feature 7 > 3.0)
#         Predict: 0.0
#      Else (feature 1 > 3.0)
#       If (feature 9 <= 2.0)
#        If (feature 0 <= 1.0)
#         Predict: 0.0
#        Else (feature 0 > 1.0)
#         Predict: 0.0
#       Else (feature 9 > 2.0)
#        If (feature 1 <= 4.0)
#         Predict: 1.0
#        Else (feature 1 > 4.0)
#         Predict: 0.0
#   Tree 25:
#     If (feature 3 <= 2.0)
#      If (feature 5 <= 2.0)
#       If (feature 3 <= 1.0)
#        If (feature 4 <= 2.0)
#         Predict: 1.0
#        Else (feature 4 > 2.0)
#         Predict: 1.0
#       Else (feature 3 > 1.0)
#        If (feature 5 <= 1.0)
#         Predict: 1.0
#        Else (feature 5 > 1.0)
#         Predict: 1.0
#      Else (feature 5 > 2.0)
#       If (feature 9 <= 2.0)
#        If (feature 1 <= 2.0)
#         Predict: 1.0
#        Else (feature 1 > 2.0)
#         Predict: 1.0
#       Else (feature 9 > 2.0)
#        If (feature 7 <= 2.0)
#         Predict: 1.0
#        Else (feature 7 > 2.0)
#         Predict: 0.0
#     Else (feature 3 > 2.0)
#      If (feature 5 <= 6.0)
#       If (feature 9 <= 10.0)
#        If (feature 7 <= 6.0)
#         Predict: 0.0
#        Else (feature 7 > 6.0)
#         Predict: 0.0
#       Else (feature 9 > 10.0)
#        If (feature 8 <= 2.0)
#         Predict: 0.0
#        Else (feature 8 > 2.0)
#         Predict: 0.0
#      Else (feature 5 > 6.0)
#       If (feature 7 <= 5.0)
#        If (feature 8 <= 2.0)
#         Predict: 0.0
#        Else (feature 8 > 2.0)
#         Predict: 0.0
#       Else (feature 7 > 5.0)
#        If (feature 6 <= 2.0)
#         Predict: 1.0
#        Else (feature 6 > 2.0)
#         Predict: 0.0
#   Tree 26:
#     If (feature 9 <= 12.0)
#      If (feature 5 <= 9.0)
#       If (feature 3 <= 9.0)
#        If (feature 7 <= 9.0)
#         Predict: 1.0
#        Else (feature 7 > 9.0)
#         Predict: 0.0
#       Else (feature 3 > 9.0)
#        If (feature 3 <= 11.0)
#         Predict: 0.0
#        Else (feature 3 > 11.0)
#         Predict: 0.0
#      Else (feature 5 > 9.0)
#       If (feature 7 <= 9.0)
#        If (feature 3 <= 7.0)
#         Predict: 0.0
#        Else (feature 3 > 7.0)
#         Predict: 0.0
#       Else (feature 7 > 9.0)
#        If (feature 9 <= 9.0)
#         Predict: 0.0
#        Else (feature 9 > 9.0)
#         Predict: 1.0
#     Else (feature 9 > 12.0)
#      If (feature 5 <= 12.0)
#       If (feature 1 <= 12.0)
#        If (feature 7 <= 12.0)
#         Predict: 0.0
#        Else (feature 7 > 12.0)
#         Predict: 1.0
#       Else (feature 1 > 12.0)
#        If (feature 3 <= 12.0)
#         Predict: 1.0
#        Else (feature 3 > 12.0)
#         Predict: 3.0
#      Else (feature 5 > 12.0)
#       If (feature 4 <= 2.0)
#        If (feature 2 <= 1.0)
#         Predict: 2.0
#        Else (feature 2 > 1.0)
#         Predict: 1.0
#       Else (feature 4 > 2.0)
#        If (feature 4 <= 3.0)
#         Predict: 1.0
#        Else (feature 4 > 3.0)
#         Predict: 1.0
#   Tree 27:
#     If (feature 9 <= 1.0)
#      If (feature 3 <= 1.0)
#       If (feature 1 <= 1.0)
#        Predict: 3.0
#       Else (feature 1 > 1.0)
#        If (feature 7 <= 2.0)
#         Predict: 2.0
#        Else (feature 7 > 2.0)
#         Predict: 1.0
#      Else (feature 3 > 1.0)
#       If (feature 7 <= 1.0)
#        If (feature 0 <= 3.0)
#         Predict: 1.0
#        Else (feature 0 > 3.0)
#         Predict: 1.0
#       Else (feature 7 > 1.0)
#        If (feature 5 <= 1.0)
#         Predict: 1.0
#        Else (feature 5 > 1.0)
#         Predict: 0.0
#     Else (feature 9 > 1.0)
#      If (feature 5 <= 2.0)
#       If (feature 9 <= 2.0)
#        If (feature 5 <= 1.0)
#         Predict: 0.0
#        Else (feature 5 > 1.0)
#         Predict: 1.0
#       Else (feature 9 > 2.0)
#        If (feature 7 <= 2.0)
#         Predict: 1.0
#        Else (feature 7 > 2.0)
#         Predict: 0.0
#      Else (feature 5 > 2.0)
#       If (feature 9 <= 2.0)
#        If (feature 7 <= 2.0)
#         Predict: 1.0
#        Else (feature 7 > 2.0)
#         Predict: 0.0
#       Else (feature 9 > 2.0)
#        If (feature 1 <= 2.0)
#         Predict: 0.0
#        Else (feature 1 > 2.0)
#         Predict: 0.0
#   Tree 28:
#     If (feature 7 <= 10.0)
#      If (feature 5 <= 9.0)
#       If (feature 9 <= 10.0)
#        If (feature 1 <= 10.0)
#         Predict: 1.0
#        Else (feature 1 > 10.0)
#         Predict: 0.0
#       Else (feature 9 > 10.0)
#        If (feature 5 <= 3.0)
#         Predict: 0.0
#        Else (feature 5 > 3.0)
#         Predict: 0.0
#      Else (feature 5 > 9.0)
#       If (feature 3 <= 7.0)
#        If (feature 7 <= 5.0)
#         Predict: 0.0
#        Else (feature 7 > 5.0)
#         Predict: 0.0
#       Else (feature 3 > 7.0)
#        If (feature 9 <= 9.0)
#         Predict: 0.0
#        Else (feature 9 > 9.0)
#         Predict: 1.0
#     Else (feature 7 > 10.0)
#      If (feature 1 <= 11.0)
#       If (feature 9 <= 9.0)
#        If (feature 5 <= 10.0)
#         Predict: 0.0
#        Else (feature 5 > 10.0)
#         Predict: 0.0
#       Else (feature 9 > 9.0)
#        If (feature 5 <= 9.0)
#         Predict: 0.0
#        Else (feature 5 > 9.0)
#         Predict: 1.0
#      Else (feature 1 > 11.0)
#       If (feature 9 <= 10.0)
#        If (feature 2 <= 2.0)
#         Predict: 1.0
#        Else (feature 2 > 2.0)
#         Predict: 1.0
#       Else (feature 9 > 10.0)
#        If (feature 5 <= 12.0)
#         Predict: 1.0
#        Else (feature 5 > 12.0)
#         Predict: 2.0
#   Tree 29:
#     If (feature 1 <= 12.0)
#      If (feature 9 <= 12.0)
#       If (feature 5 <= 12.0)
#        If (feature 3 <= 12.0)
#         Predict: 0.0
#        Else (feature 3 > 12.0)
#         Predict: 0.0
#       Else (feature 5 > 12.0)
#        If (feature 3 <= 12.0)
#         Predict: 0.0
#        Else (feature 3 > 12.0)
#         Predict: 1.0
#      Else (feature 9 > 12.0)
#       If (feature 6 <= 3.0)
#        If (feature 3 <= 12.0)
#         Predict: 0.0
#        Else (feature 3 > 12.0)
#         Predict: 1.0
#       Else (feature 6 > 3.0)
#        If (feature 1 <= 7.0)
#         Predict: 0.0
#        Else (feature 1 > 7.0)
#         Predict: 0.0
#     Else (feature 1 > 12.0)
#      If (feature 9 <= 12.0)
#       If (feature 7 <= 12.0)
#        If (feature 3 <= 12.0)
#         Predict: 0.0
#        Else (feature 3 > 12.0)
#         Predict: 1.0
#       Else (feature 7 > 12.0)
#        If (feature 4 <= 2.0)
#         Predict: 1.0
#        Else (feature 4 > 2.0)
#         Predict: 1.0
#      Else (feature 9 > 12.0)
#       If (feature 5 <= 12.0)
#        If (feature 5 <= 1.0)
#         Predict: 2.0
#        Else (feature 5 > 1.0)
#         Predict: 1.0
#       Else (feature 5 > 12.0)
#        Predict: 3.0
#   Tree 30:
#     If (feature 8 <= 2.0)
#      If (feature 6 <= 2.0)
#       If (feature 1 <= 1.0)
#        If (feature 7 <= 1.0)
#         Predict: 1.0
#        Else (feature 7 > 1.0)
#         Predict: 0.0
#       Else (feature 1 > 1.0)
#        If (feature 0 <= 2.0)
#         Predict: 0.0
#        Else (feature 0 > 2.0)
#         Predict: 1.0
#      Else (feature 6 > 2.0)
#       If (feature 5 <= 2.0)
#        If (feature 9 <= 2.0)
#         Predict: 1.0
#        Else (feature 9 > 2.0)
#         Predict: 0.0
#       Else (feature 5 > 2.0)
#        If (feature 3 <= 10.0)
#         Predict: 0.0
#        Else (feature 3 > 10.0)
#         Predict: 0.0
#     Else (feature 8 > 2.0)
#      If (feature 0 <= 2.0)
#       If (feature 6 <= 1.0)
#        If (feature 4 <= 1.0)
#         Predict: 0.0
#        Else (feature 4 > 1.0)
#         Predict: 0.0
#       Else (feature 6 > 1.0)
#        If (feature 6 <= 2.0)
#         Predict: 0.0
#        Else (feature 6 > 2.0)
#         Predict: 0.0
#      Else (feature 0 > 2.0)
#       If (feature 6 <= 1.0)
#        If (feature 0 <= 3.0)
#         Predict: 1.0
#        Else (feature 0 > 3.0)
#         Predict: 0.0
#       Else (feature 6 > 1.0)
#        If (feature 0 <= 3.0)
#         Predict: 0.0
#        Else (feature 0 > 3.0)
#         Predict: 0.0
#   Tree 31:
#     If (feature 7 <= 1.0)
#      If (feature 9 <= 1.0)
#       If (feature 3 <= 1.0)
#        Predict: 3.0
#       Else (feature 3 > 1.0)
#        If (feature 5 <= 1.0)
#         Predict: 3.0
#        Else (feature 5 > 1.0)
#         Predict: 1.0
#      Else (feature 9 > 1.0)
#       If (feature 9 <= 4.0)
#        If (feature 2 <= 1.0)
#         Predict: 0.0
#        Else (feature 2 > 1.0)
#         Predict: 1.0
#       Else (feature 9 > 4.0)
#        If (feature 5 <= 1.0)
#         Predict: 1.0
#        Else (feature 5 > 1.0)
#         Predict: 0.0
#     Else (feature 7 > 1.0)
#      If (feature 0 <= 1.0)
#       If (feature 3 <= 2.0)
#        If (feature 1 <= 12.0)
#         Predict: 1.0
#        Else (feature 1 > 12.0)
#         Predict: 0.0
#       Else (feature 3 > 2.0)
#        If (feature 7 <= 11.0)
#         Predict: 0.0
#        Else (feature 7 > 11.0)
#         Predict: 1.0
#      Else (feature 0 > 1.0)
#       If (feature 2 <= 2.0)
#        If (feature 7 <= 9.0)
#         Predict: 0.0
#        Else (feature 7 > 9.0)
#         Predict: 0.0
#       Else (feature 2 > 2.0)
#        If (feature 1 <= 6.0)
#         Predict: 0.0
#        Else (feature 1 > 6.0)
#         Predict: 0.0
#   Tree 32:
#     If (feature 7 <= 1.0)
#      If (feature 9 <= 1.0)
#       If (feature 2 <= 3.0)
#        If (feature 5 <= 1.0)
#         Predict: 3.0
#        Else (feature 5 > 1.0)
#         Predict: 1.0
#       Else (feature 2 > 3.0)
#        Predict: 1.0
#      Else (feature 9 > 1.0)
#       If (feature 5 <= 1.0)
#        If (feature 3 <= 7.0)
#         Predict: 1.0
#        Else (feature 3 > 7.0)
#         Predict: 1.0
#       Else (feature 5 > 1.0)
#        If (feature 3 <= 1.0)
#         Predict: 1.0
#        Else (feature 3 > 1.0)
#         Predict: 0.0
#     Else (feature 7 > 1.0)
#      If (feature 6 <= 3.0)
#       If (feature 9 <= 3.0)
#        If (feature 5 <= 3.0)
#         Predict: 1.0
#        Else (feature 5 > 3.0)
#         Predict: 0.0
#       Else (feature 9 > 3.0)
#        If (feature 7 <= 5.0)
#         Predict: 0.0
#        Else (feature 7 > 5.0)
#         Predict: 0.0
#      Else (feature 6 > 3.0)
#       If (feature 0 <= 2.0)
#        If (feature 5 <= 4.0)
#         Predict: 0.0
#        Else (feature 5 > 4.0)
#         Predict: 0.0
#       Else (feature 0 > 2.0)
#        If (feature 4 <= 2.0)
#         Predict: 0.0
#        Else (feature 4 > 2.0)
#         Predict: 0.0
#   Tree 33:
#     If (feature 5 <= 8.0)
#      If (feature 7 <= 6.0)
#       If (feature 9 <= 6.0)
#        If (feature 3 <= 6.0)
#         Predict: 1.0
#        Else (feature 3 > 6.0)
#         Predict: 0.0
#       Else (feature 9 > 6.0)
#        If (feature 3 <= 8.0)
#         Predict: 0.0
#        Else (feature 3 > 8.0)
#         Predict: 0.0
#      Else (feature 7 > 6.0)
#       If (feature 9 <= 10.0)
#        If (feature 7 <= 8.0)
#         Predict: 0.0
#        Else (feature 7 > 8.0)
#         Predict: 0.0
#       Else (feature 9 > 10.0)
#        If (feature 6 <= 3.0)
#         Predict: 0.0
#        Else (feature 6 > 3.0)
#         Predict: 0.0
#     Else (feature 5 > 8.0)
#      If (feature 3 <= 7.0)
#       If (feature 9 <= 8.0)
#        If (feature 1 <= 9.0)
#         Predict: 0.0
#        Else (feature 1 > 9.0)
#         Predict: 0.0
#       Else (feature 9 > 8.0)
#        If (feature 1 <= 8.0)
#         Predict: 0.0
#        Else (feature 1 > 8.0)
#         Predict: 1.0
#      Else (feature 3 > 7.0)
#       If (feature 9 <= 7.0)
#        If (feature 8 <= 3.0)
#         Predict: 0.0
#        Else (feature 8 > 3.0)
#         Predict: 0.0
#       Else (feature 9 > 7.0)
#        If (feature 5 <= 9.0)
#         Predict: 1.0
#        Else (feature 5 > 9.0)
#         Predict: 1.0
#   Tree 34:
#     If (feature 8 <= 2.0)
#      If (feature 7 <= 2.0)
#       If (feature 3 <= 2.0)
#        If (feature 9 <= 2.0)
#         Predict: 1.0
#        Else (feature 9 > 2.0)
#         Predict: 1.0
#       Else (feature 3 > 2.0)
#        If (feature 9 <= 2.0)
#         Predict: 1.0
#        Else (feature 9 > 2.0)
#         Predict: 0.0
#      Else (feature 7 > 2.0)
#       If (feature 5 <= 2.0)
#        If (feature 9 <= 2.0)
#         Predict: 1.0
#        Else (feature 9 > 2.0)
#         Predict: 0.0
#       Else (feature 5 > 2.0)
#        If (feature 0 <= 2.0)
#         Predict: 0.0
#        Else (feature 0 > 2.0)
#         Predict: 0.0
#     Else (feature 8 > 2.0)
#      If (feature 2 <= 2.0)
#       If (feature 7 <= 7.0)
#        If (feature 9 <= 5.0)
#         Predict: 1.0
#        Else (feature 9 > 5.0)
#         Predict: 0.0
#       Else (feature 7 > 7.0)
#        If (feature 5 <= 6.0)
#         Predict: 0.0
#        Else (feature 5 > 6.0)
#         Predict: 0.0
#      Else (feature 2 > 2.0)
#       If (feature 9 <= 6.0)
#        If (feature 7 <= 1.0)
#         Predict: 1.0
#        Else (feature 7 > 1.0)
#         Predict: 0.0
#       Else (feature 9 > 6.0)
#        If (feature 1 <= 6.0)
#         Predict: 0.0
#        Else (feature 1 > 6.0)
#         Predict: 0.0
#   Tree 35:
#     If (feature 3 <= 12.0)
#      If (feature 5 <= 1.0)
#       If (feature 3 <= 1.0)
#        If (feature 0 <= 1.0)
#         Predict: 1.0
#        Else (feature 0 > 1.0)
#         Predict: 1.0
#       Else (feature 3 > 1.0)
#        If (feature 7 <= 1.0)
#         Predict: 1.0
#        Else (feature 7 > 1.0)
#         Predict: 0.0
#      Else (feature 5 > 1.0)
#       If (feature 5 <= 8.0)
#        If (feature 1 <= 12.0)
#         Predict: 0.0
#        Else (feature 1 > 12.0)
#         Predict: 0.0
#       Else (feature 5 > 8.0)
#        If (feature 1 <= 8.0)
#         Predict: 0.0
#        Else (feature 1 > 8.0)
#         Predict: 1.0
#     Else (feature 3 > 12.0)
#      If (feature 1 <= 12.0)
#       If (feature 7 <= 12.0)
#        If (feature 5 <= 12.0)
#         Predict: 0.0
#        Else (feature 5 > 12.0)
#         Predict: 1.0
#       Else (feature 7 > 12.0)
#        If (feature 9 <= 9.0)
#         Predict: 1.0
#        Else (feature 9 > 9.0)
#         Predict: 1.0
#      Else (feature 1 > 12.0)
#       If (feature 7 <= 12.0)
#        If (feature 8 <= 1.0)
#         Predict: 1.0
#        Else (feature 8 > 1.0)
#         Predict: 1.0
#       Else (feature 7 > 12.0)
#        Predict: 3.0
#   Tree 36:
#     If (feature 9 <= 10.0)
#      If (feature 7 <= 11.0)
#       If (feature 1 <= 11.0)
#        If (feature 5 <= 11.0)
#         Predict: 0.0
#        Else (feature 5 > 11.0)
#         Predict: 0.0
#       Else (feature 1 > 11.0)
#        If (feature 0 <= 1.0)
#         Predict: 0.0
#        Else (feature 0 > 1.0)
#         Predict: 0.0
#      Else (feature 7 > 11.0)
#       If (feature 6 <= 1.0)
#        If (feature 9 <= 6.0)
#         Predict: 0.0
#        Else (feature 9 > 6.0)
#         Predict: 0.0
#       Else (feature 6 > 1.0)
#        If (feature 5 <= 11.0)
#         Predict: 0.0
#        Else (feature 5 > 11.0)
#         Predict: 1.0
#     Else (feature 9 > 10.0)
#      If (feature 3 <= 10.0)
#       If (feature 1 <= 10.0)
#        If (feature 3 <= 8.0)
#         Predict: 0.0
#        Else (feature 3 > 8.0)
#         Predict: 0.0
#       Else (feature 1 > 10.0)
#        If (feature 4 <= 2.0)
#         Predict: 1.0
#        Else (feature 4 > 2.0)
#         Predict: 0.0
#      Else (feature 3 > 10.0)
#       If (feature 5 <= 10.0)
#        If (feature 6 <= 2.0)
#         Predict: 1.0
#        Else (feature 6 > 2.0)
#         Predict: 0.0
#       Else (feature 5 > 10.0)
#        If (feature 1 <= 11.0)
#         Predict: 1.0
#        Else (feature 1 > 11.0)
#         Predict: 2.0
#   Tree 37:
#     If (feature 5 <= 4.0)
#      If (feature 9 <= 4.0)
#       If (feature 8 <= 1.0)
#        If (feature 7 <= 2.0)
#         Predict: 1.0
#        Else (feature 7 > 2.0)
#         Predict: 1.0
#       Else (feature 8 > 1.0)
#        If (feature 3 <= 3.0)
#         Predict: 1.0
#        Else (feature 3 > 3.0)
#         Predict: 0.0
#      Else (feature 9 > 4.0)
#       If (feature 1 <= 4.0)
#        If (feature 0 <= 1.0)
#         Predict: 0.0
#        Else (feature 0 > 1.0)
#         Predict: 1.0
#       Else (feature 1 > 4.0)
#        If (feature 3 <= 4.0)
#         Predict: 0.0
#        Else (feature 3 > 4.0)
#         Predict: 0.0
#     Else (feature 5 > 4.0)
#      If (feature 9 <= 2.0)
#       If (feature 0 <= 1.0)
#        If (feature 1 <= 2.0)
#         Predict: 1.0
#        Else (feature 1 > 2.0)
#         Predict: 0.0
#       Else (feature 0 > 1.0)
#        If (feature 3 <= 2.0)
#         Predict: 1.0
#        Else (feature 3 > 2.0)
#         Predict: 0.0
#      Else (feature 9 > 2.0)
#       If (feature 7 <= 4.0)
#        If (feature 0 <= 2.0)
#         Predict: 0.0
#        Else (feature 0 > 2.0)
#         Predict: 0.0
#       Else (feature 7 > 4.0)
#        If (feature 3 <= 3.0)
#         Predict: 0.0
#        Else (feature 3 > 3.0)
#         Predict: 1.0
#   Tree 38:
#     If (feature 1 <= 9.0)
#      If (feature 5 <= 9.0)
#       If (feature 3 <= 9.0)
#        If (feature 4 <= 1.0)
#         Predict: 0.0
#        Else (feature 4 > 1.0)
#         Predict: 1.0
#       Else (feature 3 > 9.0)
#        If (feature 7 <= 10.0)
#         Predict: 0.0
#        Else (feature 7 > 10.0)
#         Predict: 0.0
#      Else (feature 5 > 9.0)
#       If (feature 9 <= 9.0)
#        If (feature 7 <= 1.0)
#         Predict: 1.0
#        Else (feature 7 > 1.0)
#         Predict: 0.0
#       Else (feature 9 > 9.0)
#        If (feature 6 <= 2.0)
#         Predict: 1.0
#        Else (feature 6 > 2.0)
#         Predict: 0.0
#     Else (feature 1 > 9.0)
#      If (feature 5 <= 9.0)
#       If (feature 3 <= 7.0)
#        If (feature 2 <= 2.0)
#         Predict: 0.0
#        Else (feature 2 > 2.0)
#         Predict: 0.0
#       Else (feature 3 > 7.0)
#        If (feature 7 <= 7.0)
#         Predict: 0.0
#        Else (feature 7 > 7.0)
#         Predict: 1.0
#      Else (feature 5 > 9.0)
#       If (feature 3 <= 9.0)
#        If (feature 7 <= 8.0)
#         Predict: 0.0
#        Else (feature 7 > 8.0)
#         Predict: 1.0
#       Else (feature 3 > 9.0)
#        If (feature 7 <= 7.0)
#         Predict: 1.0
#        Else (feature 7 > 7.0)
#         Predict: 1.0
#   Tree 39:
#     If (feature 5 <= 4.0)
#      If (feature 9 <= 4.0)
#       If (feature 7 <= 6.0)
#        If (feature 7 <= 4.0)
#         Predict: 1.0
#        Else (feature 7 > 4.0)
#         Predict: 1.0
#       Else (feature 7 > 6.0)
#        If (feature 4 <= 1.0)
#         Predict: 0.0
#        Else (feature 4 > 1.0)
#         Predict: 1.0
#      Else (feature 9 > 4.0)
#       If (feature 3 <= 4.0)
#        If (feature 7 <= 4.0)
#         Predict: 1.0
#        Else (feature 7 > 4.0)
#         Predict: 0.0
#       Else (feature 3 > 4.0)
#        If (feature 4 <= 2.0)
#         Predict: 0.0
#        Else (feature 4 > 2.0)
#         Predict: 0.0
#     Else (feature 5 > 4.0)
#      If (feature 3 <= 7.0)
#       If (feature 7 <= 9.0)
#        If (feature 3 <= 3.0)
#         Predict: 0.0
#        Else (feature 3 > 3.0)
#         Predict: 0.0
#       Else (feature 7 > 9.0)
#        If (feature 5 <= 9.0)
#         Predict: 0.0
#        Else (feature 5 > 9.0)
#         Predict: 0.0
#      Else (feature 3 > 7.0)
#       If (feature 7 <= 7.0)
#        If (feature 0 <= 1.0)
#         Predict: 0.0
#        Else (feature 0 > 1.0)
# ...
#       Else (feature 5 > 4.0)
#        If (feature 9 <= 3.0)
#         Predict: 0.0
#        Else (feature 9 > 3.0)
#         Predict: 0.0
#   Tree 167:
#     If (feature 3 <= 11.0)
#      If (feature 5 <= 11.0)
#       If (feature 1 <= 11.0)
#        If (feature 9 <= 11.0)
#         Predict: 1.0
#        Else (feature 9 > 11.0)
#         Predict: 0.0
#       Else (feature 1 > 11.0)
#        If (feature 7 <= 10.0)
#         Predict: 0.0
#        Else (feature 7 > 10.0)
#         Predict: 1.0
#      Else (feature 5 > 11.0)
#       If (feature 9 <= 11.0)
#        If (feature 8 <= 2.0)
#         Predict: 0.0
#        Else (feature 8 > 2.0)
#         Predict: 0.0
#       Else (feature 9 > 11.0)
#        If (feature 1 <= 11.0)
#         Predict: 1.0
#        Else (feature 1 > 11.0)
#         Predict: 1.0
#     Else (feature 3 > 11.0)
#      If (feature 8 <= 1.0)
#       If (feature 1 <= 11.0)
#        If (feature 2 <= 3.0)
#         Predict: 0.0
#        Else (feature 2 > 3.0)
#         Predict: 0.0
#       Else (feature 1 > 11.0)
#        If (feature 6 <= 3.0)
#         Predict: 1.0
#        Else (feature 6 > 3.0)
#         Predict: 0.0
#      Else (feature 8 > 1.0)
#       If (feature 9 <= 11.0)
#        If (feature 5 <= 11.0)
#         Predict: 0.0
#        Else (feature 5 > 11.0)
#         Predict: 1.0
#       Else (feature 9 > 11.0)
#        If (feature 5 <= 11.0)
#         Predict: 1.0
#        Else (feature 5 > 11.0)
#         Predict: 1.0
#   Tree 168:
#     If (feature 9 <= 11.0)
#      If (feature 5 <= 11.0)
#       If (feature 1 <= 11.0)
#        If (feature 7 <= 11.0)
#         Predict: 1.0
#        Else (feature 7 > 11.0)
#         Predict: 0.0
#       Else (feature 1 > 11.0)
#        If (feature 7 <= 11.0)
#         Predict: 0.0
#        Else (feature 7 > 11.0)
#         Predict: 1.0
#      Else (feature 5 > 11.0)
#       If (feature 7 <= 11.0)
#        If (feature 3 <= 11.0)
#         Predict: 0.0
#        Else (feature 3 > 11.0)
#         Predict: 1.0
#       Else (feature 7 > 11.0)
#        If (feature 3 <= 11.0)
#         Predict: 1.0
#        Else (feature 3 > 11.0)
#         Predict: 1.0
#     Else (feature 9 > 11.0)
#      If (feature 0 <= 3.0)
#       If (feature 5 <= 11.0)
#        If (feature 3 <= 11.0)
#         Predict: 0.0
#        Else (feature 3 > 11.0)
#         Predict: 1.0
#       Else (feature 5 > 11.0)
#        If (feature 7 <= 3.0)
#         Predict: 0.0
#        Else (feature 7 > 3.0)
#         Predict: 1.0
#      Else (feature 0 > 3.0)
#       If (feature 5 <= 11.0)
#        If (feature 1 <= 5.0)
#         Predict: 0.0
#        Else (feature 1 > 5.0)
#         Predict: 0.0
#       Else (feature 5 > 11.0)
#        If (feature 3 <= 11.0)
#         Predict: 1.0
#        Else (feature 3 > 11.0)
#         Predict: 1.0
#   Tree 169:
#     If (feature 8 <= 2.0)
#      If (feature 1 <= 10.0)
#       If (feature 5 <= 9.0)
#        If (feature 9 <= 11.0)
#         Predict: 0.0
#        Else (feature 9 > 11.0)
#         Predict: 0.0
#       Else (feature 5 > 9.0)
#        If (feature 9 <= 11.0)
#         Predict: 0.0
#        Else (feature 9 > 11.0)
#         Predict: 1.0
#      Else (feature 1 > 10.0)
#       If (feature 9 <= 12.0)
#        If (feature 7 <= 9.0)
#         Predict: 0.0
#        Else (feature 7 > 9.0)
#         Predict: 1.0
#       Else (feature 9 > 12.0)
#        If (feature 3 <= 7.0)
#         Predict: 1.0
#        Else (feature 3 > 7.0)
#         Predict: 1.0
#     Else (feature 8 > 2.0)
#      If (feature 4 <= 2.0)
#       If (feature 9 <= 12.0)
#        If (feature 7 <= 9.0)
#         Predict: 0.0
#        Else (feature 7 > 9.0)
#         Predict: 0.0
#       Else (feature 9 > 12.0)
#        If (feature 1 <= 12.0)
#         Predict: 0.0
#        Else (feature 1 > 12.0)
#         Predict: 1.0
#      Else (feature 4 > 2.0)
#       If (feature 9 <= 9.0)
#        If (feature 7 <= 9.0)
#         Predict: 0.0
#        Else (feature 7 > 9.0)
#         Predict: 0.0
#       Else (feature 9 > 9.0)
#        If (feature 5 <= 6.0)
#         Predict: 0.0
#        Else (feature 5 > 6.0)
#         Predict: 0.0
#   Tree 170:
#     If (feature 8 <= 3.0)
#      If (feature 4 <= 3.0)
#       If (feature 4 <= 2.0)
#        If (feature 5 <= 1.0)
#         Predict: 1.0
#        Else (feature 5 > 1.0)
#         Predict: 0.0
#       Else (feature 4 > 2.0)
#        If (feature 7 <= 1.0)
#         Predict: 1.0
#        Else (feature 7 > 1.0)
#         Predict: 0.0
#      Else (feature 4 > 3.0)
#       If (feature 0 <= 3.0)
#        If (feature 1 <= 7.0)
#         Predict: 1.0
#        Else (feature 1 > 7.0)
#         Predict: 0.0
#       Else (feature 0 > 3.0)
#        If (feature 6 <= 3.0)
#         Predict: 0.0
#        Else (feature 6 > 3.0)
#         Predict: 0.0
#     Else (feature 8 > 3.0)
#      If (feature 7 <= 4.0)
#       If (feature 5 <= 4.0)
#        If (feature 9 <= 7.0)
#         Predict: 1.0
#        Else (feature 9 > 7.0)
#         Predict: 0.0
#       Else (feature 5 > 4.0)
#        If (feature 9 <= 6.0)
#         Predict: 0.0
#        Else (feature 9 > 6.0)
#         Predict: 0.0
#      Else (feature 7 > 4.0)
#       If (feature 5 <= 2.0)
#        If (feature 3 <= 1.0)
#         Predict: 1.0
#        Else (feature 3 > 1.0)
#         Predict: 0.0
#       Else (feature 5 > 2.0)
#        If (feature 1 <= 4.0)
#         Predict: 0.0
#        Else (feature 1 > 4.0)
#         Predict: 1.0
#   Tree 171:
#     If (feature 8 <= 2.0)
#      If (feature 5 <= 3.0)
#       If (feature 7 <= 3.0)
#        If (feature 1 <= 4.0)
#         Predict: 1.0
#        Else (feature 1 > 4.0)
#         Predict: 1.0
#       Else (feature 7 > 3.0)
#        If (feature 3 <= 3.0)
#         Predict: 1.0
#        Else (feature 3 > 3.0)
#         Predict: 0.0
#      Else (feature 5 > 3.0)
#       If (feature 1 <= 7.0)
#        If (feature 9 <= 7.0)
#         Predict: 0.0
#        Else (feature 9 > 7.0)
#         Predict: 0.0
#       Else (feature 1 > 7.0)
#        If (feature 9 <= 8.0)
#         Predict: 0.0
#        Else (feature 9 > 8.0)
#         Predict: 1.0
#     Else (feature 8 > 2.0)
#      If (feature 9 <= 12.0)
#       If (feature 7 <= 1.0)
#        If (feature 9 <= 1.0)
#         Predict: 1.0
#        Else (feature 9 > 1.0)
#         Predict: 0.0
#       Else (feature 7 > 1.0)
#        If (feature 7 <= 3.0)
#         Predict: 0.0
#        Else (feature 7 > 3.0)
#         Predict: 0.0
#      Else (feature 9 > 12.0)
#       If (feature 5 <= 12.0)
#        If (feature 3 <= 12.0)
#         Predict: 0.0
#        Else (feature 3 > 12.0)
#         Predict: 1.0
#       Else (feature 5 > 12.0)
#        If (feature 2 <= 2.0)
#         Predict: 3.0
#        Else (feature 2 > 2.0)
#         Predict: 1.0
#   Tree 172:
#     If (feature 8 <= 3.0)
#      If (feature 0 <= 1.0)
#       If (feature 1 <= 9.0)
#        If (feature 5 <= 9.0)
#         Predict: 0.0
#        Else (feature 5 > 9.0)
#         Predict: 0.0
#       Else (feature 1 > 9.0)
#        If (feature 8 <= 2.0)
#         Predict: 1.0
#        Else (feature 8 > 2.0)
#         Predict: 0.0
#      Else (feature 0 > 1.0)
#       If (feature 1 <= 6.0)
#        If (feature 3 <= 10.0)
#         Predict: 0.0
#        Else (feature 3 > 10.0)
#         Predict: 0.0
#       Else (feature 1 > 6.0)
#        If (feature 6 <= 3.0)
#         Predict: 0.0
#        Else (feature 6 > 3.0)
#         Predict: 0.0
#     Else (feature 8 > 3.0)
#      If (feature 2 <= 3.0)
#       If (feature 1 <= 4.0)
#        If (feature 9 <= 10.0)
#         Predict: 0.0
#        Else (feature 9 > 10.0)
#         Predict: 0.0
#       Else (feature 1 > 4.0)
#        If (feature 5 <= 1.0)
#         Predict: 0.0
#        Else (feature 5 > 1.0)
#         Predict: 0.0
#      Else (feature 2 > 3.0)
#       If (feature 7 <= 1.0)
#        If (feature 5 <= 1.0)
#         Predict: 1.0
#        Else (feature 5 > 1.0)
#         Predict: 0.0
#       Else (feature 7 > 1.0)
#        If (feature 0 <= 1.0)
#         Predict: 0.0
#        Else (feature 0 > 1.0)
#         Predict: 0.0
#   Tree 173:
#     If (feature 8 <= 2.0)
#      If (feature 7 <= 10.0)
#       If (feature 1 <= 11.0)
#        If (feature 1 <= 7.0)
#         Predict: 0.0
#        Else (feature 1 > 7.0)
#         Predict: 1.0
#       Else (feature 1 > 11.0)
#        If (feature 9 <= 12.0)
#         Predict: 0.0
#        Else (feature 9 > 12.0)
#         Predict: 1.0
#      Else (feature 7 > 10.0)
#       If (feature 5 <= 10.0)
#        If (feature 1 <= 11.0)
#         Predict: 0.0
#        Else (feature 1 > 11.0)
#         Predict: 1.0
#       Else (feature 5 > 10.0)
#        If (feature 9 <= 10.0)
#         Predict: 0.0
#        Else (feature 9 > 10.0)
#         Predict: 1.0
#     Else (feature 8 > 2.0)
#      If (feature 3 <= 2.0)
#       If (feature 7 <= 2.0)
#        If (feature 5 <= 5.0)
#         Predict: 1.0
#        Else (feature 5 > 5.0)
#         Predict: 1.0
#       Else (feature 7 > 2.0)
#        If (feature 5 <= 1.0)
#         Predict: 1.0
#        Else (feature 5 > 1.0)
#         Predict: 0.0
#      Else (feature 3 > 2.0)
#       If (feature 9 <= 2.0)
#        If (feature 5 <= 2.0)
#         Predict: 1.0
#        Else (feature 5 > 2.0)
#         Predict: 0.0
#       Else (feature 9 > 2.0)
#        If (feature 2 <= 1.0)
#         Predict: 0.0
#        Else (feature 2 > 1.0)
#         Predict: 0.0
#   Tree 174:
#     If (feature 5 <= 1.0)
#      If (feature 7 <= 1.0)
#       If (feature 4 <= 3.0)
#        If (feature 9 <= 1.0)
#         Predict: 3.0
#        Else (feature 9 > 1.0)
#         Predict: 1.0
#       Else (feature 4 > 3.0)
#        If (feature 1 <= 11.0)
#         Predict: 1.0
#        Else (feature 1 > 11.0)
#         Predict: 2.0
#      Else (feature 7 > 1.0)
#       If (feature 9 <= 1.0)
#        If (feature 7 <= 5.0)
#         Predict: 1.0
#        Else (feature 7 > 5.0)
#         Predict: 1.0
#       Else (feature 9 > 1.0)
#        If (feature 1 <= 1.0)
#         Predict: 1.0
#        Else (feature 1 > 1.0)
#         Predict: 0.0
#     Else (feature 5 > 1.0)
#      If (feature 8 <= 2.0)
#       If (feature 2 <= 3.0)
#        If (feature 4 <= 3.0)
#         Predict: 0.0
#        Else (feature 4 > 3.0)
#         Predict: 0.0
#       Else (feature 2 > 3.0)
#        If (feature 0 <= 1.0)
#         Predict: 1.0
#        Else (feature 0 > 1.0)
#         Predict: 0.0
#      Else (feature 8 > 2.0)
#       If (feature 0 <= 2.0)
#        If (feature 0 <= 1.0)
#         Predict: 0.0
#        Else (feature 0 > 1.0)
#         Predict: 0.0
#       Else (feature 0 > 2.0)
#        If (feature 2 <= 1.0)
#         Predict: 0.0
#        Else (feature 2 > 1.0)
#         Predict: 0.0
#   Tree 175:
#     If (feature 7 <= 10.0)
#      If (feature 5 <= 9.0)
#       If (feature 1 <= 10.0)
#        If (feature 3 <= 10.0)
#         Predict: 1.0
#        Else (feature 3 > 10.0)
#         Predict: 0.0
#       Else (feature 1 > 10.0)
#        If (feature 1 <= 11.0)
#         Predict: 0.0
#        Else (feature 1 > 11.0)
#         Predict: 0.0
#      Else (feature 5 > 9.0)
#       If (feature 9 <= 9.0)
#        If (feature 6 <= 2.0)
#         Predict: 0.0
#        Else (feature 6 > 2.0)
#         Predict: 0.0
#       Else (feature 9 > 9.0)
#        If (feature 1 <= 9.0)
#         Predict: 0.0
#        Else (feature 1 > 9.0)
#         Predict: 1.0
#     Else (feature 7 > 10.0)
#      If (feature 3 <= 10.0)
#       If (feature 7 <= 12.0)
#        If (feature 1 <= 9.0)
#         Predict: 0.0
#        Else (feature 1 > 9.0)
#         Predict: 1.0
#       Else (feature 7 > 12.0)
#        If (feature 5 <= 12.0)
#         Predict: 0.0
#        Else (feature 5 > 12.0)
#         Predict: 1.0
#      Else (feature 3 > 10.0)
#       If (feature 1 <= 10.0)
#        If (feature 9 <= 9.0)
#         Predict: 0.0
#        Else (feature 9 > 9.0)
#         Predict: 1.0
#       Else (feature 1 > 10.0)
#        If (feature 5 <= 10.0)
#         Predict: 1.0
#        Else (feature 5 > 10.0)
#         Predict: 2.0
#   Tree 176:
#     If (feature 3 <= 2.0)
#      If (feature 1 <= 2.0)
#       If (feature 9 <= 2.0)
#        If (feature 7 <= 2.0)
#         Predict: 2.0
#        Else (feature 7 > 2.0)
#         Predict: 1.0
#       Else (feature 9 > 2.0)
#        If (feature 5 <= 2.0)
#         Predict: 1.0
#        Else (feature 5 > 2.0)
#         Predict: 1.0
#      Else (feature 1 > 2.0)
#       If (feature 5 <= 2.0)
#        If (feature 7 <= 2.0)
#         Predict: 1.0
#        Else (feature 7 > 2.0)
#         Predict: 1.0
#       Else (feature 5 > 2.0)
#        If (feature 9 <= 2.0)
#         Predict: 1.0
#        Else (feature 9 > 2.0)
#         Predict: 0.0
#     Else (feature 3 > 2.0)
#      If (feature 9 <= 2.0)
#       If (feature 5 <= 2.0)
#        If (feature 1 <= 2.0)
#         Predict: 1.0
#        Else (feature 1 > 2.0)
#         Predict: 0.0
#       Else (feature 5 > 2.0)
#        If (feature 2 <= 3.0)
#         Predict: 0.0
#        Else (feature 2 > 3.0)
#         Predict: 0.0
#      Else (feature 9 > 2.0)
#       If (feature 1 <= 2.0)
#        If (feature 7 <= 2.0)
#         Predict: 1.0
#        Else (feature 7 > 2.0)
#         Predict: 0.0
#       Else (feature 1 > 2.0)
#        If (feature 1 <= 11.0)
#         Predict: 0.0
#        Else (feature 1 > 11.0)
#         Predict: 0.0
#   Tree 177:
#     If (feature 6 <= 1.0)
#      If (feature 1 <= 2.0)
#       If (feature 5 <= 2.0)
#        If (feature 9 <= 1.0)
#         Predict: 3.0
#        Else (feature 9 > 1.0)
#         Predict: 1.0
#       Else (feature 5 > 2.0)
#        If (feature 5 <= 9.0)
#         Predict: 0.0
#        Else (feature 5 > 9.0)
#         Predict: 0.0
#      Else (feature 1 > 2.0)
#       If (feature 7 <= 11.0)
#        If (feature 1 <= 5.0)
#         Predict: 1.0
#        Else (feature 1 > 5.0)
#         Predict: 0.0
#       Else (feature 7 > 11.0)
#        If (feature 5 <= 5.0)
#         Predict: 0.0
#        Else (feature 5 > 5.0)
#         Predict: 0.0
#     Else (feature 6 > 1.0)
#      If (feature 4 <= 2.0)
#       If (feature 9 <= 4.0)
#        If (feature 3 <= 3.0)
#         Predict: 1.0
#        Else (feature 3 > 3.0)
#         Predict: 0.0
#       Else (feature 9 > 4.0)
#        If (feature 9 <= 7.0)
#         Predict: 1.0
#        Else (feature 9 > 7.0)
#         Predict: 0.0
#      Else (feature 4 > 2.0)
#       If (feature 4 <= 3.0)
#        If (feature 8 <= 1.0)
#         Predict: 0.0
#        Else (feature 8 > 1.0)
#         Predict: 0.0
#       Else (feature 4 > 3.0)
#        If (feature 0 <= 3.0)
#         Predict: 0.0
#        Else (feature 0 > 3.0)
#         Predict: 0.0
#   Tree 178:
#     If (feature 7 <= 1.0)
#      If (feature 6 <= 3.0)
#       If (feature 5 <= 1.0)
#        If (feature 0 <= 2.0)
#         Predict: 1.0
#        Else (feature 0 > 2.0)
#         Predict: 1.0
#       Else (feature 5 > 1.0)
#        If (feature 3 <= 1.0)
#         Predict: 1.0
#        Else (feature 3 > 1.0)
#         Predict: 0.0
#      Else (feature 6 > 3.0)
#       If (feature 1 <= 1.0)
#        If (feature 9 <= 6.0)
#         Predict: 1.0
#        Else (feature 9 > 6.0)
#         Predict: 1.0
#       Else (feature 1 > 1.0)
#        If (feature 9 <= 1.0)
#         Predict: 1.0
#        Else (feature 9 > 1.0)
#         Predict: 1.0
#     Else (feature 7 > 1.0)
#      If (feature 9 <= 2.0)
#       If (feature 3 <= 2.0)
#        If (feature 9 <= 1.0)
#         Predict: 1.0
#        Else (feature 9 > 1.0)
#         Predict: 1.0
#       Else (feature 3 > 2.0)
#        If (feature 7 <= 2.0)
#         Predict: 1.0
#        Else (feature 7 > 2.0)
#         Predict: 0.0
#      Else (feature 9 > 2.0)
#       If (feature 5 <= 2.0)
#        If (feature 1 <= 2.0)
#         Predict: 1.0
#        Else (feature 1 > 2.0)
#         Predict: 0.0
#       Else (feature 5 > 2.0)
#        If (feature 7 <= 3.0)
#         Predict: 0.0
#        Else (feature 7 > 3.0)
#         Predict: 0.0
#   Tree 179:
#     If (feature 0 <= 1.0)
#      If (feature 8 <= 2.0)
#       If (feature 6 <= 1.0)
#        If (feature 4 <= 1.0)
#         Predict: 0.0
#        Else (feature 4 > 1.0)
#         Predict: 0.0
#       Else (feature 6 > 1.0)
#        If (feature 2 <= 1.0)
#         Predict: 0.0
#        Else (feature 2 > 1.0)
#         Predict: 1.0
#      Else (feature 8 > 2.0)
#       If (feature 3 <= 2.0)
#        If (feature 9 <= 10.0)
#         Predict: 1.0
#        Else (feature 9 > 10.0)
#         Predict: 0.0
#       Else (feature 3 > 2.0)
#        If (feature 5 <= 11.0)
#         Predict: 0.0
#        Else (feature 5 > 11.0)
#         Predict: 0.0
#     Else (feature 0 > 1.0)
#      If (feature 2 <= 2.0)
#       If (feature 7 <= 7.0)
#        If (feature 3 <= 7.0)
#         Predict: 1.0
#        Else (feature 3 > 7.0)
#         Predict: 0.0
#       Else (feature 7 > 7.0)
#        If (feature 9 <= 2.0)
#         Predict: 0.0
#        Else (feature 9 > 2.0)
#         Predict: 0.0
#      Else (feature 2 > 2.0)
#       If (feature 1 <= 6.0)
#        If (feature 7 <= 1.0)
#         Predict: 1.0
#        Else (feature 7 > 1.0)
#         Predict: 0.0
#       Else (feature 1 > 6.0)
#        If (feature 7 <= 6.0)
#         Predict: 0.0
#        Else (feature 7 > 6.0)
#         Predict: 0.0

# %% [markdown]
# With a lot more trees in the ensemble, the training error has decreased a lot! But the training time has increased substantially as well. Remember that the training time increases roughly linearly with the number of trees.

# %% [markdown]
# ### featureSubsetStrategy Parameter

# %% [markdown]
# Remember that the featureSubsetStrategy parameter only changes the number of features used as candidates for splitting. The default is set to <b>"auto"</b>, which will select "all", "sqrt", or "onethird" based on the value of numTrees. Since we are basing our analysis off of the default values, we have a numTrees value of 3, which means "sqrt" is selected. So let's start by changing it it <b>"all"</b>, which will use all of the features

# %%
classRF_tuner(3, "all")
# Out:
# 1.15256810188
# Test Error = 0.479342158043
# Learned classification tree model:TreeEnsembleModel classifier with 3 trees
#
#   Tree 0:
#     If (feature 6 <= 2.0)
#      If (feature 3 <= 2.0)
#       If (feature 5 <= 3.0)
#        If (feature 9 <= 3.0)
#         Predict: 1.0
#        Else (feature 9 > 3.0)
#         Predict: 1.0
#       Else (feature 5 > 3.0)
#        If (feature 1 <= 2.0)
#         Predict: 1.0
#        Else (feature 1 > 2.0)
#         Predict: 0.0
#      Else (feature 3 > 2.0)
#       If (feature 3 <= 12.0)
#        If (feature 7 <= 12.0)
#         Predict: 0.0
#        Else (feature 7 > 12.0)
#         Predict: 0.0
#       Else (feature 3 > 12.0)
#        If (feature 9 <= 12.0)
#         Predict: 0.0
#        Else (feature 9 > 12.0)
#         Predict: 1.0
#     Else (feature 6 > 2.0)
#      If (feature 7 <= 1.0)
#       If (feature 9 <= 1.0)
#        If (feature 3 <= 1.0)
#         Predict: 3.0
#        Else (feature 3 > 1.0)
#         Predict: 1.0
#       Else (feature 9 > 1.0)
#        If (feature 5 <= 1.0)
#         Predict: 1.0
#        Else (feature 5 > 1.0)
#         Predict: 0.0
#      Else (feature 7 > 1.0)
#       If (feature 2 <= 2.0)
#        If (feature 6 <= 3.0)
#         Predict: 0.0
#        Else (feature 6 > 3.0)
#         Predict: 0.0
#       Else (feature 2 > 2.0)
#        If (feature 0 <= 2.0)
#         Predict: 0.0
#        Else (feature 0 > 2.0)
#         Predict: 0.0
#   Tree 1:
#     If (feature 7 <= 1.0)
#      If (feature 9 <= 1.0)
#       If (feature 3 <= 1.0)
#        Predict: 3.0
#       Else (feature 3 > 1.0)
#        If (feature 0 <= 3.0)
#         Predict: 1.0
#        Else (feature 0 > 3.0)
#         Predict: 1.0
#      Else (feature 9 > 1.0)
#       If (feature 1 <= 1.0)
#        If (feature 3 <= 1.0)
#         Predict: 3.0
#        Else (feature 3 > 1.0)
#         Predict: 1.0
#       Else (feature 1 > 1.0)
#        If (feature 3 <= 1.0)
#         Predict: 1.0
#        Else (feature 3 > 1.0)
#         Predict: 0.0
#     Else (feature 7 > 1.0)
#      If (feature 1 <= 10.0)
#       If (feature 3 <= 11.0)
#        If (feature 9 <= 11.0)
#         Predict: 0.0
#        Else (feature 9 > 11.0)
#         Predict: 0.0
#       Else (feature 3 > 11.0)
#        If (feature 9 <= 11.0)
#         Predict: 0.0
#        Else (feature 9 > 11.0)
#         Predict: 1.0
#      Else (feature 1 > 10.0)
#       If (feature 7 <= 10.0)
#        If (feature 5 <= 10.0)
#         Predict: 0.0
#        Else (feature 5 > 10.0)
#         Predict: 1.0
#       Else (feature 7 > 10.0)
#        If (feature 3 <= 10.0)
#         Predict: 1.0
#        Else (feature 3 > 10.0)
#         Predict: 1.0
#   Tree 2:
#     If (feature 5 <= 11.0)
#      If (feature 9 <= 11.0)
#       If (feature 3 <= 11.0)
#        If (feature 1 <= 11.0)
#         Predict: 1.0
#        Else (feature 1 > 11.0)
#         Predict: 0.0
#       Else (feature 3 > 11.0)
#        If (feature 7 <= 11.0)
#         Predict: 0.0
#        Else (feature 7 > 11.0)
#         Predict: 1.0
#      Else (feature 9 > 11.0)
#       If (feature 1 <= 11.0)
#        If (feature 3 <= 11.0)
#         Predict: 0.0
#        Else (feature 3 > 11.0)
#         Predict: 1.0
#       Else (feature 1 > 11.0)
#        If (feature 7 <= 11.0)
#         Predict: 1.0
#        Else (feature 7 > 11.0)
#         Predict: 1.0
#     Else (feature 5 > 11.0)
#      If (feature 9 <= 11.0)
#       If (feature 1 <= 11.0)
#        If (feature 3 <= 11.0)
#         Predict: 0.0
#        Else (feature 3 > 11.0)
#         Predict: 1.0
#       Else (feature 1 > 11.0)
#        If (feature 7 <= 10.0)
#         Predict: 1.0
#        Else (feature 7 > 10.0)
#         Predict: 1.0
#      Else (feature 9 > 11.0)
#       If (feature 3 <= 11.0)
#        If (feature 7 <= 10.0)
#         Predict: 1.0
#        Else (feature 7 > 10.0)
#         Predict: 1.0
#       Else (feature 3 > 11.0)
#        If (feature 1 <= 11.0)
#         Predict: 1.0
#        Else (feature 1 > 11.0)
#         Predict: 3.0

# %% [markdown]
# We can see that there is a small increase in the building time of the model, which is expected since we are considering all of the features. As well, there is a small increase in the test error. A possibility to the increase in test error is that there are some features that aren't "good" in the model, causing an increase in the test error. Next, we will try with <b>"sqrt"</b>

# %%
classRF_tuner(3, "sqrt")
# Out:
# 1.13319277763
# Test Error = 0.475865757454
# Learned classification tree model:TreeEnsembleModel classifier with 3 trees
#
#   Tree 0:
#     If (feature 7 <= 5.0)
#      If (feature 7 <= 2.0)
#       If (feature 3 <= 2.0)
#        If (feature 0 <= 3.0)
#         Predict: 1.0
#        Else (feature 0 > 3.0)
#         Predict: 1.0
#       Else (feature 3 > 2.0)
#        If (feature 5 <= 2.0)
#         Predict: 1.0
#        Else (feature 5 > 2.0)
#         Predict: 0.0
#      Else (feature 7 > 2.0)
#       If (feature 3 <= 5.0)
#        If (feature 7 <= 4.0)
#         Predict: 0.0
#        Else (feature 7 > 4.0)
#         Predict: 0.0
#       Else (feature 3 > 5.0)
#        If (feature 9 <= 2.0)
#         Predict: 0.0
#        Else (feature 9 > 2.0)
#         Predict: 0.0
#     Else (feature 7 > 5.0)
#      If (feature 5 <= 5.0)
#       If (feature 1 <= 5.0)
#        If (feature 3 <= 5.0)
#         Predict: 1.0
#        Else (feature 3 > 5.0)
#         Predict: 0.0
#       Else (feature 1 > 5.0)
#        If (feature 6 <= 1.0)
#         Predict: 0.0
#        Else (feature 6 > 1.0)
#         Predict: 0.0
#      Else (feature 5 > 5.0)
#       If (feature 1 <= 5.0)
#        If (feature 7 <= 7.0)
#         Predict: 0.0
#        Else (feature 7 > 7.0)
#         Predict: 0.0
#       Else (feature 1 > 5.0)
#        If (feature 9 <= 5.0)
#         Predict: 0.0
#        Else (feature 9 > 5.0)
#         Predict: 1.0
#   Tree 1:
#     If (feature 4 <= 2.0)
#      If (feature 7 <= 10.0)
#       If (feature 5 <= 4.0)
#        If (feature 3 <= 3.0)
#         Predict: 1.0
#        Else (feature 3 > 3.0)
#         Predict: 0.0
#       Else (feature 5 > 4.0)
#        If (feature 7 <= 4.0)
#         Predict: 0.0
#        Else (feature 7 > 4.0)
#         Predict: 0.0
#      Else (feature 7 > 10.0)
#       If (feature 6 <= 1.0)
#        If (feature 5 <= 10.0)
#         Predict: 0.0
#        Else (feature 5 > 10.0)
#         Predict: 1.0
#       Else (feature 6 > 1.0)
#        If (feature 1 <= 10.0)
#         Predict: 0.0
#        Else (feature 1 > 10.0)
#         Predict: 1.0
#     Else (feature 4 > 2.0)
#      If (feature 8 <= 2.0)
#       If (feature 9 <= 4.0)
#        If (feature 5 <= 4.0)
#         Predict: 1.0
#        Else (feature 5 > 4.0)
#         Predict: 0.0
#       Else (feature 9 > 4.0)
#        If (feature 5 <= 4.0)
#         Predict: 0.0
#        Else (feature 5 > 4.0)
#         Predict: 0.0
#      Else (feature 8 > 2.0)
#       If (feature 9 <= 9.0)
#        If (feature 5 <= 11.0)
#         Predict: 0.0
#        Else (feature 5 > 11.0)
#         Predict: 0.0
#       Else (feature 9 > 9.0)
#        If (feature 5 <= 8.0)
#         Predict: 0.0
#        Else (feature 5 > 8.0)
#         Predict: 0.0
#   Tree 2:
#     If (feature 5 <= 4.0)
#      If (feature 9 <= 4.0)
#       If (feature 4 <= 1.0)
#        If (feature 1 <= 12.0)
#         Predict: 0.0
#        Else (feature 1 > 12.0)
#         Predict: 1.0
#       Else (feature 4 > 1.0)
#        If (feature 1 <= 6.0)
#         Predict: 1.0
#        Else (feature 1 > 6.0)
#         Predict: 0.0
#      Else (feature 9 > 4.0)
#       If (feature 7 <= 3.0)
#        If (feature 1 <= 3.0)
#         Predict: 1.0
#        Else (feature 1 > 3.0)
#         Predict: 0.0
#       Else (feature 7 > 3.0)
#        If (feature 9 <= 5.0)
#         Predict: 0.0
#        Else (feature 9 > 5.0)
#         Predict: 0.0
#     Else (feature 5 > 4.0)
#      If (feature 7 <= 4.0)
#       If (feature 1 <= 12.0)
#        If (feature 3 <= 4.0)
#         Predict: 0.0
#        Else (feature 3 > 4.0)
#         Predict: 0.0
#       Else (feature 1 > 12.0)
#        If (feature 3 <= 12.0)
#         Predict: 0.0
#        Else (feature 3 > 12.0)
#         Predict: 1.0
#      Else (feature 7 > 4.0)
#       If (feature 3 <= 3.0)
#        If (feature 7 <= 9.0)
#         Predict: 0.0
#        Else (feature 7 > 9.0)
#         Predict: 0.0
#       Else (feature 3 > 3.0)
#        If (feature 3 <= 7.0)
#         Predict: 0.0
#        Else (feature 3 > 7.0)
#         Predict: 1.0

# %% [markdown]
# This has very similar values to the "auto", which is correct since "auto" is using "sqrt" for featureSubsetStrategy, since our numTrees value was set to 3. Let's try using "onethird" now, which uses one third of the features.

# %%
classRF_tuner(3, "onethird")
# Out:
# 1.1675388813
# Test Error = 0.465703971119
# Learned classification tree model:TreeEnsembleModel classifier with 3 trees
#
#   Tree 0:
#     If (feature 7 <= 8.0)
#      If (feature 1 <= 8.0)
#       If (feature 5 <= 8.0)
#        If (feature 9 <= 8.0)
#         Predict: 1.0
#        Else (feature 9 > 8.0)
#         Predict: 0.0
#       Else (feature 5 > 8.0)
#        If (feature 1 <= 1.0)
#         Predict: 0.0
#        Else (feature 1 > 1.0)
#         Predict: 0.0
#      Else (feature 1 > 8.0)
#       If (feature 5 <= 10.0)
#        If (feature 8 <= 2.0)
#         Predict: 0.0
#        Else (feature 8 > 2.0)
#         Predict: 0.0
#       Else (feature 5 > 10.0)
#        If (feature 9 <= 8.0)
#         Predict: 0.0
#        Else (feature 9 > 8.0)
#         Predict: 1.0
#     Else (feature 7 > 8.0)
#      If (feature 1 <= 8.0)
#       If (feature 1 <= 4.0)
#        If (feature 9 <= 12.0)
#         Predict: 0.0
#        Else (feature 9 > 12.0)
#         Predict: 0.0
#       Else (feature 1 > 4.0)
#        If (feature 9 <= 4.0)
#         Predict: 0.0
#        Else (feature 9 > 4.0)
#         Predict: 0.0
#      Else (feature 1 > 8.0)
#       If (feature 5 <= 8.0)
#        If (feature 9 <= 8.0)
#         Predict: 0.0
#        Else (feature 9 > 8.0)
#         Predict: 1.0
#       Else (feature 5 > 8.0)
#        If (feature 7 <= 9.0)
#         Predict: 1.0
#        Else (feature 7 > 9.0)
#         Predict: 1.0
#   Tree 1:
#     If (feature 2 <= 2.0)
#      If (feature 3 <= 2.0)
#       If (feature 1 <= 2.0)
#        If (feature 5 <= 12.0)
#         Predict: 1.0
#        Else (feature 5 > 12.0)
#         Predict: 0.0
#       Else (feature 1 > 2.0)
#        If (feature 7 <= 2.0)
#         Predict: 1.0
#        Else (feature 7 > 2.0)
#         Predict: 0.0
#      Else (feature 3 > 2.0)
#       If (feature 9 <= 2.0)
#        If (feature 5 <= 2.0)
#         Predict: 1.0
#        Else (feature 5 > 2.0)
#         Predict: 0.0
#       Else (feature 9 > 2.0)
#        If (feature 7 <= 2.0)
#         Predict: 0.0
#        Else (feature 7 > 2.0)
#         Predict: 0.0
#     Else (feature 2 > 2.0)
#      If (feature 6 <= 2.0)
#       If (feature 1 <= 8.0)
#        If (feature 5 <= 8.0)
#         Predict: 0.0
#        Else (feature 5 > 8.0)
#         Predict: 0.0
#       Else (feature 1 > 8.0)
#        If (feature 7 <= 7.0)
#         Predict: 0.0
#        Else (feature 7 > 7.0)
#         Predict: 1.0
#      Else (feature 6 > 2.0)
#       If (feature 8 <= 3.0)
#        If (feature 9 <= 10.0)
#         Predict: 0.0
#        Else (feature 9 > 10.0)
#         Predict: 0.0
#       Else (feature 8 > 3.0)
#        If (feature 4 <= 1.0)
#         Predict: 0.0
#        Else (feature 4 > 1.0)
#         Predict: 0.0
#   Tree 2:
#     If (feature 5 <= 9.0)
#      If (feature 3 <= 10.0)
#       If (feature 1 <= 10.0)
#        If (feature 1 <= 8.0)
#         Predict: 1.0
#        Else (feature 1 > 8.0)
#         Predict: 0.0
#       Else (feature 1 > 10.0)
#        If (feature 8 <= 2.0)
#         Predict: 0.0
#        Else (feature 8 > 2.0)
#         Predict: 0.0
#      Else (feature 3 > 10.0)
#       If (feature 1 <= 10.0)
#        If (feature 7 <= 11.0)
#         Predict: 0.0
#        Else (feature 7 > 11.0)
#         Predict: 1.0
#       Else (feature 1 > 10.0)
#        If (feature 7 <= 10.0)
#         Predict: 0.0
#        Else (feature 7 > 10.0)
#         Predict: 1.0
#     Else (feature 5 > 9.0)
#      If (feature 3 <= 9.0)
#       If (feature 1 <= 9.0)
#        If (feature 9 <= 2.0)
#         Predict: 0.0
#        Else (feature 9 > 2.0)
#         Predict: 0.0
#       Else (feature 1 > 9.0)
#        If (feature 7 <= 10.0)
#         Predict: 0.0
#        Else (feature 7 > 10.0)
#         Predict: 1.0
#      Else (feature 3 > 9.0)
#       If (feature 7 <= 9.0)
#        If (feature 9 <= 9.0)
#         Predict: 0.0
#        Else (feature 9 > 9.0)
#         Predict: 1.0
#       Else (feature 7 > 9.0)
#        If (feature 1 <= 8.0)
#         Predict: 1.0
#        Else (feature 1 > 8.0)
#         Predict: 1.0

# %% [markdown]
# We see that the run-time is similar to the default, but the testing error has decreased a little bit. It's possible that there is about the same number of features when you take one third of them, as if you take the square root of them for this particular dataset. Let's try with the last type, which is <b>"log2"</b>

# %%
classRF_tuner(3, "log2")
# Out:
# 1.12230682373
# Test Error = 0.485893836074
# Learned classification tree model:TreeEnsembleModel classifier with 3 trees
#
#   Tree 0:
#     If (feature 5 <= 3.0)
#      If (feature 3 <= 3.0)
#       If (feature 1 <= 3.0)
#        If (feature 7 <= 5.0)
#         Predict: 1.0
#        Else (feature 7 > 5.0)
#         Predict: 1.0
#       Else (feature 1 > 3.0)
#        If (feature 7 <= 3.0)
#         Predict: 1.0
#        Else (feature 7 > 3.0)
#         Predict: 0.0
#      Else (feature 3 > 3.0)
#       If (feature 8 <= 3.0)
#        If (feature 7 <= 6.0)
#         Predict: 1.0
#        Else (feature 7 > 6.0)
#         Predict: 0.0
#       Else (feature 8 > 3.0)
#        If (feature 1 <= 1.0)
#         Predict: 1.0
#        Else (feature 1 > 1.0)
#         Predict: 0.0
#     Else (feature 5 > 3.0)
#      If (feature 3 <= 3.0)
#       If (feature 7 <= 3.0)
#        If (feature 9 <= 4.0)
#         Predict: 1.0
#        Else (feature 9 > 4.0)
#         Predict: 0.0
#       Else (feature 7 > 3.0)
#        If (feature 9 <= 1.0)
#         Predict: 0.0
#        Else (feature 9 > 1.0)
#         Predict: 0.0
#      Else (feature 3 > 3.0)
#       If (feature 7 <= 3.0)
#        If (feature 7 <= 2.0)
#         Predict: 0.0
#        Else (feature 7 > 2.0)
#         Predict: 0.0
#       Else (feature 7 > 3.0)
#        If (feature 1 <= 3.0)
#         Predict: 0.0
#        Else (feature 1 > 3.0)
#         Predict: 1.0
#   Tree 1:
#     If (feature 4 <= 2.0)
#      If (feature 0 <= 2.0)
#       If (feature 1 <= 10.0)
#        If (feature 7 <= 2.0)
#         Predict: 1.0
#        Else (feature 7 > 2.0)
#         Predict: 0.0
#       Else (feature 1 > 10.0)
#        If (feature 0 <= 1.0)
#         Predict: 1.0
#        Else (feature 0 > 1.0)
#         Predict: 0.0
#      Else (feature 0 > 2.0)
#       If (feature 1 <= 7.0)
#        If (feature 7 <= 7.0)
#         Predict: 0.0
#        Else (feature 7 > 7.0)
#         Predict: 0.0
#       Else (feature 1 > 7.0)
#        If (feature 7 <= 7.0)
#         Predict: 0.0
#        Else (feature 7 > 7.0)
#         Predict: 1.0
#     Else (feature 4 > 2.0)
#      If (feature 0 <= 3.0)
#       If (feature 8 <= 2.0)
#        If (feature 9 <= 7.0)
#         Predict: 0.0
#        Else (feature 9 > 7.0)
#         Predict: 1.0
#       Else (feature 8 > 2.0)
#        If (feature 3 <= 8.0)
#         Predict: 0.0
#        Else (feature 3 > 8.0)
#         Predict: 0.0
#      Else (feature 0 > 3.0)
#       If (feature 5 <= 8.0)
#        If (feature 6 <= 2.0)
#         Predict: 0.0
#        Else (feature 6 > 2.0)
#         Predict: 0.0
#       Else (feature 5 > 8.0)
#        If (feature 6 <= 3.0)
#         Predict: 0.0
#        Else (feature 6 > 3.0)
#         Predict: 0.0
#   Tree 2:
#     If (feature 5 <= 1.0)
#      If (feature 3 <= 1.0)
#       If (feature 9 <= 1.0)
#        If (feature 1 <= 3.0)
#         Predict: 6.0
#        Else (feature 1 > 3.0)
#         Predict: 3.0
#       Else (feature 9 > 1.0)
#        If (feature 2 <= 2.0)
#         Predict: 1.0
#        Else (feature 2 > 2.0)
#         Predict: 1.0
#      Else (feature 3 > 1.0)
#       If (feature 7 <= 1.0)
#        If (feature 1 <= 1.0)
#         Predict: 3.0
#        Else (feature 1 > 1.0)
#         Predict: 1.0
#       Else (feature 7 > 1.0)
#        If (feature 9 <= 1.0)
#         Predict: 1.0
#        Else (feature 9 > 1.0)
#         Predict: 0.0
#     Else (feature 5 > 1.0)
#      If (feature 3 <= 10.0)
#       If (feature 7 <= 12.0)
#        If (feature 9 <= 10.0)
#         Predict: 0.0
#        Else (feature 9 > 10.0)
#         Predict: 0.0
#       Else (feature 7 > 12.0)
#        If (feature 9 <= 12.0)
#         Predict: 0.0
#        Else (feature 9 > 12.0)
#         Predict: 1.0
#      Else (feature 3 > 10.0)
#       If (feature 7 <= 10.0)
#        If (feature 9 <= 10.0)
#         Predict: 0.0
#        Else (feature 9 > 10.0)
#         Predict: 0.0
#       Else (feature 7 > 10.0)
#        If (feature 5 <= 10.0)
#         Predict: 1.0
#        Else (feature 5 > 10.0)
#         Predict: 1.0

# %% [markdown]
# When using <b>"log2"</b>, there is a decrease in run-time, along with testing error!

# %% [markdown]
# ---

# %% [markdown]
# ## RandomForest (Regression)

# %% [markdown]
# Now it's time for you to try it out for yourself! Build a Regression RandomForest in a similar way that the Classification RandomForest was built. Please note that you will be using the same dataset in this section (classRF_train, classRF_test), therefore you do not need to re-initialize that section.<br> <br>
#
# Try to only reference the above section when you are experiencing a lot of difficulty. This section is mainly for you to apply your learning.

# %% [markdown]
# For some help with the variables:
# <ul>
#     <li><b>categoricalFeaturesInfo</b>: Has a value of <b>{}</b> (parameter doesn't require tuning)</li>
#     <li><b>featureSubsetStrategy</b>: Can change these values between <b>"auto"</b>, <b>"all"</b>, <b>"sqrt"</b>, <b>"log2"</b>, and <b>"onethird"</b></li>
#     <li><b>numTrees</b>: Values range from <b>1</b> to infinity<i>(Default: 3)</i></li>
#     <ul>
#         <li>Note: If the value is too large, the system can run out of memory and not run.</li>
#     </ul>
#     <li><b>impurity</b>: For Regression, the value must be set to <b>'variance'</b> <i>(Default: 'variance')</i></li>
#     <li><b>maxDepth</b>: Values range between <b>0 and 30</b> <i>(Default: 5)</i></li>
#     <li><b>maxBins</b>: Value ranges between <b>2 and 2147483647</b> (largest value for 32-bits) <i>(Default: 32)</i></li>
#     <li><b>seed</b> Can be set to any value, or to a value based on system time with <i>None</i> <i>(Default: None)</i></li>
# </ul>
#
# When displaying the <b>Mean Squared Error</b>, use the following formula and print statement instead of Training Error: <br>
# <b>regRF_MSE = regRF_label_pred.map(lambda (v, p): (v - p)**2).sum() / float(classRF_test.count())</b> <br>
# <b>print('Test Error = ' + str(regRF_MSE))</b>

# %% [markdown]
# ### The Goal
# Try to create a model that is better than the model with default values.
#
# ### Try to beat!
# With some parameter tuning, I was able to get a run-time increase of the model by ~0.9 seconds and a Test error decrease of ~2.54. Try to get a value similar to this, or better.
#
# ### Note
# We want a model that doesn't take too long to train and will cause overfitting. Remember that a very large model with high accuracy but long run time may not be good because the model may have overfit the data.

# %%
start = time.time()
regRF_model = RandomForest.trainRegressor(classRF_train, categoricalFeaturesInfo={},
                                    numTrees=14, featureSubsetStrategy="onethird",
                                    impurity='variance', maxDepth=11, maxBins=24, seed=None)
print(time.time() - start)
# Evaluate model on test instances and compute test error
regRF_pred = regRF_model.predict(classRF_train.map(lambda x: x.features))
regRF_label_pred = classRF_train.map(lambda lp: lp.label).zip(regRF_pred)
regRF_MSE = regRF_label_pred.map(lambda (v, p): (v - p) ** 2).sum()/\
                                   float(classRF_train.count())
print('Test Mean Squared Error = ' + str(regRF_MSE))
print('Learned regression forest model: ' + regRF_model.toDebugString())
# Out:
# 3.78572702408
# Test Mean Squared Error = 0.346675558881
# Learned regression forest model: TreeEnsembleModel regressor with 14 trees
#
#   Tree 0:
#     If (feature 5 <= 8.0)
#      If (feature 3 <= 8.0)
#       If (feature 1 <= 8.0)
#        If (feature 7 <= 8.0)
#         If (feature 9 <= 8.0)
#          If (feature 5 <= 6.0)
#           If (feature 7 <= 6.0)
#            If (feature 9 <= 6.0)
#             If (feature 7 <= 2.0)
#              If (feature 4 <= 1.0)
#               If (feature 9 <= 3.0)
#                Predict: 1.0
#               Else (feature 9 > 3.0)
#                Predict: 0.4166666666666667
#              Else (feature 4 > 1.0)
#               If (feature 1 <= 3.0)
#                Predict: 1.8571428571428572
#               Else (feature 1 > 3.0)
#                Predict: 0.9083333333333333
#             Else (feature 7 > 2.0)
#              If (feature 3 <= 6.0)
#               If (feature 9 <= 4.0)
#                Predict: 1.3857142857142857
#               Else (feature 9 > 4.0)
#                Predict: 2.0898876404494384
#              Else (feature 3 > 6.0)
#               If (feature 5 <= 1.0)
#                Predict: 0.2222222222222222
#               Else (feature 5 > 1.0)
#                Predict: 0.8924731182795699
#            Else (feature 9 > 6.0)
#             If (feature 7 <= 1.0)
#              If (feature 5 <= 2.0)
#               If (feature 8 <= 3.0)
#                Predict: 1.3333333333333333
#               Else (feature 8 > 3.0)
#                Predict: 4.25
#              Else (feature 5 > 2.0)
#               If (feature 2 <= 3.0)
#                Predict: 1.1666666666666667
#               Else (feature 2 > 3.0)
#                Predict: 2.0
#             Else (feature 7 > 1.0)
#              If (feature 5 <= 3.0)
#               If (feature 4 <= 3.0)
#                Predict: 0.5901639344262295
#               Else (feature 4 > 3.0)
#                Predict: 1.15
#              Else (feature 5 > 3.0)
#               If (feature 4 <= 1.0)
#                Predict: 1.5454545454545454
#               Else (feature 4 > 1.0)
#                Predict: 0.9701492537313433
#           Else (feature 7 > 6.0)
#            If (feature 2 <= 2.0)
#             If (feature 7 <= 7.0)
#              If (feature 0 <= 1.0)
#               If (feature 4 <= 1.0)
#                Predict: 1.0
#               Else (feature 4 > 1.0)
#                Predict: 1.6
#              Else (feature 0 > 1.0)
#               If (feature 9 <= 1.0)
#                Predict: 0.5
#               Else (feature 9 > 1.0)
#                Predict: 0.9069767441860465
#             Else (feature 7 > 7.0)
#              If (feature 2 <= 1.0)
#               If (feature 9 <= 1.0)
#                Predict: 2.0
#               Else (feature 9 > 1.0)
#                Predict: 0.7368421052631579
#              Else (feature 2 > 1.0)
#               If (feature 5 <= 3.0)
#                Predict: 0.5
#               Else (feature 5 > 3.0)
#                Predict: 2.3125
#            Else (feature 2 > 2.0)
#             If (feature 8 <= 2.0)
#              If (feature 9 <= 1.0)
#               If (feature 3 <= 2.0)
#                Predict: 0.3333333333333333
#               Else (feature 3 > 2.0)
#                Predict: 0.0
#              Else (feature 9 > 1.0)
#               If (feature 1 <= 1.0)
#                Predict: 0.0
#               Else (feature 1 > 1.0)
#                Predict: 0.7142857142857143
#             Else (feature 8 > 2.0)
#              If (feature 9 <= 3.0)
#               If (feature 8 <= 3.0)
#                Predict: 0.8888888888888888
#               Else (feature 8 > 3.0)
#                Predict: 0.3
#              Else (feature 9 > 3.0)
#               If (feature 5 <= 5.0)
#                Predict: 0.9487179487179487
#               Else (feature 5 > 5.0)
#                Predict: 1.6666666666666667
#          Else (feature 5 > 6.0)
#           If (feature 9 <= 4.0)
#            If (feature 9 <= 3.0)
#             If (feature 6 <= 2.0)
#              If (feature 6 <= 1.0)
#               If (feature 7 <= 6.0)
#                Predict: 0.6842105263157895
#               Else (feature 7 > 6.0)
#                Predict: 1.5
#              Else (feature 6 > 1.0)
#               If (feature 7 <= 4.0)
#                Predict: 0.7333333333333333
#               Else (feature 7 > 4.0)
#                Predict: 0.2
#             Else (feature 6 > 2.0)
#              If (feature 1 <= 3.0)
#               If (feature 3 <= 3.0)
#                Predict: 0.9285714285714286
#               Else (feature 3 > 3.0)
#                Predict: 1.4
#              Else (feature 1 > 3.0)
#               If (feature 0 <= 3.0)
#                Predict: 0.7142857142857143
#               Else (feature 0 > 3.0)
#                Predict: 1.1111111111111112
#            Else (feature 9 > 3.0)
#             If (feature 7 <= 2.0)
#              If (feature 3 <= 4.0)
#               Predict: 1.0
#              Else (feature 3 > 4.0)
#               If (feature 8 <= 1.0)
#                Predict: 0.0
#               Else (feature 8 > 1.0)
#                Predict: 0.25
#             Else (feature 7 > 2.0)
#              If (feature 5 <= 7.0)
#               If (feature 8 <= 2.0)
#                Predict: 0.625
#               Else (feature 8 > 2.0)
#                Predict: 0.0
#              Else (feature 5 > 7.0)
#               If (feature 1 <= 2.0)
#                Predict: 1.0
#               Else (feature 1 > 2.0)
#                Predict: 1.2
#           Else (feature 9 > 4.0)
#            If (feature 7 <= 6.0)
#             If (feature 3 <= 7.0)
#              If (feature 2 <= 1.0)
#               If (feature 3 <= 1.0)
#                Predict: 3.8
#               Else (feature 3 > 1.0)
#                Predict: 1.2
#              Else (feature 2 > 1.0)
#               If (feature 6 <= 3.0)
#                Predict: 0.611764705882353
#               Else (feature 6 > 3.0)
#                Predict: 1.0869565217391304
#             Else (feature 3 > 7.0)
#              If (feature 9 <= 5.0)
#               If (feature 1 <= 2.0)
#                Predict: 1.0
#               Else (feature 1 > 2.0)
#                Predict: 4.0
#              Else (feature 9 > 5.0)
#               If (feature 1 <= 4.0)
#                Predict: 0.625
#               Else (feature 1 > 4.0)
#                Predict: 2.0
#            Else (feature 7 > 6.0)
#             If (feature 1 <= 3.0)
#              If (feature 8 <= 2.0)
#               If (feature 0 <= 3.0)
#                Predict: 1.0
#               Else (feature 0 > 3.0)
#                Predict: 0.0
#              Else (feature 8 > 2.0)
#               If (feature 9 <= 5.0)
#                Predict: 2.5
#               Else (feature 9 > 5.0)
#                Predict: 2.0
#             Else (feature 1 > 3.0)
#              If (feature 9 <= 5.0)
#               If (feature 6 <= 3.0)
#                Predict: 2.5
#               Else (feature 6 > 3.0)
#                Predict: 4.0
#              Else (feature 9 > 5.0)
#               If (feature 2 <= 1.0)
#                Predict: 2.6666666666666665
#               Else (feature 2 > 1.0)
#                Predict: 1.0909090909090908
#         Else (feature 9 > 8.0)
#          If (feature 5 <= 3.0)
#           If (feature 4 <= 3.0)
#            If (feature 2 <= 2.0)
#             If (feature 8 <= 2.0)
#              If (feature 3 <= 7.0)
#               If (feature 1 <= 1.0)
#                Predict: 1.3333333333333333
#               Else (feature 1 > 1.0)
#                Predict: 0.6666666666666666
#              Else (feature 3 > 7.0)
#               If (feature 7 <= 3.0)
#                Predict: 0.6
#               Else (feature 7 > 3.0)
#                Predict: 0.07692307692307693
#             Else (feature 8 > 2.0)
#              If (feature 1 <= 2.0)
#               If (feature 7 <= 5.0)
#                Predict: 3.5
#               Else (feature 7 > 5.0)
#                Predict: 0.6666666666666666
#              Else (feature 1 > 2.0)
#               If (feature 9 <= 12.0)
#                Predict: 1.0217391304347827
#               Else (feature 9 > 12.0)
#                Predict: 0.25
#            Else (feature 2 > 2.0)
#             If (feature 8 <= 3.0)
#              If (feature 9 <= 11.0)
#               If (feature 0 <= 2.0)
#                Predict: 0.9310344827586207
#               Else (feature 0 > 2.0)
#                Predict: 0.6511627906976745
#              Else (feature 9 > 11.0)
#               If (feature 8 <= 1.0)
#                Predict: 0.7857142857142857
#               Else (feature 8 > 1.0)
#                Predict: 0.2962962962962963
#             Else (feature 8 > 3.0)
#              If (feature 7 <= 3.0)
#               If (feature 4 <= 2.0)
#                Predict: 0.18181818181818182
#               Else (feature 4 > 2.0)
#                Predict: 0.0
#              Else (feature 7 > 3.0)
#               If (feature 5 <= 1.0)
#                Predict: 0.6875
#               Else (feature 5 > 1.0)
#                Predict: 0.26666666666666666
#           Else (feature 4 > 3.0)
#            If (feature 9 <= 11.0)
#             If (feature 3 <= 6.0)
#              If (feature 7 <= 2.0)
#               If (feature 0 <= 1.0)
#                Predict: 1.6666666666666667
#               Else (feature 0 > 1.0)
#                Predict: 1.0
#              Else (feature 7 > 2.0)
#               If (feature 3 <= 3.0)
#                Predict: 0.8571428571428571
#               Else (feature 3 > 3.0)
#                Predict: 0.0
#             Else (feature 3 > 6.0)
#              If (feature 8 <= 2.0)
#               If (feature 0 <= 1.0)
#                Predict: 0.3333333333333333
#               Else (feature 0 > 1.0)
#                Predict: 0.0
#              Else (feature 8 > 2.0)
#               If (feature 5 <= 2.0)
#                Predict: 0.8333333333333334
#               Else (feature 5 > 2.0)
#                Predict: 0.0
#            Else (feature 9 > 11.0)
#             If (feature 6 <= 3.0)
#              If (feature 7 <= 3.0)
#               If (feature 1 <= 6.0)
#                Predict: 1.9230769230769231
#               Else (feature 1 > 6.0)
#                Predict: 0.75
#              Else (feature 7 > 3.0)
#               If (feature 5 <= 2.0)
#                Predict: 0.8181818181818182
#               Else (feature 5 > 2.0)
#                Predict: 0.0
#             Else (feature 6 > 3.0)
#              If (feature 8 <= 2.0)
#               If (feature 7 <= 4.0)
#                Predict: 0.5
#               Else (feature 7 > 4.0)
#                Predict: 2.0
#              Else (feature 8 > 2.0)
#               Predict: 5.0
#          Else (feature 5 > 3.0)
#           If (feature 5 <= 7.0)
#            If (feature 0 <= 3.0)
#             If (feature 5 <= 6.0)
#              If (feature 3 <= 3.0)
#               If (feature 1 <= 3.0)
#                Predict: 0.10714285714285714
#               Else (feature 1 > 3.0)
#                Predict: 0.53125
#              Else (feature 3 > 3.0)
#               If (feature 7 <= 3.0)
#                Predict: 0.3181818181818182
#               Else (feature 7 > 3.0)
#                Predict: 0.8552631578947368
#             Else (feature 5 > 6.0)
#              If (feature 8 <= 1.0)
#               If (feature 7 <= 6.0)
#                Predict: 0.2
#               Else (feature 7 > 6.0)
#                Predict: 1.25
#              Else (feature 8 > 1.0)
#               If (feature 8 <= 2.0)
#                Predict: 1.09375
#               Else (feature 8 > 2.0)
#                Predict: 0.6071428571428571
#            Else (feature 0 > 3.0)
#             If (feature 8 <= 3.0)
#              If (feature 9 <= 9.0)
#               If (feature 8 <= 2.0)
#                Predict: 0.0
#               Else (feature 8 > 2.0)
#                Predict: 0.2
#              Else (feature 9 > 9.0)
#               If (feature 5 <= 6.0)
#                Predict: 0.5471698113207547
#               Else (feature 5 > 6.0)
#                Predict: 0.1875
#             Else (feature 8 > 3.0)
#              If (feature 7 <= 6.0)
#               If (feature 6 <= 2.0)
#                Predict: 1.375
#               Else (feature 6 > 2.0)
#                Predict: 0.4166666666666667
#              Else (feature 7 > 6.0)
#               If (feature 3 <= 4.0)
#                Predict: 0.0
#               Else (feature 3 > 4.0)
#                Predict: 0.75
#           Else (feature 5 > 7.0)
#            If (feature 3 <= 7.0)
#             If (feature 3 <= 4.0)
#              If (feature 7 <= 7.0)
#               If (feature 2 <= 1.0)
#                Predict: 0.09090909090909091
#               Else (feature 2 > 1.0)
#                Predict: 0.5957446808510638
#              Else (feature 7 > 7.0)
#               If (feature 4 <= 3.0)
#                Predict: 1.0909090909090908
#               Else (feature 4 > 3.0)
#                Predict: 3.0
#             Else (feature 3 > 4.0)
#              If (feature 7 <= 4.0)
#               If (feature 4 <= 1.0)
#                Predict: 0.42857142857142855
#               Else (feature 4 > 1.0)
#                Predict: 0.10526315789473684
#              Else (feature 7 > 4.0)
#               If (feature 2 <= 1.0)
#                Predict: 0.0
#               Else (feature 2 > 1.0)
#                Predict: 0.8823529411764706
#            Else (feature 3 > 7.0)
#             If (feature 7 <= 7.0)
#              If (feature 9 <= 9.0)
#               If (feature 4 <= 1.0)
#                Predict: 2.0
#               Else (feature 4 > 1.0)
#                Predict: 2.5
#              Else (feature 9 > 9.0)
#               If (feature 0 <= 3.0)
#                Predict: 1.0
#               Else (feature 0 > 3.0)
#                Predict: 1.75
#             Else (feature 7 > 7.0)
#              Predict: 3.0
#        Else (feature 7 > 8.0)
#         If (feature 3 <= 7.0)
#          If (feature 9 <= 7.0)
#           If (feature 2 <= 3.0)
#            If (feature 7 <= 10.0)
#             If (feature 6 <= 1.0)
#              If (feature 0 <= 2.0)
#               If (feature 9 <= 1.0)
#                Predict: 0.0
#               Else (feature 9 > 1.0)
#                Predict: 0.9090909090909091
#              Else (feature 0 > 2.0)
#               If (feature 8 <= 3.0)
#                Predict: 0.32432432432432434
#               Else (feature 8 > 3.0)
#                Predict: 1.0
#             Else (feature 6 > 1.0)
#              If (feature 0 <= 2.0)
#               If (feature 8 <= 1.0)
#                Predict: 1.375
#               Else (feature 8 > 1.0)
#                Predict: 0.835820895522388
#              Else (feature 0 > 2.0)
#               If (feature 1 <= 5.0)
#                Predict: 0.7704918032786885
#               Else (feature 1 > 5.0)
#                Predict: 0.4090909090909091
#            Else (feature 7 > 10.0)
#             If (feature 2 <= 2.0)
#              If (feature 6 <= 1.0)
#               If (feature 0 <= 2.0)
#                Predict: 0.6
#               Else (feature 0 > 2.0)
#                Predict: 1.2857142857142858
#              Else (feature 6 > 1.0)
#               If (feature 5 <= 7.0)
#                Predict: 0.5433070866141733
#               Else (feature 5 > 7.0)
#                Predict: 0.15
#             Else (feature 2 > 2.0)
#              If (feature 8 <= 1.0)
#               If (feature 1 <= 5.0)
#                Predict: 0.95
#               Else (feature 1 > 5.0)
#                Predict: 0.2857142857142857
#              Else (feature 8 > 1.0)
#               If (feature 1 <= 6.0)
#                Predict: 0.28125
#               Else (feature 1 > 6.0)
#                Predict: 0.631578947368421
#           Else (feature 2 > 3.0)
#            If (feature 7 <= 9.0)
#             If (feature 4 <= 3.0)
#              If (feature 9 <= 5.0)
#               If (feature 6 <= 1.0)
#                Predict: 0.25
#               Else (feature 6 > 1.0)
#                Predict: 0.0
#              Else (feature 9 > 5.0)
#               Predict: 1.0
#             Else (feature 4 > 3.0)
#              If (feature 1 <= 3.0)
#               Predict: 0.0
#              Else (feature 1 > 3.0)
#               If (feature 3 <= 5.0)
#                Predict: 1.0
#               Else (feature 3 > 5.0)
#                Predict: 0.0
#            Else (feature 7 > 9.0)
#             If (feature 5 <= 7.0)
#              If (feature 7 <= 11.0)
#               If (feature 5 <= 1.0)
#                Predict: 1.5
#               Else (feature 5 > 1.0)
#                Predict: 0.423728813559322
#              Else (feature 7 > 11.0)
#               If (feature 1 <= 5.0)
#                Predict: 1.0588235294117647
#               Else (feature 1 > 5.0)
#                Predict: 0.36
#             Else (feature 5 > 7.0)
#              If (feature 6 <= 2.0)
#               If (feature 8 <= 2.0)
#                Predict: 1.0
#               Else (feature 8 > 2.0)
#                Predict: 0.2727272727272727
#              Else (feature 6 > 2.0)
#               Predict: 0.0
#          Else (feature 9 > 7.0)
#           If (feature 8 <= 2.0)
#            If (feature 2 <= 2.0)
#             If (feature 5 <= 5.0)
#              If (feature 4 <= 3.0)
#               If (feature 6 <= 1.0)
#                Predict: 0.7058823529411765
#               Else (feature 6 > 1.0)
#                Predict: 0.19696969696969696
#              Else (feature 4 > 3.0)
#               If (feature 7 <= 11.0)
#                Predict: 0.3333333333333333
#               Else (feature 7 > 11.0)
#                Predict: 1.25
#             Else (feature 5 > 5.0)
#              If (feature 8 <= 1.0)
#               If (feature 9 <= 10.0)
#                Predict: 0.0
#               Else (feature 9 > 10.0)
#                Predict: 0.14285714285714285
#              Else (feature 8 > 1.0)
#               If (feature 3 <= 4.0)
#                Predict: 0.13333333333333333
#               Else (feature 3 > 4.0)
#                Predict: 0.8571428571428571
#            Else (feature 2 > 2.0)
#             If (feature 5 <= 2.0)
#              If (feature 1 <= 3.0)
#               If (feature 7 <= 12.0)
#                Predict: 0.8461538461538461
#               Else (feature 7 > 12.0)
#                Predict: 6.0
#              Else (feature 1 > 3.0)
#               If (feature 9 <= 9.0)
#                Predict: 1.0
#               Else (feature 9 > 9.0)
#                Predict: 0.13333333333333333
#             Else (feature 5 > 2.0)
#              If (feature 0 <= 2.0)
#               If (feature 3 <= 4.0)
#                Predict: 0.09375
#               Else (feature 3 > 4.0)
#                Predict: 0.6296296296296297
#              Else (feature 0 > 2.0)
#               If (feature 3 <= 5.0)
#                Predict: 0.6285714285714286
#               Else (feature 3 > 5.0)
#                Predict: 0.16666666666666666
#           Else (feature 8 > 2.0)
#            If (feature 4 <= 1.0)
#             If (feature 0 <= 2.0)
#              If (feature 5 <= 2.0)
#               If (feature 1 <= 1.0)
#                Predict: 2.0
#               Else (feature 1 > 1.0)
#                Predict: 0.15
#              Else (feature 5 > 2.0)
#               If (feature 9 <= 11.0)
#                Predict: 0.7837837837837838
#               Else (feature 9 > 11.0)
#                Predict: 0.0
#             Else (feature 0 > 2.0)
#              If (feature 7 <= 12.0)
#               If (feature 6 <= 2.0)
#                Predict: 1.411764705882353
#               Else (feature 6 > 2.0)
#                Predict: 0.5
#              Else (feature 7 > 12.0)
#               If (feature 6 <= 1.0)
#                Predict: 1.0
#               Else (feature 6 > 1.0)
#                Predict: 0.0
#            Else (feature 4 > 1.0)
#             If (feature 5 <= 7.0)
#              If (feature 2 <= 1.0)
#               If (feature 5 <= 2.0)
#                Predict: 0.21428571428571427
#               Else (feature 5 > 2.0)
#                Predict: 0.6571428571428571
#              Else (feature 2 > 1.0)
#               If (feature 6 <= 1.0)
#                Predict: 0.53125
#               Else (feature 6 > 1.0)
#                Predict: 0.31683168316831684
#             Else (feature 5 > 7.0)
#              If (feature 8 <= 3.0)
#               If (feature 3 <= 2.0)
#                Predict: 1.25
#               Else (feature 3 > 2.0)
#                Predict: 0.8571428571428571
#              Else (feature 8 > 3.0)
#               If (feature 4 <= 3.0)
#                Predict: 0.7272727272727273
#               Else (feature 4 > 3.0)
#                Predict: 0.0
#         Else (feature 3 > 7.0)
#          If (feature 9 <= 11.0)
#           If (feature 8 <= 1.0)
#            If (feature 5 <= 6.0)
#             If (feature 1 <= 7.0)
#              If (feature 2 <= 3.0)
#               If (feature 0 <= 3.0)
#                Predict: 0.06666666666666667
#               Else (feature 0 > 3.0)
#                Predict: 0.3333333333333333
#              Else (feature 2 > 3.0)
#               If (feature 1 <= 1.0)
#                Predict: 0.8571428571428571
#               Else (feature 1 > 1.0)
#                Predict: 0.3333333333333333
#             Else (feature 1 > 7.0)
#              If (feature 6 <= 1.0)
#               Predict: 1.0
#              Else (feature 6 > 1.0)
#               Predict: 3.0
#            Else (feature 5 > 6.0)
#             Predict: 0.0
#           Else (feature 8 > 1.0)
#            If (feature 4 <= 2.0)
#             If (feature 1 <= 7.0)
#              If (feature 5 <= 6.0)
#               If (feature 5 <= 1.0)
#                Predict: 0.0
#               Else (feature 5 > 1.0)
#                Predict: 0.2608695652173913
#              Else (feature 5 > 6.0)
#               If (feature 1 <= 5.0)
#                Predict: 0.8888888888888888
#               Else (feature 1 > 5.0)
#                Predict: 2.0
#             Else (feature 1 > 7.0)
#              Predict: 1.0
#            Else (feature 4 > 2.0)
#             If (feature 5 <= 7.0)
#              If (feature 1 <= 7.0)
#               If (feature 8 <= 3.0)
#                Predict: 0.4782608695652174
#               Else (feature 8 > 3.0)
#                Predict: 1.0
#              Else (feature 1 > 7.0)
#               If (feature 8 <= 2.0)
#                Predict: 1.375
#               Else (feature 8 > 2.0)
#                Predict: 1.0
#             Else (feature 5 > 7.0)
#              If (feature 7 <= 9.0)
#               Predict: 1.0
#              Else (feature 7 > 9.0)
#               If (feature 1 <= 1.0)
#                Predict: 1.0
#               Else (feature 1 > 1.0)
#                Predict: 1.875
#          Else (feature 9 > 11.0)
#           If (feature 1 <= 7.0)
#            If (feature 1 <= 1.0)
#             If (feature 6 <= 1.0)
#              Predict: 1.0
#             Else (feature 6 > 1.0)
#              Predict: 2.0
#            Else (feature 1 > 1.0)
#             If (feature 2 <= 1.0)
#              Predict: 0.0
#             Else (feature 2 > 1.0)
#              If (feature 6 <= 1.0)
#               Predict: 1.0
#              Else (feature 6 > 1.0)
#               If (feature 8 <= 2.0)
#                Predict: 0.5555555555555556
#               Else (feature 8 > 2.0)
#                Predict: 0.0
#           Else (feature 1 > 7.0)
#            If (feature 0 <= 1.0)
#             Predict: 1.0
#            Else (feature 0 > 1.0)
#             If (feature 7 <= 12.0)
#              Predict: 2.0
#             Else (feature 7 > 12.0)
#              Predict: 6.0
#       Else (feature 1 > 8.0)
#        If (feature 4 <= 2.0)
#         If (feature 8 <= 1.0)
#          If (feature 6 <= 1.0)
#           If (feature 5 <= 6.0)
#            If (feature 5 <= 4.0)
#             If (feature 2 <= 1.0)
#              If (feature 0 <= 1.0)
#               Predict: 5.0
#              Else (feature 0 > 1.0)
#               Predict: 0.0
#             Else (feature 2 > 1.0)
#              If (feature 2 <= 3.0)
#               If (feature 3 <= 7.0)
#                Predict: 0.48148148148148145
#               Else (feature 3 > 7.0)
#                Predict: 0.0
#              Else (feature 2 > 3.0)
#               If (feature 3 <= 3.0)
#                Predict: 1.1428571428571428
#               Else (feature 3 > 3.0)
#                Predict: 0.0
#            Else (feature 5 > 4.0)
#             If (feature 9 <= 5.0)
#              If (feature 0 <= 1.0)
#               If (feature 7 <= 7.0)
#                Predict: 1.0
#               Else (feature 7 > 7.0)
#                Predict: 0.0
#              Else (feature 0 > 1.0)
#               If (feature 7 <= 5.0)
#                Predict: 1.0
#               Else (feature 7 > 5.0)
#                Predict: 0.0
#             Else (feature 9 > 5.0)
#              If (feature 0 <= 1.0)
#               Predict: 5.0
#              Else (feature 0 > 1.0)
#               Predict: 1.0
#           Else (feature 5 > 6.0)
#            If (feature 7 <= 12.0)
#             If (feature 7 <= 5.0)
#              If (feature 7 <= 1.0)
#               Predict: 1.0
#              Else (feature 7 > 1.0)
#               Predict: 5.0
#             Else (feature 7 > 5.0)
#              If (feature 1 <= 10.0)
#               If (feature 3 <= 7.0)
#                Predict: 1.0
#               Else (feature 3 > 7.0)
#                Predict: 3.0
#              Else (feature 1 > 10.0)
#               If (feature 7 <= 6.0)
#                Predict: 0.0
#               Else (feature 7 > 6.0)
#                Predict: 1.0
#            Else (feature 7 > 12.0)
#             Predict: 6.0
#          Else (feature 6 > 1.0)
#           If (feature 3 <= 7.0)
#            If (feature 9 <= 5.0)
#             If (feature 0 <= 3.0)
#              If (feature 1 <= 12.0)
#               If (feature 0 <= 1.0)
#                Predict: 0.7857142857142857
#               Else (feature 0 > 1.0)
#                Predict: 0.4642857142857143
#              Else (feature 1 > 12.0)
#               If (feature 4 <= 1.0)
#                Predict: 0.75
#               Else (feature 4 > 1.0)
#                Predict: 1.5714285714285714
#             Else (feature 0 > 3.0)
#              If (feature 7 <= 1.0)
#               Predict: 0.0
#              Else (feature 7 > 1.0)
#               If (feature 6 <= 2.0)
#                Predict: 0.75
#               Else (feature 6 > 2.0)
#                Predict: 1.8888888888888888
#            Else (feature 9 > 5.0)
#             If (feature 3 <= 6.0)
#              If (feature 6 <= 2.0)
#               If (feature 9 <= 10.0)
#                Predict: 0.06666666666666667
#               Else (feature 9 > 10.0)
#                Predict: 0.3333333333333333
#              Else (feature 6 > 2.0)
#               If (feature 7 <= 9.0)
#                Predict: 0.4186046511627907
#               Else (feature 7 > 9.0)
#                Predict: 0.75
#             Else (feature 3 > 6.0)
#              If (feature 9 <= 9.0)
#               If (feature 4 <= 1.0)
#                Predict: 2.0
#               Else (feature 4 > 1.0)
#                Predict: 0.5
#              Else (feature 9 > 9.0)
#               Predict: 0.0
#           Else (feature 3 > 7.0)
#            If (feature 9 <= 7.0)
#             If (feature 1 <= 11.0)
#              If (feature 9 <= 5.0)
#               Predict: 0.0
#              Else (feature 9 > 5.0)
#               If (feature 7 <= 1.0)
#                Predict: 0.0
#               Else (feature 7 > 1.0)
#                Predict: 1.0
#             Else (feature 1 > 11.0)
#              If (feature 7 <= 3.0)
#               Predict: 0.0
#              Else (feature 7 > 3.0)
#               Predict: 1.0
#            Else (feature 9 > 7.0)
#             If (feature 9 <= 11.0)
#              Predict: 1.0
#             Else (feature 9 > 11.0)
#              Predict: 0.0
#         Else (feature 8 > 1.0)
#          If (feature 1 <= 11.0)
#           If (feature 9 <= 11.0)
#            If (feature 7 <= 12.0)
#             If (feature 5 <= 1.0)
#              If (feature 7 <= 1.0)
#               If (feature 2 <= 2.0)
#                Predict: 1.0
#               Else (feature 2 > 2.0)
#                Predict: 2.0
#              Else (feature 7 > 1.0)
#               If (feature 7 <= 3.0)
#                Predict: 0.375
#               Else (feature 7 > 3.0)
#                Predict: 1.0434782608695652
#             Else (feature 5 > 1.0)
#              If (feature 7 <= 7.0)
#               If (feature 6 <= 1.0)
#                Predict: 0.7872340425531915
#               Else (feature 6 > 1.0)
#                Predict: 0.5957446808510638
#              Else (feature 7 > 7.0)
#               If (feature 3 <= 1.0)
#                Predict: 1.4210526315789473
#               Else (feature 3 > 1.0)
#                Predict: 0.7586206896551724
#            Else (feature 7 > 12.0)
#             If (feature 9 <= 6.0)
#              If (feature 3 <= 1.0)
#               Predict: 0.0
#              Else (feature 3 > 1.0)
#               If (feature 1 <= 9.0)
#                Predict: 0.375
#               Else (feature 1 > 9.0)
#                Predict: 0.08333333333333333
#             Else (feature 9 > 6.0)
#              If (feature 0 <= 3.0)
#               If (feature 6 <= 1.0)
#                Predict: 0.4444444444444444
#               Else (feature 6 > 1.0)
#                Predict: 0.8
#              Else (feature 0 > 3.0)
#               Predict: 0.0
#           Else (feature 9 > 11.0)
#            If (feature 6 <= 3.0)
#             If (feature 5 <= 5.0)
#              If (feature 7 <= 7.0)
#               If (feature 3 <= 1.0)
#                Predict: 1.0
#               Else (feature 3 > 1.0)
#                Predict: 0.17647058823529413
#              Else (feature 7 > 7.0)
#               If (feature 8 <= 3.0)
#                Predict: 0.45454545454545453
#               Else (feature 8 > 3.0)
#                Predict: 1.0
#             Else (feature 5 > 5.0)
#              If (feature 5 <= 7.0)
#               If (feature 0 <= 3.0)
#                Predict: 1.0769230769230769
#               Else (feature 0 > 3.0)
#                Predict: 0.5
#              Else (feature 5 > 7.0)
#               If (feature 0 <= 2.0)
#                Predict: 0.7142857142857143
#               Else (feature 0 > 2.0)
#                Predict: 0.0
#            Else (feature 6 > 3.0)
#             If (feature 8 <= 2.0)
#              If (feature 7 <= 1.0)
#               Predict: 0.0
#              Else (feature 7 > 1.0)
#               Predict: 1.0
#             Else (feature 8 > 2.0)
#              If (feature 5 <= 7.0)
#               If (feature 1 <= 9.0)
#                Predict: 0.5
#               Else (feature 1 > 9.0)
#                Predict: 0.0
#              Else (feature 5 > 7.0)
#               If (feature 7 <= 2.0)
#                Predict: 0.0
#               Else (feature 7 > 2.0)
#                Predict: 1.0
#          Else (feature 1 > 11.0)
#           If (feature 7 <= 11.0)
#            If (feature 6 <= 2.0)
#             If (feature 0 <= 1.0)
#              If (feature 9 <= 8.0)
#               If (feature 4 <= 1.0)
#                Predict: 0.26666666666666666
#               Else (feature 4 > 1.0)
#                Predict: 0.0
#              Else (feature 9 > 8.0)
#               If (feature 5 <= 5.0)
#                Predict: 0.6
#               Else (feature 5 > 5.0)
#                Predict: 2.0
#             Else (feature 0 > 1.0)
#              If (feature 3 <= 6.0)
#               If (feature 6 <= 1.0)
#                Predict: 0.5098039215686274
#               Else (feature 6 > 1.0)
#                Predict: 0.4166666666666667
#              Else (feature 3 > 6.0)
#               If (feature 5 <= 1.0)
#                Predict: 1.0
#               Else (feature 5 > 1.0)
#                Predict: 0.17777777777777778
#            Else (feature 6 > 2.0)
#             If (feature 9 <= 8.0)
#              If (feature 4 <= 1.0)
#               If (feature 8 <= 2.0)
#                Predict: 0.9615384615384616
#               Else (feature 8 > 2.0)
#                Predict: 0.5454545454545454
#              Else (feature 4 > 1.0)
#               If (feature 5 <= 5.0)
#                Predict: 0.7575757575757576
#               Else (feature 5 > 5.0)
#                Predict: 0.13636363636363635
#             Else (feature 9 > 8.0)
#              If (feature 0 <= 1.0)
#               Predict: 0.0
#              Else (feature 0 > 1.0)
#               If (feature 9 <= 10.0)
#                Predict: 0.25
#               Else (feature 9 > 10.0)
#                Predict: 0.5609756097560976
#           Else (feature 7 > 11.0)
#            If (feature 9 <= 12.0)
#             If (feature 1 <= 12.0)
#              If (feature 6 <= 3.0)
#               If (feature 3 <= 7.0)
#                Predict: 0.5238095238095238
#               Else (feature 3 > 7.0)
#                Predict: 2.0
#              Else (feature 6 > 3.0)
#               Predict: 0.0
#             Else (feature 1 > 12.0)
#              If (feature 7 <= 12.0)
#               If (feature 5 <= 1.0)
#                Predict: 1.0
#               Else (feature 5 > 1.0)
#                Predict: 0.3333333333333333
#              Else (feature 7 > 12.0)
#               If (feature 5 <= 4.0)
#                Predict: 1.0
#               Else (feature 5 > 4.0)
#                Predict: 1.8333333333333333
#            Else (feature 9 > 12.0)
#             If (feature 0 <= 1.0)
#              Predict: 1.0
#             Else (feature 0 > 1.0)
#              Predict: 3.0
#        Else (feature 4 > 2.0)
#         If (feature 7 <= 11.0)
#          If (feature 9 <= 9.0)
#           If (feature 8 <= 3.0)
#            If (feature 7 <= 10.0)
#             If (feature 7 <= 4.0)
#              If (feature 9 <= 4.0)
#               If (feature 5 <= 4.0)
#                Predict: 1.125
#               Else (feature 5 > 4.0)
#                Predict: 0.5555555555555556
#              Else (feature 9 > 4.0)
#               If (feature 3 <= 5.0)
#                Predict: 0.3783783783783784
#               Else (feature 3 > 5.0)
#                Predict: 0.8275862068965517
#             Else (feature 7 > 4.0)
#              If (feature 6 <= 2.0)
#               If (feature 1 <= 10.0)
#                Predict: 0.7241379310344828
#               Else (feature 1 > 10.0)
#                Predict: 0.3020833333333333
#              Else (feature 6 > 2.0)
#               If (feature 9 <= 2.0)
#                Predict: 0.2857142857142857
#               Else (feature 9 > 2.0)
#                Predict: 0.7019867549668874
#            Else (feature 7 > 10.0)
#             If (feature 8 <= 1.0)
#              If (feature 6 <= 2.0)
#               Predict: 0.0
#              Else (feature 6 > 2.0)
#               If (feature 0 <= 1.0)
#                Predict: 0.3333333333333333
#               Else (feature 0 > 1.0)
#                Predict: 1.0
#             Else (feature 8 > 1.0)
#              If (feature 1 <= 11.0)
#               If (feature 6 <= 1.0)
#                Predict: 0.3333333333333333
#               Else (feature 6 > 1.0)
#                Predict: 2.0
#              Else (feature 1 > 11.0)
#               If (feature 3 <= 5.0)
#                Predict: 0.9
#               Else (feature 3 > 5.0)
#                Predict: 0.0
#           Else (feature 8 > 3.0)
#            If (feature 3 <= 6.0)
#             If (feature 7 <= 3.0)
#              If (feature 5 <= 4.0)
#               If (feature 5 <= 3.0)
#                Predict: 0.8695652173913043
#               Else (feature 5 > 3.0)
#                Predict: 3.0
#              Else (feature 5 > 4.0)
#               If (feature 9 <= 1.0)
#                Predict: 1.0
#               Else (feature 9 > 1.0)
#                Predict: 0.16666666666666666
#             Else (feature 7 > 3.0)
#              If (feature 1 <= 9.0)
#               If (feature 5 <= 1.0)
#                Predict: 0.0
#               Else (feature 5 > 1.0)
#                Predict: 1.125
#              Else (feature 1 > 9.0)
#               If (feature 3 <= 3.0)
#                Predict: 0.24390243902439024
#               Else (feature 3 > 3.0)
#                Predict: 0.4897959183673469
#            Else (feature 3 > 6.0)
#             If (feature 5 <= 6.0)
#              If (feature 6 <= 1.0)
#               If (feature 4 <= 3.0)
#                Predict: 0.0
#               Else (feature 4 > 3.0)
#                Predict: 0.6666666666666666
#              Else (feature 6 > 1.0)
#               If (feature 0 <= 3.0)
#                Predict: 0.0
#               Else (feature 0 > 3.0)
#                Predict: 0.14285714285714285
#             Else (feature 5 > 6.0)
#              If (feature 6 <= 3.0)
#               If (feature 7 <= 1.0)
#                Predict: 0.0
#               Else (feature 7 > 1.0)
#                Predict: 1.0
#              Else (feature 6 > 3.0)
#               Predict: 0.0
#          Else (feature 9 > 9.0)
#           If (feature 7 <= 10.0)
#            If (feature 3 <= 6.0)
#             If (feature 7 <= 5.0)
#              If (feature 9 <= 12.0)
#               If (feature 1 <= 9.0)
#                Predict: 0.4
#               Else (feature 1 > 9.0)
#                Predict: 0.6507936507936508
#              Else (feature 9 > 12.0)
#               If (feature 8 <= 1.0)
#                Predict: 0.8
#               Else (feature 8 > 1.0)
#                Predict: 0.21052631578947367
#             Else (feature 7 > 5.0)
#              If (feature 1 <= 12.0)
#               If (feature 3 <= 4.0)
#                Predict: 0.32558139534883723
#               Else (feature 3 > 4.0)
#                Predict: 0.6842105263157895
#              Else (feature 1 > 12.0)
#               If (feature 0 <= 1.0)
#                Predict: 0.25
#               Else (feature 0 > 1.0)
#                Predict: 0.05555555555555555
#            Else (feature 3 > 6.0)
#             If (feature 5 <= 5.0)
#              If (feature 8 <= 1.0)
#               If (feature 5 <= 3.0)
#                Predict: 0.8
#               Else (feature 5 > 3.0)
#                Predict: 0.0
#              Else (feature 8 > 1.0)
#               If (feature 7 <= 6.0)
#                Predict: 0.0
#               Else (feature 7 > 6.0)
#                Predict: 0.125
#             Else (feature 5 > 5.0)
#              If (feature 1 <= 12.0)
#               If (feature 9 <= 11.0)
#                Predict: 0.0
#               Else (feature 9 > 11.0)
#                Predict: 0.6666666666666666
#              Else (feature 1 > 12.0)
#               If (feature 0 <= 1.0)
#                Predict: 0.0
#               Else (feature 0 > 1.0)
#                Predict: 1.6666666666666667
#           Else (feature 7 > 10.0)
#            If (feature 6 <= 1.0)
#             If (feature 1 <= 12.0)
#              If (feature 8 <= 3.0)
#               Predict: 1.0
#              Else (feature 8 > 3.0)
#               If (feature 9 <= 11.0)
#                Predict: 1.0
#               Else (feature 9 > 11.0)
#                Predict: 1.75
#             Else (feature 1 > 12.0)
#              Predict: 0.0
#            Else (feature 6 > 1.0)
#             If (feature 9 <= 11.0)
#              If (feature 9 <= 10.0)
#               If (feature 4 <= 3.0)
#                Predict: 0.6666666666666666
#               Else (feature 4 > 3.0)
#                Predict: 0.0
#              Else (feature 9 > 10.0)
#               Predict: 1.0
#             Else (feature 9 > 11.0)
#              If (feature 1 <= 12.0)
#               Predict: 0.0
#              Else (feature 1 > 12.0)
#               Predict: 1.0
#         Else (feature 7 > 11.0)
#          If (feature 1 <= 11.0)
#           If (feature 4 <= 3.0)
#            If (feature 9 <= 9.0)
#             If (feature 2 <= 3.0)
#              Predict: 0.0
#             Else (feature 2 > 3.0)
#              If (feature 7 <= 12.0)
#               If (feature 9 <= 1.0)
#                Predict: 1.0
#               Else (feature 9 > 1.0)
#                Predict: 0.0
#              Else (feature 7 > 12.0)
#               Predict: 0.0
#            Else (feature 9 > 9.0)
#             If (feature 2 <= 3.0)
#              If (feature 6 <= 2.0)
#               If (feature 2 <= 1.0)
#                Predict: 1.0
#               Else (feature 2 > 1.0)
#                Predict: 0.16666666666666666
#              Else (feature 6 > 2.0)
#               If (feature 6 <= 3.0)
#                Predict: 0.0
#               Else (feature 6 > 3.0)
#                Predict: 0.5
#             Else (feature 2 > 3.0)
#              Predict: 1.0
#           Else (feature 4 > 3.0)
#            If (feature 3 <= 6.0)
#             If (feature 9 <= 9.0)
#              If (feature 3 <= 4.0)
#               Predict: 0.0
#              Else (feature 3 > 4.0)
#               If (feature 2 <= 1.0)
#                Predict: 0.0
#               Else (feature 2 > 1.0)
#                Predict: 0.3333333333333333
#             Else (feature 9 > 9.0)
#              If (feature 3 <= 4.0)
#               If (feature 7 <= 12.0)
#                Predict: 0.2857142857142857
#               Else (feature 7 > 12.0)
#                Predict: 0.8333333333333334
#              Else (feature 3 > 4.0)
#               Predict: 0.0
#            Else (feature 3 > 6.0)
#             Predict: 1.0
#          Else (feature 1 > 11.0)
#           If (feature 3 <= 5.0)
#            If (feature 6 <= 3.0)
#             If (feature 5 <= 3.0)
#              If (feature 5 <= 1.0)
#               If (feature 9 <= 8.0)
#                Predict: 1.25
#               Else (feature 9 > 8.0)
#                Predict: 3.0
#              Else (feature 5 > 1.0)
#               If (feature 9 <= 1.0)
#                Predict: 1.5
#               Else (feature 9 > 1.0)
#                Predict: 1.0
#             Else (feature 5 > 3.0)
#              If (feature 8 <= 2.0)
#               If (feature 0 <= 3.0)
#                Predict: 0.8888888888888888
#               Else (feature 0 > 3.0)
#                Predict: 0.0
#              Else (feature 8 > 2.0)
#               Predict: 0.0
#            Else (feature 6 > 3.0)
#             If (feature 0 <= 1.0)
#              Predict: 0.0
#             Else (feature 0 > 1.0)
#              Predict: 1.0
#           Else (feature 3 > 5.0)
#            If (feature 6 <= 2.0)
#             If (feature 9 <= 1.0)
#              Predict: 1.0
#             Else (feature 9 > 1.0)
#              Predict: 0.0
#            Else (feature 6 > 2.0)
#             If (feature 3 <= 7.0)
#              If (feature 7 <= 12.0)
#               If (feature 0 <= 2.0)
#                Predict: 1.0
#               Else (feature 0 > 2.0)
#                Predict: 0.0
#              Else (feature 7 > 12.0)
#               Predict: 1.0
#             Else (feature 3 > 7.0)
#              Predict: 0.0
#      Else (feature 3 > 8.0)
#       If (feature 7 <= 12.0)
#        If (feature 9 <= 8.0)
#         If (feature 7 <= 10.0)
#          If (feature 5 <= 7.0)
#           If (feature 8 <= 1.0)
#            If (feature 2 <= 2.0)
#             If (feature 1 <= 11.0)
#              If (feature 6 <= 1.0)
#               If (feature 9 <= 4.0)
#                Predict: 1.1612903225806452
#               Else (feature 9 > 4.0)
#                Predict: 0.47619047619047616
#              Else (feature 6 > 1.0)
#               If (feature 5 <= 1.0)
#                Predict: 1.0
#               Else (feature 5 > 1.0)
#                Predict: 0.5445544554455446
#             Else (feature 1 > 11.0)
#              If (feature 6 <= 1.0)
#               If (feature 7 <= 7.0)
#                Predict: 0.8181818181818182
#               Else (feature 7 > 7.0)
#                Predict: 0.0
#              Else (feature 6 > 1.0)
#               If (feature 4 <= 1.0)
#                Predict: 0.0
#               Else (feature 4 > 1.0)
#                Predict: 0.2727272727272727
#            Else (feature 2 > 2.0)
#             If (feature 1 <= 9.0)
#              If (feature 5 <= 4.0)
#               If (feature 7 <= 8.0)
#                Predict: 0.4479166666666667
#               Else (feature 7 > 8.0)
#                Predict: 0.2
#              Else (feature 5 > 4.0)
#               If (feature 9 <= 7.0)
#                Predict: 0.5789473684210527
#               Else (feature 9 > 7.0)
#                Predict: 1.8181818181818181
#             Else (feature 1 > 9.0)
#              If (feature 5 <= 6.0)
#               If (feature 7 <= 4.0)
#                Predict: 0.14285714285714285
#               Else (feature 7 > 4.0)
#                Predict: 0.5238095238095238
#              Else (feature 5 > 6.0)
#               Predict: 0.0
#           Else (feature 8 > 1.0)
#            If (feature 3 <= 11.0)
#             If (feature 7 <= 5.0)
#              If (feature 1 <= 2.0)
#               If (feature 0 <= 2.0)
#                Predict: 1.1666666666666667
#               Else (feature 0 > 2.0)
#                Predict: 0.6206896551724138
#              Else (feature 1 > 2.0)
#               If (feature 9 <= 6.0)
#                Predict: 0.54337899543379
#               Else (feature 9 > 6.0)
#                Predict: 0.2616822429906542
#             Else (feature 7 > 5.0)
#              If (feature 9 <= 5.0)
#               If (feature 5 <= 1.0)
#                Predict: 0.30434782608695654
#               Else (feature 5 > 1.0)
#                Predict: 0.521505376344086
#              Else (feature 9 > 5.0)
#               If (feature 1 <= 5.0)
#                Predict: 0.6153846153846154
#               Else (feature 1 > 5.0)
#                Predict: 0.872093023255814
#            Else (feature 3 > 11.0)
#             If (feature 7 <= 6.0)
#              If (feature 3 <= 12.0)
#               If (feature 1 <= 6.0)
#                Predict: 0.5957446808510638
#               Else (feature 1 > 6.0)
#                Predict: 0.34951456310679613
#              Else (feature 3 > 12.0)
#               If (feature 6 <= 2.0)
#                Predict: 0.726027397260274
#               Else (feature 6 > 2.0)
#                Predict: 0.5652173913043478
#             Else (feature 7 > 6.0)
#              If (feature 9 <= 7.0)
#               If (feature 8 <= 2.0)
#                Predict: 0.16393442622950818
#               Else (feature 8 > 2.0)
#                Predict: 0.3488372093023256
#              Else (feature 9 > 7.0)
#               If (feature 5 <= 5.0)
#                Predict: 0.16666666666666666
#               Else (feature 5 > 5.0)
#                Predict: 1.75
#          Else (feature 5 > 7.0)
#           If (feature 7 <= 7.0)
#            If (feature 9 <= 6.0)
#             If (feature 9 <= 5.0)
#              If (feature 0 <= 3.0)
#               If (feature 6 <= 3.0)
#                Predict: 0.15384615384615385
#               Else (feature 6 > 3.0)
#                Predict: 0.5294117647058824
#              Else (feature 0 > 3.0)
#               If (feature 6 <= 3.0)
#                Predict: 0.6666666666666666
#               Else (feature 6 > 3.0)
#                Predict: 0.25
#             Else (feature 9 > 5.0)
#              If (feature 6 <= 3.0)
#               If (feature 6 <= 2.0)
#                Predict: 0.09090909090909091
#               Else (feature 6 > 2.0)
#                Predict: 1.0
#              Else (feature 6 > 3.0)
#               Predict: 0.0
#            Else (feature 9 > 6.0)
#             If (feature 2 <= 3.0)
#              If (feature 4 <= 2.0)
#               Predict: 0.0
#              Else (feature 4 > 2.0)
#               If (feature 1 <= 9.0)
#                Predict: 1.0
#               Else (feature 1 > 9.0)
#                Predict: 0.5
#             Else (feature 2 > 3.0)
#              If (feature 1 <= 3.0)
#               Predict: 1.0
#              Else (feature 1 > 3.0)
#               If (feature 0 <= 1.0)
#                Predict: 4.0
#               Else (feature 0 > 1.0)
#                Predict: 3.0
#           Else (feature 7 > 7.0)
#            If (feature 9 <= 7.0)
#             If (feature 6 <= 2.0)
#              If (feature 9 <= 3.0)
#               If (feature 4 <= 2.0)
#                Predict: 0.5714285714285714
#               Else (feature 4 > 2.0)
#                Predict: 1.6666666666666667
#              Else (feature 9 > 3.0)
#               If (feature 7 <= 8.0)
#                Predict: 1.0
#               Else (feature 7 > 8.0)
#                Predict: 0.07692307692307693
#             Else (feature 6 > 2.0)
#              If (feature 9 <= 1.0)
#               If (feature 1 <= 7.0)
#                Predict: 1.0
#               Else (feature 1 > 7.0)
#                Predict: 3.0
#              Else (feature 9 > 1.0)
#               If (feature 7 <= 8.0)
#                Predict: 1.2857142857142858
#               Else (feature 7 > 8.0)
#                Predict: 0.9230769230769231
#            Else (feature 9 > 7.0)
#             If (feature 7 <= 9.0)
#              Predict: 3.0
#             Else (feature 7 > 9.0)
#              Predict: 6.0
#         Else (feature 7 > 10.0)
#          If (feature 5 <= 6.0)
#           If (feature 1 <= 11.0)
#            If (feature 3 <= 12.0)
#             If (feature 6 <= 2.0)
#              If (feature 0 <= 1.0)
#               If (feature 6 <= 1.0)
#                Predict: 0.14285714285714285
#               Else (feature 6 > 1.0)
#                Predict: 0.8461538461538461
#              Else (feature 0 > 1.0)
#               If (feature 5 <= 1.0)
#                Predict: 0.058823529411764705
#               Else (feature 5 > 1.0)
#                Predict: 0.31343283582089554
#             Else (feature 6 > 2.0)
#              If (feature 1 <= 8.0)
#               If (feature 8 <= 3.0)
#                Predict: 0.8333333333333334
#               Else (feature 8 > 3.0)
#                Predict: 0.5333333333333333
#              Else (feature 1 > 8.0)
#               If (feature 3 <= 11.0)
#                Predict: 0.42105263157894735
#               Else (feature 3 > 11.0)
#                Predict: 0.16666666666666666
#            Else (feature 3 > 12.0)
#             If (feature 8 <= 3.0)
#              If (feature 9 <= 3.0)
# ...
#             If (feature 3 <= 4.0)
#              If (feature 1 <= 4.0)
#               Predict: 1.0
#              Else (feature 1 > 4.0)
#               If (feature 7 <= 1.0)
#                Predict: 0.16666666666666666
#               Else (feature 7 > 1.0)
#                Predict: 0.25
#             Else (feature 3 > 4.0)
#              If (feature 6 <= 3.0)
#               If (feature 2 <= 3.0)
#                Predict: 0.5327433628318584
#               Else (feature 2 > 3.0)
#                Predict: 0.37012987012987014
#              Else (feature 6 > 3.0)
#               If (feature 1 <= 5.0)
#                Predict: 0.16
#               Else (feature 1 > 5.0)
#                Predict: 0.4371584699453552
#           Else (feature 1 > 12.0)
#            If (feature 0 <= 2.0)
#             If (feature 5 <= 9.0)
#              If (feature 5 <= 5.0)
#               If (feature 9 <= 5.0)
#                Predict: 1.0
#               Else (feature 9 > 5.0)
#                Predict: 0.0
#              Else (feature 5 > 5.0)
#               Predict: 0.0
#             Else (feature 5 > 9.0)
#              If (feature 7 <= 2.0)
#               If (feature 5 <= 10.0)
#                Predict: 1.0
#               Else (feature 5 > 10.0)
#                Predict: 0.0
#              Else (feature 7 > 2.0)
#               Predict: 0.0
#            Else (feature 0 > 2.0)
#             If (feature 5 <= 12.0)
#              If (feature 9 <= 8.0)
#               If (feature 7 <= 1.0)
#                Predict: 0.3333333333333333
#               Else (feature 7 > 1.0)
#                Predict: 0.0
#              Else (feature 9 > 8.0)
#               If (feature 7 <= 2.0)
#                Predict: 0.5
#               Else (feature 7 > 2.0)
#                Predict: 0.0
#             Else (feature 5 > 12.0)
#              If (feature 9 <= 10.0)
#               Predict: 1.0
#              Else (feature 9 > 10.0)
#               If (feature 6 <= 2.0)
#                Predict: 2.0
#               Else (feature 6 > 2.0)
#                Predict: 1.0
#         Else (feature 9 > 12.0)
#          If (feature 3 <= 11.0)
#           If (feature 3 <= 1.0)
#            If (feature 7 <= 1.0)
#             Predict: 2.0
#            Else (feature 7 > 1.0)
#             If (feature 1 <= 6.0)
#              Predict: 0.0
#             Else (feature 1 > 6.0)
#              Predict: 1.0
#           Else (feature 3 > 1.0)
#            If (feature 5 <= 12.0)
#             If (feature 0 <= 1.0)
#              If (feature 4 <= 1.0)
#               Predict: 0.0
#              Else (feature 4 > 1.0)
#               If (feature 1 <= 10.0)
#                Predict: 0.4117647058823529
#               Else (feature 1 > 10.0)
#                Predict: 1.8
#             Else (feature 0 > 1.0)
#              If (feature 1 <= 12.0)
#               If (feature 5 <= 11.0)
#                Predict: 0.18085106382978725
#               Else (feature 5 > 11.0)
#                Predict: 0.6
#              Else (feature 1 > 12.0)
#               Predict: 1.0
#            Else (feature 5 > 12.0)
#             If (feature 1 <= 12.0)
#              If (feature 4 <= 2.0)
#               If (feature 1 <= 8.0)
#                Predict: 2.0
#               Else (feature 1 > 8.0)
#                Predict: 1.1111111111111112
#              Else (feature 4 > 2.0)
#               Predict: 1.0
#             Else (feature 1 > 12.0)
#              Predict: 3.0
#          Else (feature 3 > 11.0)
#           If (feature 5 <= 8.0)
#            Predict: 1.0
#           Else (feature 5 > 8.0)
#            If (feature 0 <= 3.0)
#             If (feature 0 <= 2.0)
#              Predict: 3.0
#             Else (feature 0 > 2.0)
#              Predict: 1.0
#            Else (feature 0 > 3.0)
#             Predict: 5.0
#        Else (feature 7 > 3.0)
#         If (feature 3 <= 3.0)
#          If (feature 6 <= 3.0)
#           If (feature 1 <= 11.0)
#            If (feature 3 <= 2.0)
#             If (feature 1 <= 8.0)
#              If (feature 5 <= 5.0)
#               If (feature 0 <= 1.0)
#                Predict: 1.0
#               Else (feature 0 > 1.0)
#                Predict: 0.5416666666666666
#              Else (feature 5 > 5.0)
#               If (feature 6 <= 1.0)
#                Predict: 0.3068181818181818
#               Else (feature 6 > 1.0)
#                Predict: 0.4827586206896552
#             Else (feature 1 > 8.0)
#              If (feature 9 <= 4.0)
#               If (feature 4 <= 2.0)
#                Predict: 0.6
#               Else (feature 4 > 2.0)
#                Predict: 1.3529411764705883
#              Else (feature 9 > 4.0)
#               If (feature 7 <= 12.0)
#                Predict: 0.5414364640883977
#               Else (feature 7 > 12.0)
#                Predict: 0.125
#            Else (feature 3 > 2.0)
#             If (feature 9 <= 10.0)
#              If (feature 5 <= 5.0)
#               If (feature 7 <= 4.0)
#                Predict: 1.0
#               Else (feature 7 > 4.0)
#                Predict: 0.21428571428571427
#              Else (feature 5 > 5.0)
#               If (feature 5 <= 6.0)
#                Predict: 0.9583333333333334
#               Else (feature 5 > 6.0)
#                Predict: 0.44375
#             Else (feature 9 > 10.0)
#              If (feature 8 <= 1.0)
#               If (feature 0 <= 2.0)
#                Predict: 1.0
#               Else (feature 0 > 2.0)
#                Predict: 0.3333333333333333
#              Else (feature 8 > 1.0)
#               If (feature 4 <= 1.0)
#                Predict: 0.3333333333333333
#               Else (feature 4 > 1.0)
#                Predict: 0.10204081632653061
#           Else (feature 1 > 11.0)
#            If (feature 2 <= 1.0)
#             If (feature 4 <= 1.0)
#              If (feature 5 <= 7.0)
#               Predict: 5.0
#              Else (feature 5 > 7.0)
#               Predict: 0.0
#             Else (feature 4 > 1.0)
#              If (feature 5 <= 9.0)
#               If (feature 6 <= 1.0)
#                Predict: 0.7777777777777778
#               Else (feature 6 > 1.0)
#                Predict: 0.2631578947368421
#              Else (feature 5 > 9.0)
#               If (feature 7 <= 5.0)
#                Predict: 0.0
#               Else (feature 7 > 5.0)
#                Predict: 1.25
#            Else (feature 2 > 1.0)
#             If (feature 7 <= 4.0)
#              If (feature 5 <= 8.0)
#               If (feature 4 <= 2.0)
#                Predict: 1.0
#               Else (feature 4 > 2.0)
#                Predict: 3.6666666666666665
#              Else (feature 5 > 8.0)
#               Predict: 0.0
#             Else (feature 7 > 4.0)
#              If (feature 5 <= 11.0)
#               If (feature 4 <= 3.0)
#                Predict: 0.4727272727272727
#               Else (feature 4 > 3.0)
#                Predict: 0.20588235294117646
#              Else (feature 5 > 11.0)
#               If (feature 4 <= 2.0)
#                Predict: 1.0909090909090908
#               Else (feature 4 > 2.0)
#                Predict: 0.4166666666666667
#          Else (feature 6 > 3.0)
#           If (feature 9 <= 7.0)
#            If (feature 1 <= 6.0)
#             If (feature 7 <= 6.0)
#              If (feature 3 <= 1.0)
#               If (feature 5 <= 4.0)
#                Predict: 1.0
#               Else (feature 5 > 4.0)
#                Predict: 3.0
#              Else (feature 3 > 1.0)
#               If (feature 8 <= 2.0)
#                Predict: 2.0
#               Else (feature 8 > 2.0)
#                Predict: 0.5
#             Else (feature 7 > 6.0)
#              If (feature 7 <= 8.0)
#               If (feature 5 <= 8.0)
#                Predict: 0.75
#               Else (feature 5 > 8.0)
#                Predict: 0.0
#              Else (feature 7 > 8.0)
#               If (feature 5 <= 4.0)
#                Predict: 3.0
#               Else (feature 5 > 4.0)
#                Predict: 0.75
#            Else (feature 1 > 6.0)
#             If (feature 9 <= 6.0)
#              If (feature 1 <= 12.0)
#               If (feature 5 <= 10.0)
#                Predict: 0.410958904109589
#               Else (feature 5 > 10.0)
#                Predict: 0.12
#              Else (feature 1 > 12.0)
#               If (feature 7 <= 9.0)
#                Predict: 0.0
#               Else (feature 7 > 9.0)
#                Predict: 0.5
#             Else (feature 9 > 6.0)
#              If (feature 1 <= 8.0)
#               If (feature 5 <= 8.0)
#                Predict: 1.0
#               Else (feature 5 > 8.0)
#                Predict: 1.5
#              Else (feature 1 > 8.0)
#               If (feature 1 <= 9.0)
#                Predict: 0.0
#               Else (feature 1 > 9.0)
#                Predict: 0.6666666666666666
#           Else (feature 9 > 7.0)
#            If (feature 2 <= 3.0)
#             If (feature 8 <= 2.0)
#              If (feature 5 <= 12.0)
#               If (feature 5 <= 9.0)
#                Predict: 0.3709677419354839
#               Else (feature 5 > 9.0)
#                Predict: 0.08333333333333333
#              Else (feature 5 > 12.0)
#               If (feature 7 <= 9.0)
#                Predict: 0.0
#               Else (feature 7 > 9.0)
#                Predict: 1.0
#             Else (feature 8 > 2.0)
#              If (feature 7 <= 4.0)
#               If (feature 9 <= 8.0)
#                Predict: 3.0
#               Else (feature 9 > 8.0)
#                Predict: 0.375
#              Else (feature 7 > 4.0)
#               If (feature 1 <= 12.0)
#                Predict: 0.12195121951219512
#               Else (feature 1 > 12.0)
#                Predict: 0.625
#            Else (feature 2 > 3.0)
#             If (feature 7 <= 10.0)
#              If (feature 7 <= 6.0)
#               If (feature 1 <= 6.0)
#                Predict: 0.75
#               Else (feature 1 > 6.0)
#                Predict: 1.0
#              Else (feature 7 > 6.0)
#               If (feature 9 <= 10.0)
#                Predict: 1.4
#               Else (feature 9 > 10.0)
#                Predict: 0.21428571428571427
#             Else (feature 7 > 10.0)
#              If (feature 1 <= 10.0)
#               Predict: 0.0
#              Else (feature 1 > 10.0)
#               Predict: 1.0
#         Else (feature 3 > 3.0)
#          If (feature 7 <= 11.0)
#           If (feature 9 <= 10.0)
#            If (feature 5 <= 11.0)
#             If (feature 3 <= 11.0)
#              If (feature 4 <= 3.0)
#               If (feature 9 <= 8.0)
#                Predict: 0.8834586466165414
#               Else (feature 9 > 8.0)
#                Predict: 1.103125
#              Else (feature 4 > 3.0)
#               If (feature 1 <= 11.0)
#                Predict: 1.2951388888888888
#               Else (feature 1 > 11.0)
#                Predict: 0.4864864864864865
#             Else (feature 3 > 11.0)
#              If (feature 1 <= 11.0)
#               If (feature 5 <= 10.0)
#                Predict: 0.6323024054982818
#               Else (feature 5 > 10.0)
#                Predict: 0.2857142857142857
#              Else (feature 1 > 11.0)
#               If (feature 5 <= 4.0)
#                Predict: 1.3333333333333333
#               Else (feature 5 > 4.0)
#                Predict: 0.7878787878787878
#            Else (feature 5 > 11.0)
#             If (feature 9 <= 5.0)
#              If (feature 1 <= 5.0)
#               If (feature 8 <= 2.0)
#                Predict: 2.0
#               Else (feature 8 > 2.0)
#                Predict: 1.0
#              Else (feature 1 > 5.0)
#               If (feature 0 <= 1.0)
#                Predict: 0.92
#               Else (feature 0 > 1.0)
#                Predict: 0.6578947368421053
#             Else (feature 9 > 5.0)
#              If (feature 1 <= 12.0)
#               If (feature 3 <= 11.0)
#                Predict: 0.5
#               Else (feature 3 > 11.0)
#                Predict: 0.9264705882352942
#              Else (feature 1 > 12.0)
#               If (feature 8 <= 2.0)
#                Predict: 0.7692307692307693
#               Else (feature 8 > 2.0)
#                Predict: 1.5
#           Else (feature 9 > 10.0)
#            If (feature 3 <= 12.0)
#             If (feature 7 <= 10.0)
#              If (feature 3 <= 4.0)
#               If (feature 7 <= 4.0)
#                Predict: 2.4
#               Else (feature 7 > 4.0)
#                Predict: 0.8714285714285714
#              Else (feature 3 > 4.0)
#               If (feature 3 <= 7.0)
#                Predict: 0.4714285714285714
#               Else (feature 3 > 7.0)
#                Predict: 0.7098765432098766
#             Else (feature 7 > 10.0)
#              If (feature 9 <= 11.0)
#               If (feature 5 <= 9.0)
#                Predict: 1.4
#               Else (feature 5 > 9.0)
#                Predict: 2.9285714285714284
#              Else (feature 9 > 11.0)
#               If (feature 4 <= 1.0)
#                Predict: 1.4285714285714286
#               Else (feature 4 > 1.0)
#                Predict: 0.6610169491525424
#            Else (feature 3 > 12.0)
#             If (feature 9 <= 12.0)
#              If (feature 0 <= 3.0)
#               If (feature 1 <= 11.0)
#                Predict: 0.5348837209302325
#               Else (feature 1 > 11.0)
#                Predict: 1.5333333333333334
#              Else (feature 0 > 3.0)
#               If (feature 8 <= 3.0)
#                Predict: 0.6666666666666666
#               Else (feature 8 > 3.0)
#                Predict: 0.125
#             Else (feature 9 > 12.0)
#              If (feature 1 <= 12.0)
#               If (feature 0 <= 1.0)
#                Predict: 2.7
#               Else (feature 0 > 1.0)
#                Predict: 1.3636363636363635
#              Else (feature 1 > 12.0)
#               Predict: 6.0
#          Else (feature 7 > 11.0)
#           If (feature 5 <= 5.0)
#            If (feature 1 <= 5.0)
#             If (feature 9 <= 5.0)
#              Predict: 3.0
#             Else (feature 9 > 5.0)
#              If (feature 9 <= 11.0)
#               If (feature 4 <= 2.0)
#                Predict: 0.3333333333333333
#               Else (feature 4 > 2.0)
#                Predict: 1.0
#              Else (feature 9 > 11.0)
#               Predict: 2.0
#            Else (feature 1 > 5.0)
#             If (feature 6 <= 1.0)
#              If (feature 3 <= 11.0)
#               If (feature 2 <= 1.0)
#                Predict: 1.0
#               Else (feature 2 > 1.0)
#                Predict: 0.125
#              Else (feature 3 > 11.0)
#               Predict: 0.0
#             Else (feature 6 > 1.0)
#              If (feature 1 <= 9.0)
#               If (feature 3 <= 11.0)
#                Predict: 0.2894736842105263
#               Else (feature 3 > 11.0)
#                Predict: 1.1875
#              Else (feature 1 > 9.0)
#               If (feature 6 <= 2.0)
#                Predict: 0.7777777777777778
#               Else (feature 6 > 2.0)
#                Predict: 0.45
#           Else (feature 5 > 5.0)
#            If (feature 9 <= 10.0)
#             If (feature 9 <= 8.0)
#              If (feature 1 <= 11.0)
#               If (feature 1 <= 9.0)
#                Predict: 0.7090163934426229
#               Else (feature 1 > 9.0)
#                Predict: 0.5135135135135135
#              Else (feature 1 > 11.0)
#               If (feature 0 <= 1.0)
#                Predict: 1.1428571428571428
#               Else (feature 0 > 1.0)
#                Predict: 0.8
#             Else (feature 9 > 8.0)
#              If (feature 2 <= 2.0)
#               If (feature 8 <= 1.0)
#                Predict: 0.2608695652173913
#               Else (feature 8 > 1.0)
#                Predict: 0.8596491228070176
#              Else (feature 2 > 2.0)
#               If (feature 7 <= 12.0)
#                Predict: 0.7931034482758621
#               Else (feature 7 > 12.0)
#                Predict: 1.5
#            Else (feature 9 > 10.0)
#             If (feature 8 <= 3.0)
#              If (feature 1 <= 6.0)
#               If (feature 5 <= 10.0)
#                Predict: 0.5185185185185185
#               Else (feature 5 > 10.0)
#                Predict: 1.0
#              Else (feature 1 > 6.0)
#               If (feature 2 <= 1.0)
#                Predict: 0.8285714285714286
#               Else (feature 2 > 1.0)
#                Predict: 1.3404255319148937
#             Else (feature 8 > 3.0)
#              If (feature 5 <= 6.0)
#               Predict: 2.0
#              Else (feature 5 > 6.0)
#               If (feature 0 <= 3.0)
#                Predict: 1.0909090909090908
#               Else (feature 0 > 3.0)
#                Predict: 2.3333333333333335
